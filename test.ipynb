# %%
import requests
import base64

# %%
import urllib.parse

# %%
params = {
    'track': 'Stairway*to*Heaven',
    'artist': 'Led Zeppelin',
    'album': 'Led Zeppelin IV'
}

# %%
urllib.parse.urlencode(params)
# Out:
# 'track=Stairway%2Ato%2AHeaven&artist=Led+Zeppelin&album=Led+Zeppelin+IV'

# %%
CLIENT_ID = "fb725b50f755401cb21714d2f2c08d56"
CLIENT_SECRET = "71d1e11f53ab4c7799b871f0cfd8f24c"
REDIRECT_URI = "http://localhost:5000/callback"

AUTH_URL = "https://accounts.spotify.com/authorize"
TOKEN_URL = "https://accounts.spotify.com/api/token"
API_BASE_URL = "https://api.spotify.com/v1/"

# %%
scope = "user-read-private user-read-email"

params = {
    'client_id': CLIENT_ID,
    'response_type': 'code',
    'scope': scope,
    'redirect_uri': REDIRECT_URI,
    'show_dialog': False
}

auth_url = f"{AUTH_URL}?{urllib.parse.urlencode(params)}"

# %%
response = requests.get(auth_url)

# %%
response.__dict__['cookies']
# Out:
# <RequestsCookieJar[Cookie(version=0, name='__Secure-TPASESSION', value='AQCAF7CRAhcluMWiYz3VKIcvL/igu8ZKy/IHfhJ4N4UUDWnDBNQklD3ht26G8+izlSp9PlkCslz8XOWZLVjAyCuxvuR9hb2MU5I=', port=None, port_specified=False, domain='.accounts.spotify.com', domain_specified=True, domain_initial_dot=False, path='/', path_specified=True, secure=True, expires=None, discard=True, comment=None, comment_url=None, rest={'HttpOnly': None, 'SameSite': 'None'}, rfc2109=True), Cookie(version=0, name='sp_sso_csrf_token', value='013acda719a5fabb36e45345e64f15b15ae4c3a51d31373335373830353439383432', port=None, port_specified=False, domain='.accounts.spotify.com', domain_specified=True, domain_initial_dot=False, path='/', path_specified=True, secure=True, expires=None, discard=True, comment=None, comment_url=None, rest={'SameSite': 'Lax'}, rfc2109=True), Cookie(version=0, name='__Host-sp_csrf_sid', value='757a9d87e918d4123bbf67bec410badfd800dae5b6f74993251401545a20806f', port=None, port_specified=False, domain='acco
# ...

# %%
teste = [1, 2, 3]

# %%
str(teste)
# Out:
# '[1, 2, 3]'

# %% [markdown]
# # GET BEARER TOKEN

# %% [markdown]
# curl -X POST "https://accounts.spotify.com/api/token" \
#      -H "Content-Type: application/x-www-form-urlencoded" \
#      -d "grant_type=client_credentials&client_id=your-client-id&client_secret=your-client-secret"

# %%
client_id = "fb725b50f755401cb21714d2f2c08d56"
client_secret = "71d1e11f53ab4c7799b871f0cfd8f24c"

encoded_creds = base64.b64encode(client_id.encode() + b":" + client_secret.encode()).decode('utf-8')

# urls
token_url = "https://accounts.spotify.com/api/token"

# scope
scope = 'playlist-modify-public playlist-modify-private'

# %%
# obtains authorization token

token_headers = {
    "Authorization": "Basic " + encoded_creds,
    "Content-Type": "application/x-www-form-urlencoded"
}

token_data = {
    "grant_type": "client_credentials",
    "scope": scope
}

r = requests.post(token_url, data=token_data, headers=token_headers)
access_token = r.json()['access_token']
access_token
# Out:
# 'BQDCjIKHAdhxNOzBs3v6x5kpIC5XsVJ5_lRhrC1SMW0FDZo1bnp07K64h_xgkMcgsebEejRqavH-_hhwSVazuxPVxFQsn-veU40VfPRBTNdkAM-SIA2eVMMC4Dm0OmrgQmk9u6U0XxRJ1LJniUrJ4oAuuhrsHGkHCW92c_u6mU4pR6jr'

# %% [markdown]
# # GET ARTIST DATA

# %% [markdown]
# curl "https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb" \
#      -H "Authorization: Bearer  BQDBKJ5eo5jxbtpWjVOj7ryS84khybFpP_lTqzV7uV-T_m0cTfwvdn5BnBSKPxKgEb11"

# %%
url = "https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb"

headers = { "Authorization": "Bearer " + access_token }

r = requests.get(url, headers = headers)
r.json()
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#  'followers': {'href': None, 'total': 11156523},
#  'genres': ['alternative rock',
#   'art rock',
#   'melancholia',
#   'oxford indie',
#   'permanent wave',
#   'rock'],
#  'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#  'id': '4Z8W4fKeB5YxbusRsdQVPb',
#  'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5eba03696716c9ee605006047fd',
#    'height': 640,
#    'width': 640},
#   {'url': 'https://i.scdn.co/image/ab67616100005174a03696716c9ee605006047fd',
#    'height': 320,
#    'width': 320},
#   {'url': 'https://i.scdn.co/image/ab6761610000f178a03696716c9ee605006047fd',
#    'height': 160,
#    'width': 160}],
#  'name': 'Radiohead',
#  'popularity': 85,
#  'type': 'artist',
#  'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}

# %% [markdown]
# # Crealte a playlist

# %% [markdown]
# echo '{
#     "name": "New Playlist",
#     "description": "New playlist description",
#     "public": false
# }' |  \
#   http POST https://api.spotify.com/v1/users/smedjan/playlists \
#   Authorization:'Bearer 1POdFZRZbvb...qqillRxMr2z' \
#   Content-Type:application/json

# %%
username = "t29dhlqdaov8fdmnrbcnhidcb"
name = "Teste Nich's Jukebox"
description = "testes iniciais de API"

url = "https://api.spotify.com/v1/users/t29dhlqdaov8fdmnrbcnhidcb/playlists"

headers = { "Authorization": "Bearer " + access_token }

data = {
    "name": name,
    "description": description,
    "public": False
}

r = requests.post(url, headers = headers, data=data)
r.json()
# Out:
# {'error': {'status': 401, 'message': 'Valid user authentication required'}}

# %%
input = "Montadoras decretam férias coletivas por conta das enchentes do RS"
resp = requests.post("https://fact-check-inspiria-32mkcjubia-rj.a.run.app", json={'input':input, 'dominios': 2, 'max': 1})
if resp.status_code ==200:
    print(resp.json()['response'])

# %%
resp.json()

# %%
playlist = {
  "href": "https://api.spotify.com/v1/playlists/7zOs4PgwOpwlfQAkX7OHEJ/tracks?offset=0&limit=100&locale=pt-BR,pt;q%3D0.9,es-ES;q%3D0.8,es;q%3D0.7,zh-TW;q%3D0.6,zh;q%3D0.5",
  "items": [
    {
      "added_at": "2024-12-29T22:18:52Z",
      "added_by": {
        "external_urls": {
          "spotify": "https://open.spotify.com/user/t29dhlqdaov8fdmnrbcnhidcb"
        },
        "href": "https://api.spotify.com/v1/users/t29dhlqdaov8fdmnrbcnhidcb",
        "id": "t29dhlqdaov8fdmnrbcnhidcb",
        "type": "user",
        "uri": "spotify:user:t29dhlqdaov8fdmnrbcnhidcb"
      },
      "is_local": False,
      "primary_color": "null",
      "track": {
        "preview_url": "null",
        "available_markets": [
          "AR",
          "AU",
          "AT",
          "BE",
          "BO",
          "BR",
          "BG",
          "CA",
          "CL",
          "CO",
          "CR",
          "CY",
          "CZ",
          "DK",
          "DO",
          "DE",
          "EC",
          "EE",
          "SV",
          "FI",
          "FR",
          "GR",
          "GT",
          "HN",
          "HK",
          "HU",
          "IS",
          "IE",
          "IT",
          "LV",
          "LT",
          "LU",
          "MY",
          "MT",
          "MX",
          "NL",
          "NZ",
          "NI",
          "NO",
          "PA",
          "PY",
          "PE",
          "PH",
          "PL",
          "PT",
          "SG",
          "SK",
          "ES",
          "SE",
          "CH",
          "TW",
          "TR",
          "UY",
          "US",
          "GB",
          "AD",
          "LI",
          "MC",
          "ID",
          "JP",
          "TH",
          "VN",
          "RO",
          "ZA",
          "SA",
          "AE",
          "BH",
          "QA",
          "OM",
          "KW",
          "EG",
          "MA",
          "DZ",
          "TN",
          "LB",
          "JO",
          "PS",
          "IN",
          "BY",
          "KZ",
          "MD",
          "UA",
          "AL",
          "BA",
          "HR",
          "ME",
          "MK",
          "RS",
          "SI",
          "KR",
          "BD",
          "PK",
          "LK",
          "GH",
          "KE",
          "NG",
          "TZ",
          "UG",
          "AG",
          "AM",
          "BS",
          "BB",
          "BZ",
          "BT",
          "BW",
          "BF",
          "CV",
          "CW",
          "DM",
          "FJ",
          "GM",
          "GE",
          "GD",
          "GW",
          "GY",
          "HT",
          "JM",
          "KI",
          "LS",
          "LR",
          "MW",
          "MV",
          "ML",
          "MH",
          "FM",
          "NA",
          "NR",
          "NE",
          "PW",
          "PG",
          "PR",
          "WS",
          "SM",
          "ST",
          "SN",
          "SC",
          "SL",
          "SB",
          "KN",
          "LC",
          "VC",
          "SR",
          "TL",
          "TO",
          "TT",
          "TV",
          "VU",
          "AZ",
          "BN",
          "BI",
          "KH",
          "CM",
          "TD",
          "KM",
          "GQ",
          "SZ",
          "GA",
          "GN",
          "KG",
          "LA",
          "MO",
          "MR",
          "MN",
          "NP",
          "RW",
          "TG",
          "UZ",
          "ZW",
          "BJ",
          "MG",
          "MU",
          "MZ",
          "AO",
          "CI",
          "DJ",
          "ZM",
          "CD",
          "CG",
          "IQ",
          "LY",
          "TJ",
          "VE",
          "ET",
          "XK"
        ],
        "explicit": False,
        "type": "track",
        "episode": False,
        "track": True,
        "album": {
          "available_markets": [
            "AR",
            "AU",
            "AT",
            "BE",
            "BO",
            "BR",
            "BG",
            "CA",
            "CL",
            "CO",
            "CR",
            "CY",
            "CZ",
            "DK",
            "DO",
            "DE",
            "EC",
            "EE",
            "SV",
            "FI",
            "FR",
            "GR",
            "GT",
            "HN",
            "HK",
            "HU",
            "IS",
            "IE",
            "IT",
            "LV",
            "LT",
            "LU",
            "MY",
            "MT",
            "MX",
            "NL",
            "NZ",
            "NI",
            "NO",
            "PA",
            "PY",
            "PE",
            "PH",
            "PL",
            "PT",
            "SG",
            "SK",
            "ES",
            "SE",
            "CH",
            "TW",
            "TR",
            "UY",
            "US",
            "GB",
            "AD",
            "LI",
            "MC",
            "ID",
            "JP",
            "TH",
            "VN",
            "RO",
            "ZA",
            "SA",
            "AE",
            "BH",
            "QA",
            "OM",
            "KW",
            "EG",
            "MA",
            "DZ",
            "TN",
            "LB",
            "JO",
            "PS",
            "IN",
            "BY",
            "KZ",
            "MD",
            "UA",
            "AL",
            "BA",
            "HR",
            "ME",
            "MK",
            "RS",
            "SI",
            "KR",
            "BD",
            "PK",
            "LK",
            "GH",
            "KE",
            "NG",
            "TZ",
            "UG",
            "AG",
            "AM",
            "BS",
            "BB",
            "BZ",
            "BT",
            "BW",
            "BF",
            "CV",
            "CW",
            "DM",
            "FJ",
            "GM",
            "GE",
            "GD",
            "GW",
            "GY",
            "HT",
            "JM",
            "KI",
            "LS",
            "LR",
            "MW",
            "MV",
            "ML",
            "MH",
            "FM",
            "NA",
            "NR",
            "NE",
            "PW",
            "PG",
            "PR",
            "WS",
            "SM",
            "ST",
            "SN",
            "SC",
            "SL",
            "SB",
            "KN",
            "LC",
            "VC",
            "SR",
            "TL",
            "TO",
            "TT",
            "TV",
            "VU",
            "AZ",
            "BN",
            "BI",
            "KH",
            "CM",
            "TD",
            "KM",
            "GQ",
            "SZ",
            "GA",
            "GN",
            "KG",
            "LA",
            "MO",
            "MR",
            "MN",
            "NP",
            "RW",
            "TG",
            "UZ",
            "ZW",
            "BJ",
            "MG",
            "MU",
            "MZ",
            "AO",
            "CI",
            "DJ",
            "ZM",
            "CD",
            "CG",
            "IQ",
            "LY",
            "TJ",
            "VE",
            "ET",
            "XK"
          ],
          "type": "album",
          "album_type": "album",
          "href": "https://api.spotify.com/v1/albums/22Jw1aVVP0MijVVO5ls0qn",
          "id": "22Jw1aVVP0MijVVO5ls0qn",
          "images": [
            {
              "height": 640,
              "url": "https://i.scdn.co/image/ab67616d0000b273d8b7f29b1da971d65059d858",
              "width": 640
            },
            {
              "height": 300,
              "url": "https://i.scdn.co/image/ab67616d00001e02d8b7f29b1da971d65059d858",
              "width": 300
            },
            {
              "height": 64,
              "url": "https://i.scdn.co/image/ab67616d00004851d8b7f29b1da971d65059d858",
              "width": 64
            }
          ],
          "name": "The Reckoning",
          "release_date": "2008",
          "release_date_precision": "year",
          "uri": "spotify:album:22Jw1aVVP0MijVVO5ls0qn",
          "artists": [
            {
              "external_urls": {
                "spotify": "https://open.spotify.com/artist/7t51dSX8ZkKC7VoKRd0lME"
              },
              "href": "https://api.spotify.com/v1/artists/7t51dSX8ZkKC7VoKRd0lME",
              "id": "7t51dSX8ZkKC7VoKRd0lME",
              "name": "Asaf Avidan",
              "type": "artist",
              "uri": "spotify:artist:7t51dSX8ZkKC7VoKRd0lME"
            },
            {
              "external_urls": {
                "spotify": "https://open.spotify.com/artist/5abaNg0SJPEF7EST0RjY9F"
              },
              "href": "https://api.spotify.com/v1/artists/5abaNg0SJPEF7EST0RjY9F",
              "id": "5abaNg0SJPEF7EST0RjY9F",
              "name": "The Mojos",
              "type": "artist",
              "uri": "spotify:artist:5abaNg0SJPEF7EST0RjY9F"
            }
          ],
          "external_urls": {
            "spotify": "https://open.spotify.com/album/22Jw1aVVP0MijVVO5ls0qn"
          },
          "total_tracks": 15
        },
        "artists": [
          {
            "external_urls": {
              "spotify": "https://open.spotify.com/artist/7t51dSX8ZkKC7VoKRd0lME"
            },
            "href": "https://api.spotify.com/v1/artists/7t51dSX8ZkKC7VoKRd0lME",
            "id": "7t51dSX8ZkKC7VoKRd0lME",
            "name": "Asaf Avidan",
            "type": "artist",
            "uri": "spotify:artist:7t51dSX8ZkKC7VoKRd0lME"
          },
          {
            "external_urls": {
              "spotify": "https://open.spotify.com/artist/5abaNg0SJPEF7EST0RjY9F"
            },
            "href": "https://api.spotify.com/v1/artists/5abaNg0SJPEF7EST0RjY9F",
            "id": "5abaNg0SJPEF7EST0RjY9F",
            "name": "The Mojos",
            "type": "artist",
            "uri": "spotify:artist:5abaNg0SJPEF7EST0RjY9F"
          }
        ],
        "disc_number": 1,
        "track_number": 5,
        "duration_ms": 166813,
        "external_ids": {
          "isrc": "IL6170800063"
        },
        "external_urls": {
          "spotify": "https://open.spotify.com/track/6Wk6A8k7NjjSsPQT9Z3FXM"
        },
        "href": "https://api.spotify.com/v1/tracks/6Wk6A8k7NjjSsPQT9Z3FXM",
        "id": "6Wk6A8k7NjjSsPQT9Z3FXM",
        "name": "Reckoning Song",
        "popularity": 68,
        "uri": "spotify:track:6Wk6A8k7NjjSsPQT9Z3FXM",
        "is_local": False
      },
      "video_thumbnail": {
        "url": "null"
      }
    },
    {
      "added_at": "2024-12-30T21:38:51Z",
      "added_by": {
        "external_urls": {
          "spotify": "https://open.spotify.com/user/t29dhlqdaov8fdmnrbcnhidcb"
        },
        "href": "https://api.spotify.com/v1/users/t29dhlqdaov8fdmnrbcnhidcb",
        "id": "t29dhlqdaov8fdmnrbcnhidcb",
        "type": "user",
        "uri": "spotify:user:t29dhlqdaov8fdmnrbcnhidcb"
      },
      "is_local": False,
      "primary_color": "null",
      "track": {
        "preview_url": "null",
        "available_markets": [
          "AR",
          "AU",
          "AT",
          "BE",
          "BO",
          "BR",
          "BG",
          "CA",
          "CL",
          "CO",
          "CR",
          "CY",
          "CZ",
          "DK",
          "DO",
          "DE",
          "EC",
          "EE",
          "SV",
          "FI",
          "FR",
          "GR",
          "GT",
          "HN",
          "HK",
          "HU",
          "IS",
          "IE",
          "IT",
          "LV",
          "LT",
          "LU",
          "MY",
          "MT",
          "MX",
          "NL",
          "NZ",
          "NI",
          "NO",
          "PA",
          "PY",
          "PE",
          "PH",
          "PL",
          "PT",
          "SG",
          "SK",
          "ES",
          "SE",
          "CH",
          "TW",
          "TR",
          "UY",
          "US",
          "GB",
          "AD",
          "LI",
          "MC",
          "ID",
          "JP",
          "TH",
          "VN",
          "RO",
          "IL",
          "ZA",
          "SA",
          "AE",
          "BH",
          "QA",
          "OM",
          "KW",
          "EG",
          "MA",
          "DZ",
          "TN",
          "LB",
          "JO",
          "PS",
          "IN",
          "BY",
          "KZ",
          "MD",
          "UA",
          "AL",
          "BA",
          "HR",
          "ME",
          "MK",
          "RS",
          "SI",
          "KR",
          "BD",
          "PK",
          "LK",
          "GH",
          "KE",
          "NG",
          "TZ",
          "UG",
          "AG",
          "AM",
          "BS",
          "BB",
          "BZ",
          "BT",
          "BW",
          "BF",
          "CV",
          "CW",
          "DM",
          "FJ",
          "GM",
          "GE",
          "GD",
          "GW",
          "GY",
          "HT",
          "JM",
          "KI",
          "LS",
          "LR",
          "MW",
          "MV",
          "ML",
          "MH",
          "FM",
          "NA",
          "NR",
          "NE",
          "PW",
          "PG",
          "PR",
          "WS",
          "SM",
          "ST",
          "SN",
          "SC",
          "SL",
          "SB",
          "KN",
          "LC",
          "VC",
          "SR",
          "TL",
          "TO",
          "TT",
          "TV",
          "VU",
          "AZ",
          "BN",
          "BI",
          "KH",
          "CM",
          "TD",
          "KM",
          "GQ",
          "SZ",
          "GA",
          "GN",
          "KG",
          "LA",
          "MO",
          "MR",
          "MN",
          "NP",
          "RW",
          "TG",
          "UZ",
          "ZW",
          "BJ",
          "MG",
          "MU",
          "MZ",
          "AO",
          "CI",
          "DJ",
          "ZM",
          "CD",
          "CG",
          "IQ",
          "LY",
          "TJ",
          "VE",
          "ET",
          "XK"
        ],
        "explicit": False,
        "type": "track",
        "episode": False,
        "track": True,
        "album": {
          "available_markets": [
            "AR",
            "AU",
            "AT",
            "BE",
            "BO",
            "BR",
            "BG",
            "CA",
            "CL",
            "CO",
            "CR",
            "CY",
            "CZ",
            "DK",
            "DO",
            "DE",
            "EC",
            "EE",
            "SV",
            "FI",
            "FR",
            "GR",
            "GT",
            "HN",
            "HK",
            "HU",
            "IS",
            "IE",
            "IT",
            "LV",
            "LT",
            "LU",
            "MY",
            "MT",
            "MX",
            "NL",
            "NZ",
            "NI",
            "NO",
            "PA",
            "PY",
            "PE",
            "PH",
            "PL",
            "PT",
            "SG",
            "SK",
            "ES",
            "SE",
            "CH",
            "TW",
            "TR",
            "UY",
            "US",
            "GB",
            "AD",
            "LI",
            "MC",
            "ID",
            "JP",
            "TH",
            "VN",
            "RO",
            "IL",
            "ZA",
            "SA",
            "AE",
            "BH",
            "QA",
            "OM",
            "KW",
            "EG",
            "MA",
            "DZ",
            "TN",
            "LB",
            "JO",
            "PS",
            "IN",
            "BY",
            "KZ",
            "MD",
            "UA",
            "AL",
            "BA",
            "HR",
            "ME",
            "MK",
            "RS",
            "SI",
            "KR",
            "BD",
            "PK",
            "LK",
            "GH",
            "KE",
            "NG",
            "TZ",
            "UG",
            "AG",
            "AM",
            "BS",
            "BB",
            "BZ",
            "BT",
            "BW",
            "BF",
            "CV",
            "CW",
            "DM",
            "FJ",
            "GM",
            "GE",
            "GD",
            "GW",
            "GY",
            "HT",
            "JM",
            "KI",
            "LS",
            "LR",
            "MW",
            "MV",
            "ML",
            "MH",
            "FM",
            "NA",
            "NR",
            "NE",
            "PW",
            "PG",
            "PR",
            "WS",
            "SM",
            "ST",
            "SN",
            "SC",
            "SL",
            "SB",
            "KN",
            "LC",
            "VC",
            "SR",
            "TL",
            "TO",
            "TT",
            "TV",
            "VU",
            "AZ",
            "BN",
            "BI",
            "KH",
            "CM",
            "TD",
            "KM",
            "GQ",
            "SZ",
            "GA",
            "GN",
            "KG",
            "LA",
            "MO",
            "MR",
            "MN",
            "NP",
            "RW",
            "TG",
            "UZ",
            "ZW",
            "BJ",
            "MG",
            "MU",
            "MZ",
            "AO",
            "CI",
            "DJ",
            "ZM",
            "CD",
            "CG",
            "IQ",
            "LY",
            "TJ",
            "VE",
            "ET",
            "XK"
          ],
          "type": "album",
          "album_type": "album",
          "href": "https://api.spotify.com/v1/albums/3AKNwgDdWfEDrPM384eY3S",
          "id": "3AKNwgDdWfEDrPM384eY3S",
          "images": [
            {
              "height": 640,
              "url": "https://i.scdn.co/image/ab67616d0000b2738ccc291223b6c9da031e6a5e",
              "width": 640
            },
            {
              "height": 300,
              "url": "https://i.scdn.co/image/ab67616d00001e028ccc291223b6c9da031e6a5e",
              "width": 300
            },
            {
              "height": 64,
              "url": "https://i.scdn.co/image/ab67616d000048518ccc291223b6c9da031e6a5e",
              "width": 64
            }
          ],
          "name": "Roda de Funk",
          "release_date": "1999-11-01",
          "release_date_precision": "day",
          "uri": "spotify:album:3AKNwgDdWfEDrPM384eY3S",
          "artists": [
            {
              "external_urls": {
                "spotify": "https://open.spotify.com/artist/4EdK5PbxoQyOAJFWpc8xLg"
              },
              "href": "https://api.spotify.com/v1/artists/4EdK5PbxoQyOAJFWpc8xLg",
              "id": "4EdK5PbxoQyOAJFWpc8xLg",
              "name": "Funk Como Le Gusta",
              "type": "artist",
              "uri": "spotify:artist:4EdK5PbxoQyOAJFWpc8xLg"
            },
            {
              "external_urls": {
                "spotify": "https://open.spotify.com/artist/1kDJFTg4KHIPymr1A6Vylm"
              },
              "href": "https://api.spotify.com/v1/artists/1kDJFTg4KHIPymr1A6Vylm",
              "id": "1kDJFTg4KHIPymr1A6Vylm",
              "name": "BiD",
              "type": "artist",
              "uri": "spotify:artist:1kDJFTg4KHIPymr1A6Vylm"
            }
          ],
          "external_urls": {
            "spotify": "https://open.spotify.com/album/3AKNwgDdWfEDrPM384eY3S"
          },
          "total_tracks": 16
        },
        "artists": [
          {
            "external_urls": {
              "spotify": "https://open.spotify.com/artist/4EdK5PbxoQyOAJFWpc8xLg"
            },
            "href": "https://api.spotify.com/v1/artists/4EdK5PbxoQyOAJFWpc8xLg",
            "id": "4EdK5PbxoQyOAJFWpc8xLg",
            "name": "Funk Como Le Gusta",
            "type": "artist",
            "uri": "spotify:artist:4EdK5PbxoQyOAJFWpc8xLg"
          },
          {
            "external_urls": {
              "spotify": "https://open.spotify.com/artist/1kDJFTg4KHIPymr1A6Vylm"
            },
            "href": "https://api.spotify.com/v1/artists/1kDJFTg4KHIPymr1A6Vylm",
            "id": "1kDJFTg4KHIPymr1A6Vylm",
            "name": "BiD",
            "type": "artist",
            "uri": "spotify:artist:1kDJFTg4KHIPymr1A6Vylm"
          }
        ],
        "disc_number": 1,
        "track_number": 7,
        "duration_ms": 244400,
        "external_ids": {
          "isrc": "BRTRB1871185"
        },
        "external_urls": {
          "spotify": "https://open.spotify.com/track/00XzBQrfXJ6QXNAxvN1dJM"
        },
        "href": "https://api.spotify.com/v1/tracks/00XzBQrfXJ6QXNAxvN1dJM",
        "id": "00XzBQrfXJ6QXNAxvN1dJM",
        "name": "Funk Hum",
        "popularity": 15,
        "uri": "spotify:track:00XzBQrfXJ6QXNAxvN1dJM",
        "is_local": False
      },
      "video_thumbnail": {
        "url": "null"
      }
    }
  ],
  "limit": 100,
  "next": "null",
  "offset": 0,
  "previous": "null",
  "total": 2
}

# %%
playlist = {
  "collaborative": False,
  "description": "string",
  "external_urls": {
    "spotify": "string"
  },
  "followers": {
    "href": "string",
    "total": 0
  },
  "href": "string",
  "id": "string",
  "images": [
    {
      "url": "https://i.scdn.co/image/ab67616d00001e02ff9ca10b55ce82ae553c8228",
      "height": 300,
      "width": 300
    }
  ],
  "name": "string",
  "owner": {
    "external_urls": {
      "spotify": "string"
    },
    "followers": {
      "href": "string",
      "total": 0
    },
    "href": "string",
    "id": "string",
    "type": "user",
    "uri": "string",
    "display_name": "string"
  },
  "public": False,
  "snapshot_id": "string",
  "tracks": {
    "href": "https://api.spotify.com/v1/me/shows?offset=0&limit=20",
    "limit": 20,
    "next": "https://api.spotify.com/v1/me/shows?offset=1&limit=1",
    "offset": 0,
    "previous": "https://api.spotify.com/v1/me/shows?offset=1&limit=1",
    "total": 4,
    "items": [
      {
        "added_at": "string",
        "added_by": {
          "external_urls": {
            "spotify": "string"
          },
          "followers": {
            "href": "string",
            "total": 0
          },
          "href": "string",
          "id": "string",
          "type": "user",
          "uri": "string"
        },
        "is_local": False,
        "track": {
          "album": {
            "album_type": "compilation",
            "total_tracks": 9,
            "available_markets": [
              "CA",
              "BR",
              "IT"
            ],
            "external_urls": {
              "spotify": "string"
            },
            "href": "string",
            "id": "2up3OPMp9Tb4dAKM2erWXQ",
            "images": [
              {
                "url": "https://i.scdn.co/image/ab67616d00001e02ff9ca10b55ce82ae553c8228",
                "height": 300,
                "width": 300
              }
            ],
            "name": "string",
            "release_date": "1981-12",
            "release_date_precision": "year",
            "restrictions": {
              "reason": "market"
            },
            "type": "album",
            "uri": "spotify:album:2up3OPMp9Tb4dAKM2erWXQ",
            "artists": [
              {
                "external_urls": {
                  "spotify": "string"
                },
                "href": "string",
                "id": "string",
                "name": "string",
                "type": "artist",
                "uri": "string"
              }
            ]
          },
          "artists": [
            {
              "external_urls": {
                "spotify": "string"
              },
              "href": "string",
              "id": "string",
              "name": "string",
              "type": "artist",
              "uri": "string"
            }
          ],
          "available_markets": [
            "string"
          ],
          "disc_number": 0,
          "duration_ms": 0,
          "explicit": False,
          "external_ids": {
            "isrc": "string",
            "ean": "string",
            "upc": "string"
          },
          "external_urls": {
            "spotify": "string"
          },
          "href": "string",
          "id": "string",
          "is_playable": False,
          "linked_from": {},
          "restrictions": {
            "reason": "string"
          },
          "name": "string",
          "popularity": 0,
          "preview_url": "string",
          "track_number": 0,
          "type": "track",
          "uri": "string",
          "is_local": False
        }
      }
    ]
  },
  "type": "string",
  "uri": "string"
}

# %%
playlist

# %%
resp = {
  "currently_playing": {
    "album": {
      "album_type": "album",
      "artists": [
        {
          "external_urls": {
            "spotify": "https://open.spotify.com/artist/7HGNYPmbDrMkylWqeFCOIQ"
          },
          "href": "https://api.spotify.com/v1/artists/7HGNYPmbDrMkylWqeFCOIQ",
          "id": "7HGNYPmbDrMkylWqeFCOIQ",
          "name": "Caetano Veloso",
          "type": "artist",
          "uri": "spotify:artist:7HGNYPmbDrMkylWqeFCOIQ"
        }
      ],
      "available_markets": [
        "AR",
        "AU",
        "AT",
        "BE",
        "BO",
        "BR",
        "BG",
        "CA",
        "CL",
        "CO",
        "CR",
        "CY",
        "CZ",
        "DK",
        "DO",
        "DE",
        "EC",
        "EE",
        "SV",
        "FI",
        "FR",
        "GR",
        "GT",
        "HN",
        "HK",
        "HU",
        "IS",
        "IE",
        "IT",
        "LV",
        "LT",
        "LU",
        "MY",
        "MT",
        "MX",
        "NL",
        "NZ",
        "NI",
        "NO",
        "PA",
        "PY",
        "PE",
        "PH",
        "PL",
        "PT",
        "SG",
        "SK",
        "ES",
        "SE",
        "CH",
        "TW",
        "TR",
        "UY",
        "US",
        "GB",
        "AD",
        "LI",
        "MC",
        "ID",
        "JP",
        "TH",
        "VN",
        "RO",
        "IL",
        "ZA",
        "SA",
        "AE",
        "BH",
        "QA",
        "OM",
        "KW",
        "EG",
        "MA",
        "DZ",
        "TN",
        "LB",
        "JO",
        "PS",
        "IN",
        "BY",
        "KZ",
        "MD",
        "UA",
        "AL",
        "BA",
        "HR",
        "ME",
        "MK",
        "RS",
        "SI",
        "KR",
        "BD",
        "PK",
        "LK",
        "GH",
        "KE",
        "NG",
        "TZ",
        "UG",
        "AG",
        "AM",
        "BS",
        "BB",
        "BZ",
        "BT",
        "BW",
        "BF",
        "CV",
        "CW",
        "DM",
        "FJ",
        "GM",
        "GE",
        "GD",
        "GW",
        "GY",
        "HT",
        "JM",
        "KI",
        "LS",
        "LR",
        "MW",
        "MV",
        "ML",
        "MH",
        "FM",
        "NA",
        "NR",
        "NE",
        "PW",
        "PG",
        "WS",
        "SM",
        "ST",
        "SN",
        "SC",
        "SL",
        "SB",
        "KN",
        "LC",
        "VC",
        "SR",
        "TL",
        "TO",
        "TT",
        "TV",
        "VU",
        "AZ",
        "BN",
        "BI",
        "KH",
        "CM",
        "TD",
        "KM",
        "GQ",
        "SZ",
        "GA",
        "GN",
        "KG",
        "LA",
        "MO",
        "MR",
        "MN",
        "NP",
        "RW",
        "TG",
        "UZ",
        "ZW",
        "BJ",
        "MG",
        "MU",
        "MZ",
        "AO",
        "CI",
        "DJ",
        "ZM",
        "CD",
        "CG",
        "IQ",
        "LY",
        "TJ",
        "VE",
        "ET",
        "XK"
      ],
      "external_urls": {
        "spotify": "https://open.spotify.com/album/1xAQ6kW7DQZxTghyepHtzm"
      },
      "href": "https://api.spotify.com/v1/albums/1xAQ6kW7DQZxTghyepHtzm",
      "id": "1xAQ6kW7DQZxTghyepHtzm",
      "images": [
        {
          "height": 640,
          "url": "https://i.scdn.co/image/ab67616d0000b273d9e9436112102a62090fbff2",
          "width": 640
        },
        {
          "height": 300,
          "url": "https://i.scdn.co/image/ab67616d00001e02d9e9436112102a62090fbff2",
          "width": 300
        },
        {
          "height": 64,
          "url": "https://i.scdn.co/image/ab67616d00004851d9e9436112102a62090fbff2",
          "width": 64
        }
      ],
      "name": "Cores, Nomes",
      "release_date": "1982-01-01",
      "release_date_precision": "day",
      "total_tracks": 12,
      "type": "album",
      "uri": "spotify:album:1xAQ6kW7DQZxTghyepHtzm"
    },
    "artists": [
      {
        "external_urls": {
          "spotify": "https://open.spotify.com/artist/7HGNYPmbDrMkylWqeFCOIQ"
        },
        "href": "https://api.spotify.com/v1/artists/7HGNYPmbDrMkylWqeFCOIQ",
        "id": "7HGNYPmbDrMkylWqeFCOIQ",
        "name": "Caetano Veloso",
        "type": "artist",
        "uri": "spotify:artist:7HGNYPmbDrMkylWqeFCOIQ"
      }
    ],
    "available_markets": [
      "AR",
      "AU",
      "AT",
      "BE",
      "BO",
      "BR",
      "BG",
      "CA",
      "CL",
      "CO",
      "CR",
      "CY",
      "CZ",
      "DK",
      "DO",
      "DE",
      "EC",
      "EE",
      "SV",
      "FI",
      "FR",
      "GR",
      "GT",
      "HN",
      "HK",
      "HU",
      "IS",
      "IE",
      "IT",
      "LV",
      "LT",
      "LU",
      "MY",
      "MT",
      "MX",
      "NL",
      "NZ",
      "NI",
      "NO",
      "PA",
      "PY",
      "PE",
      "PH",
      "PL",
      "PT",
      "SG",
      "SK",
      "ES",
      "SE",
      "CH",
      "TW",
      "TR",
      "UY",
      "US",
      "GB",
      "AD",
      "LI",
      "MC",
      "ID",
      "JP",
      "TH",
      "VN",
      "RO",
      "IL",
      "ZA",
      "SA",
      "AE",
      "BH",
      "QA",
      "OM",
      "KW",
      "EG",
      "MA",
      "DZ",
      "TN",
      "LB",
      "JO",
      "PS",
      "IN",
      "BY",
      "KZ",
      "MD",
      "UA",
      "AL",
      "BA",
      "HR",
      "ME",
      "MK",
      "RS",
      "SI",
      "KR",
      "BD",
      "PK",
      "LK",
      "GH",
      "KE",
      "NG",
      "TZ",
      "UG",
      "AG",
      "AM",
      "BS",
      "BB",
      "BZ",
      "BT",
      "BW",
      "BF",
      "CV",
      "CW",
      "DM",
      "FJ",
      "GM",
      "GE",
      "GD",
      "GW",
      "GY",
      "HT",
      "JM",
      "KI",
      "LS",
      "LR",
      "MW",
      "MV",
      "ML",
      "MH",
      "FM",
      "NA",
      "NR",
      "NE",
      "PW",
      "PG",
      "WS",
      "SM",
      "ST",
      "SN",
      "SC",
      "SL",
      "SB",
      "KN",
      "LC",
      "VC",
      "SR",
      "TL",
      "TO",
      "TT",
      "TV",
      "VU",
      "AZ",
      "BN",
      "BI",
      "KH",
      "CM",
      "TD",
      "KM",
      "GQ",
      "SZ",
      "GA",
      "GN",
      "KG",
      "LA",
      "MO",
      "MR",
      "MN",
      "NP",
      "RW",
      "TG",
      "UZ",
      "ZW",
      "BJ",
      "MG",
      "MU",
      "MZ",
      "AO",
      "CI",
      "DJ",
      "ZM",
      "CD",
      "CG",
      "IQ",
      "LY",
      "TJ",
      "VE",
      "ET",
      "XK"
    ],
    "disc_number": 1,
    "duration_ms": 434960,
    "explicit": False,
    "external_ids": {
      "isrc": "BRMCA8200165"
    },
    "external_urls": {
      "spotify": "https://open.spotify.com/track/0WpeZok7zzqy1MHTcyWra0"
    },
    "href": "https://api.spotify.com/v1/tracks/0WpeZok7zzqy1MHTcyWra0",
    "id": "0WpeZok7zzqy1MHTcyWra0",
    "is_local": False,
    "name": "Ele Me Deu Um Beijo Na Boca (He Gave Me A Kiss On The Mouth)",
    "popularity": 27,
    "preview_url": "null",
    "track_number": 2,
    "type": "track",
    "uri": "spotify:track:0WpeZok7zzqy1MHTcyWra0"
  },
  "queue": [
    {
      "album": {
        "album_type": "album",
        "artists": [
          {
            "external_urls": {
              "spotify": "https://open.spotify.com/artist/7HGNYPmbDrMkylWqeFCOIQ"
            },
            "href": "https://api.spotify.com/v1/artists/7HGNYPmbDrMkylWqeFCOIQ",
            "id": "7HGNYPmbDrMkylWqeFCOIQ",
            "name": "Caetano Veloso",
            "type": "artist",
            "uri": "spotify:artist:7HGNYPmbDrMkylWqeFCOIQ"
          }
        ],
        "available_markets": [
          "AR",
          "AU",
          "AT",
          "BE",
          "BO",
          "BR",
          "BG",
          "CA",
          "CL",
          "CO",
          "CR",
          "CY",
          "CZ",
          "DK",
          "DO",
          "DE",
          "EC",
          "EE",
          "SV",
          "FI",
          "FR",
          "GR",
          "GT",
          "HN",
          "HK",
          "HU",
          "IS",
          "IE",
          "IT",
          "LV",
          "LT",
          "LU",
          "MY",
          "MT",
          "MX",
          "NL",
          "NZ",
          "NI",
          "NO",
          "PA",
          "PY",
          "PE",
          "PH",
          "PL",
          "PT",
          "SG",
          "SK",
          "ES",
          "SE",
          "CH",
          "TW",
          "TR",
          "UY",
          "US",
          "GB",
          "AD",
          "LI",
          "MC",
          "ID",
          "JP",
          "TH",
          "VN",
          "RO",
          "IL",
          "ZA",
          "SA",
          "AE",
          "BH",
          "QA",
          "OM",
          "KW",
          "EG",
          "MA",
          "DZ",
          "TN",
          "LB",
          "JO",
          "PS",
          "IN",
          "BY",
          "KZ",
          "MD",
          "UA",
          "AL",
          "BA",
          "HR",
          "ME",
          "MK",
          "RS",
          "SI",
          "KR",
          "BD",
          "PK",
          "LK",
          "GH",
          "KE",
          "NG",
          "TZ",
          "UG",
          "AG",
          "AM",
          "BS",
          "BB",
          "BZ",
          "BT",
          "BW",
          "BF",
          "CV",
          "CW",
          "DM",
          "FJ",
          "GM",
          "GE",
          "GD",
          "GW",
          "GY",
          "HT",
          "JM",
          "KI",
          "LS",
          "LR",
          "MW",
          "MV",
          "ML",
          "MH",
          "FM",
          "NA",
          "NR",
          "NE",
          "PW",
          "PG",
          "WS",
          "SM",
          "ST",
          "SN",
          "SC",
          "SL",
          "SB",
          "KN",
          "LC",
          "VC",
          "SR",
          "TL",
          "TO",
          "TT",
          "TV",
          "VU",
          "AZ",
          "BN",
          "BI",
          "KH",
          "CM",
          "TD",
          "KM",
          "GQ",
          "SZ",
          "GA",
          "GN",
          "KG",
          "LA",
          "MO",
          "MR",
          "MN",
          "NP",
          "RW",
          "TG",
          "UZ",
          "ZW",
          "BJ",
          "MG",
          "MU",
          "MZ",
          "AO",
          "CI",
          "DJ",
          "ZM",
          "CD",
          "CG",
          "IQ",
          "LY",
          "TJ",
          "VE",
          "ET",
          "XK"
        ],
        "external_urls": {
          "spotify": "https://open.spotify.com/album/1xAQ6kW7DQZxTghyepHtzm"
        },
        "href": "https://api.spotify.com/v1/albums/1xAQ6kW7DQZxTghyepHtzm",
        "id": "1xAQ6kW7DQZxTghyepHtzm",
        "images": [
          {
            "height": 640,
            "url": "https://i.scdn.co/image/ab67616d0000b273d9e9436112102a62090fbff2",
            "width": 640
          },
          {
            "height": 300,
            "url": "https://i.scdn.co/image/ab67616d00001e02d9e9436112102a62090fbff2",
            "width": 300
          },
          {
            "height": 64,
            "url": "https://i.scdn.co/image/ab67616d00004851d9e9436112102a62090fbff2",
            "width": 64
          }
        ],
        "name": "Cores, Nomes",
        "release_date": "1982-01-01",
        "release_date_precision": "day",
        "total_tracks": 12,
        "type": "album",
        "uri": "spotify:album:1xAQ6kW7DQZxTghyepHtzm"
      },
      "artists": [
        {
          "external_urls": {
            "spotify": "https://open.spotify.com/artist/7HGNYPmbDrMkylWqeFCOIQ"
          },
          "href": "https://api.spotify.com/v1/artists/7HGNYPmbDrMkylWqeFCOIQ",
          "id": "7HGNYPmbDrMkylWqeFCOIQ",
          "name": "Caetano Veloso",
          "type": "artist",
          "uri": "spotify:artist:7HGNYPmbDrMkylWqeFCOIQ"
        }
      ],
      "available_markets": [
        "AR",
        "AU",
        "AT",
        "BE",
        "BO",
        "BR",
        "BG",
        "CA",
        "CL",
        "CO",
        "CR",
        "CY",
        "CZ",
        "DK",
        "DO",
        "DE",
        "EC",
        "EE",
        "SV",
        "FI",
        "FR",
        "GR",
        "GT",
        "HN",
        "HK",
        "HU",
        "IS",
        "IE",
        "IT",
        "LV",
        "LT",
        "LU",
        "MY",
        "MT",
        "MX",
        "NL",
        "NZ",
        "NI",
        "NO",
        "PA",
        "PY",
        "PE",
        "PH",
        "PL",
        "PT",
        "SG",
        "SK",
        "ES",
        "SE",
        "CH",
        "TW",
        "TR",
        "UY",
        "US",
        "GB",
        "AD",
        "LI",
        "MC",
        "ID",
        "JP",
        "TH",
        "VN",
        "RO",
        "IL",
        "ZA",
        "SA",
        "AE",
        "BH",
        "QA",
        "OM",
        "KW",
        "EG",
        "MA",
        "DZ",
        "TN",
        "LB",
        "JO",
        "PS",
        "IN",
        "BY",
        "KZ",
        "MD",
        "UA",
        "AL",
        "BA",
        "HR",
        "ME",
        "MK",
        "RS",
        "SI",
        "KR",
        "BD",
        "PK",
        "LK",
        "GH",
        "KE",
        "NG",
        "TZ",
        "UG",
        "AG",
        "AM",
        "BS",
        "BB",
        "BZ",
        "BT",
        "BW",
        "BF",
        "CV",
        "CW",
        "DM",
        "FJ",
        "GM",
        "GE",
        "GD",
        "GW",
        "GY",
        "HT",
        "JM",
        "KI",
        "LS",
        "LR",
        "MW",
        "MV",
        "ML",
        "MH",
        "FM",
        "NA",
        "NR",
        "NE",
        "PW",
        "PG",
        "WS",
        "SM",
        "ST",
        "SN",
        "SC",
        "SL",
        "SB",
        "KN",
        "LC",
        "VC",
        "SR",
        "TL",
        "TO",
        "TT",
        "TV",
        "VU",
        "AZ",
        "BN",
        "BI",
        "KH",
        "CM",
        "TD",
        "KM",
        "GQ",
        "SZ",
        "GA",
        "GN",
        "KG",
        "LA",
        "MO",
        "MR",
        "MN",
        "NP",
        "RW",
        "TG",
        "UZ",
        "ZW",
        "BJ",
        "MG",
        "MU",
        "MZ",
        "AO",
        "CI",
        "DJ",
        "ZM",
        "CD",
        "CG",
        "IQ",
        "LY",
        "TJ",
        "VE",
        "ET",
        "XK"
      ],
      "disc_number": 1,
      "duration_ms": 263373,
      "explicit": False,
      "external_ids": {
        "isrc": "BRMCA8200164"
      },
      "external_urls": {
        "spotify": "https://open.spotify.com/track/1NIAQbzrcpqoaZd3sNFFKJ"
      },
      "href": "https://api.spotify.com/v1/tracks/1NIAQbzrcpqoaZd3sNFFKJ",
      "id": "1NIAQbzrcpqoaZd3sNFFKJ",
      "is_local": False,
      "name": "Queixa",
      "popularity": 51,
      "preview_url": "null",
      "track_number": 1,
      "type": "track",
      "uri": "spotify:track:1NIAQbzrcpqoaZd3sNFFKJ"
    },
    {
      "album": {
        "album_type": "album",
        "artists": [
          {
            "external_urls": {
              "spotify": "https://open.spotify.com/artist/7t51dSX8ZkKC7VoKRd0lME"
            },
            "href": "https://api.spotify.com/v1/artists/7t51dSX8ZkKC7VoKRd0lME",
            "id": "7t51dSX8ZkKC7VoKRd0lME",
            "name": "Asaf Avidan",
            "type": "artist",
            "uri": "spotify:artist:7t51dSX8ZkKC7VoKRd0lME"
          },
          {
            "external_urls": {
              "spotify": "https://open.spotify.com/artist/5abaNg0SJPEF7EST0RjY9F"
            },
            "href": "https://api.spotify.com/v1/artists/5abaNg0SJPEF7EST0RjY9F",
            "id": "5abaNg0SJPEF7EST0RjY9F",
            "name": "The Mojos",
            "type": "artist",
            "uri": "spotify:artist:5abaNg0SJPEF7EST0RjY9F"
          }
        ],
        "available_markets": [
          "AR",
          "AU",
          "AT",
          "BE",
          "BO",
          "BR",
          "BG",
          "CA",
          "CL",
          "CO",
          "CR",
          "CY",
          "CZ",
          "DK",
          "DO",
          "DE",
          "EC",
          "EE",
          "SV",
          "FI",
          "FR",
          "GR",
          "GT",
          "HN",
          "HK",
          "HU",
          "IS",
          "IE",
          "IT",
          "LV",
          "LT",
          "LU",
          "MY",
          "MT",
          "MX",
          "NL",
          "NZ",
          "NI",
          "NO",
          "PA",
          "PY",
          "PE",
          "PH",
          "PL",
          "PT",
          "SG",
          "SK",
          "ES",
          "SE",
          "CH",
          "TW",
          "TR",
          "UY",
          "US",
          "GB",
          "AD",
          "LI",
          "MC",
          "ID",
          "JP",
          "TH",
          "VN",
          "RO",
          "ZA",
          "SA",
          "AE",
          "BH",
          "QA",
          "OM",
          "KW",
          "EG",
          "MA",
          "DZ",
          "TN",
          "LB",
          "JO",
          "PS",
          "IN",
          "BY",
          "KZ",
          "MD",
          "UA",
          "AL",
          "BA",
          "HR",
          "ME",
          "MK",
          "RS",
          "SI",
          "KR",
          "BD",
          "PK",
          "LK",
          "GH",
          "KE",
          "NG",
          "TZ",
          "UG",
          "AG",
          "AM",
          "BS",
          "BB",
          "BZ",
          "BT",
          "BW",
          "BF",
          "CV",
          "CW",
          "DM",
          "FJ",
          "GM",
          "GE",
          "GD",
          "GW",
          "GY",
          "HT",
          "JM",
          "KI",
          "LS",
          "LR",
          "MW",
          "MV",
          "ML",
          "MH",
          "FM",
          "NA",
          "NR",
          "NE",
          "PW",
          "PG",
          "PR",
          "WS",
          "SM",
          "ST",
          "SN",
          "SC",
          "SL",
          "SB",
          "KN",
          "LC",
          "VC",
          "SR",
          "TL",
          "TO",
          "TT",
          "TV",
          "VU",
          "AZ",
          "BN",
          "BI",
          "KH",
          "CM",
          "TD",
          "KM",
          "GQ",
          "SZ",
          "GA",
          "GN",
          "KG",
          "LA",
          "MO",
          "MR",
          "MN",
          "NP",
          "RW",
          "TG",
          "UZ",
          "ZW",
          "BJ",
          "MG",
          "MU",
          "MZ",
          "AO",
          "CI",
          "DJ",
          "ZM",
          "CD",
          "CG",
          "IQ",
          "LY",
          "TJ",
          "VE",
          "ET",
          "XK"
        ],
        "external_urls": {
          "spotify": "https://open.spotify.com/album/22Jw1aVVP0MijVVO5ls0qn"
        },
        "href": "https://api.spotify.com/v1/albums/22Jw1aVVP0MijVVO5ls0qn",
        "id": "22Jw1aVVP0MijVVO5ls0qn",
        "images": [
          {
            "height": 640,
            "url": "https://i.scdn.co/image/ab67616d0000b273d8b7f29b1da971d65059d858",
            "width": 640
          },
          {
            "height": 300,
            "url": "https://i.scdn.co/image/ab67616d00001e02d8b7f29b1da971d65059d858",
            "width": 300
          },
          {
            "height": 64,
            "url": "https://i.scdn.co/image/ab67616d00004851d8b7f29b1da971d65059d858",
            "width": 64
          }
        ],
        "name": "The Reckoning",
        "release_date": "2008",
        "release_date_precision": "year",
        "total_tracks": 15,
        "type": "album",
        "uri": "spotify:album:22Jw1aVVP0MijVVO5ls0qn"
      },
      "artists": [
        {
          "external_urls": {
            "spotify": "https://open.spotify.com/artist/7t51dSX8ZkKC7VoKRd0lME"
          },
          "href": "https://api.spotify.com/v1/artists/7t51dSX8ZkKC7VoKRd0lME",
          "id": "7t51dSX8ZkKC7VoKRd0lME",
          "name": "Asaf Avidan",
          "type": "artist",
          "uri": "spotify:artist:7t51dSX8ZkKC7VoKRd0lME"
        },
        {
          "external_urls": {
            "spotify": "https://open.spotify.com/artist/5abaNg0SJPEF7EST0RjY9F"
          },
          "href": "https://api.spotify.com/v1/artists/5abaNg0SJPEF7EST0RjY9F",
          "id": "5abaNg0SJPEF7EST0RjY9F",
          "name": "The Mojos",
          "type": "artist",
          "uri": "spotify:artist:5abaNg0SJPEF7EST0RjY9F"
        }
      ],
      "available_markets": [
        "AR",
        "AU",
        "AT",
        "BE",
        "BO",
        "BR",
        "BG",
        "CA",
        "CL",
        "CO",
        "CR",
        "CY",
        "CZ",
        "DK",
        "DO",
        "DE",
        "EC",
        "EE",
        "SV",
        "FI",
        "FR",
        "GR",
        "GT",
        "HN",
        "HK",
        "HU",
        "IS",
        "IE",
        "IT",
        "LV",
        "LT",
        "LU",
        "MY",
        "MT",
        "MX",
        "NL",
        "NZ",
        "NI",
        "NO",
        "PA",
        "PY",
        "PE",
        "PH",
        "PL",
        "PT",
        "SG",
        "SK",
        "ES",
        "SE",
        "CH",
        "TW",
        "TR",
        "UY",
        "US",
        "GB",
        "AD",
        "LI",
        "MC",
        "ID",
        "JP",
        "TH",
        "VN",
        "RO",
        "ZA",
        "SA",
        "AE",
        "BH",
        "QA",
        "OM",
        "KW",
        "EG",
        "MA",
        "DZ",
        "TN",
        "LB",
        "JO",
        "PS",
        "IN",
        "BY",
        "KZ",
        "MD",
        "UA",
        "AL",
        "BA",
        "HR",
        "ME",
        "MK",
        "RS",
        "SI",
        "KR",
        "BD",
        "PK",
        "LK",
        "GH",
        "KE",
        "NG",
        "TZ",
        "UG",
        "AG",
        "AM",
        "BS",
        "BB",
        "BZ",
        "BT",
        "BW",
        "BF",
        "CV",
        "CW",
        "DM",
        "FJ",
        "GM",
        "GE",
        "GD",
        "GW",
        "GY",
        "HT",
        "JM",
        "KI",
        "LS",
        "LR",
        "MW",
        "MV",
        "ML",
        "MH",
        "FM",
        "NA",
        "NR",
        "NE",
        "PW",
        "PG",
        "PR",
        "WS",
        "SM",
        "ST",
        "SN",
        "SC",
        "SL",
        "SB",
        "KN",
        "LC",
        "VC",
        "SR",
        "TL",
        "TO",
        "TT",
        "TV",
        "VU",
        "AZ",
        "BN",
        "BI",
        "KH",
        "CM",
        "TD",
        "KM",
        "GQ",
        "SZ",
        "GA",
        "GN",
        "KG",
        "LA",
        "MO",
        "MR",
        "MN",
        "NP",
        "RW",
        "TG",
        "UZ",
        "ZW",
        "BJ",
        "MG",
        "MU",
        "MZ",
        "AO",
        "CI",
        "DJ",
        "ZM",
        "CD",
        "CG",
        "IQ",
        "LY",
        "TJ",
        "VE",
        "ET",
        "XK"
      ],
      "disc_number": 1,
      "duration_ms": 166813,
      "explicit": False,
      "external_ids": {
        "isrc": "IL6170800063"
      },
      "external_urls": {
        "spotify": "https://open.spotify.com/track/6Wk6A8k7NjjSsPQT9Z3FXM"
      },
      "href": "https://api.spotify.com/v1/tracks/6Wk6A8k7NjjSsPQT9Z3FXM",
      "id": "6Wk6A8k7NjjSsPQT9Z3FXM",
      "is_local": False,
      "name": "Reckoning Song",
      "popularity": 68,
      "preview_url": "null",
      "track_number": 5,
      "type": "track",
      "uri": "spotify:track:6Wk6A8k7NjjSsPQT9Z3FXM"
    },
    {
      "album": {
        "album_type": "album",
        "artists": [
          {
            "external_urls": {
              "spotify": "https://open.spotify.com/artist/7HGNYPmbDrMkylWqeFCOIQ"
            },
            "href": "https://api.spotify.com/v1/artists/7HGNYPmbDrMkylWqeFCOIQ",
            "id": "7HGNYPmbDrMkylWqeFCOIQ",
            "name": "Caetano Veloso",
            "type": "artist",
            "uri": "spotify:artist:7HGNYPmbDrMkylWqeFCOIQ"
          }
        ],
        "available_markets": [
          "AR",
          "AU",
          "AT",
          "BE",
          "BO",
          "BR",
          "BG",
          "CA",
          "CL",
          "CO",
          "CR",
          "CY",
          "CZ",
          "DK",
          "DO",
          "DE",
          "EC",
          "EE",
          "SV",
          "FI",
          "FR",
          "GR",
          "GT",
          "HN",
          "HK",
          "HU",
          "IS",
          "IE",
          "IT",
          "LV",
          "LT",
          "LU",
          "MY",
          "MT",
          "MX",
          "NL",
          "NZ",
          "NI",
          "NO",
          "PA",
          "PY",
          "PE",
          "PH",
          "PL",
          "PT",
          "SG",
          "SK",
          "ES",
          "SE",
          "CH",
          "TW",
          "TR",
          "UY",
          "US",
          "GB",
          "AD",
          "LI",
          "MC",
          "ID",
          "JP",
          "TH",
          "VN",
          "RO",
          "IL",
          "ZA",
          "SA",
          "AE",
          "BH",
          "QA",
          "OM",
          "KW",
          "EG",
          "MA",
          "DZ",
          "TN",
          "LB",
          "JO",
          "PS",
          "IN",
          "BY",
          "KZ",
          "MD",
          "UA",
          "AL",
          "BA",
          "HR",
          "ME",
          "MK",
          "RS",
          "SI",
          "KR",
          "BD",
          "PK",
          "LK",
          "GH",
          "KE",
          "NG",
          "TZ",
          "UG",
          "AG",
          "AM",
          "BS",
          "BB",
          "BZ",
          "BT",
          "BW",
          "BF",
          "CV",
          "CW",
          "DM",
          "FJ",
          "GM",
          "GE",
          "GD",
          "GW",
          "GY",
          "HT",
          "JM",
          "KI",
          "LS",
          "LR",
          "MW",
          "MV",
          "ML",
          "MH",
          "FM",
          "NA",
          "NR",
          "NE",
          "PW",
          "PG",
          "WS",
          "SM",
          "ST",
          "SN",
          "SC",
          "SL",
          "SB",
          "KN",
          "LC",
          "VC",
          "SR",
          "TL",
          "TO",
          "TT",
          "TV",
          "VU",
          "AZ",
          "BN",
          "BI",
          "KH",
          "CM",
          "TD",
          "KM",
          "GQ",
          "SZ",
          "GA",
          "GN",
          "KG",
          "LA",
          "MO",
          "MR",
          "MN",
          "NP",
          "RW",
          "TG",
          "UZ",
          "ZW",
          "BJ",
          "MG",
          "MU",
          "MZ",
          "AO",
          "CI",
          "DJ",
          "ZM",
          "CD",
          "CG",
          "IQ",
          "LY",
          "TJ",
          "VE",
          "ET",
          "XK"
        ],
        "external_urls": {
          "spotify": "https://open.spotify.com/album/1xAQ6kW7DQZxTghyepHtzm"
        },
        "href": "https://api.spotify.com/v1/albums/1xAQ6kW7DQZxTghyepHtzm",
        "id": "1xAQ6kW7DQZxTghyepHtzm",
        "images": [
          {
            "height": 640,
            "url": "https://i.scdn.co/image/ab67616d0000b273d9e9436112102a62090fbff2",
            "width": 640
          },
          {
            "height": 300,
            "url": "https://i.scdn.co/image/ab67616d00001e02d9e9436112102a62090fbff2",
            "width": 300
          },
          {
            "height": 64,
            "url": "https://i.scdn.co/image/ab67616d00004851d9e9436112102a62090fbff2",
            "width": 64
          }
        ],
        "name": "Cores, Nomes",
        "release_date": "1982-01-01",
        "release_date_precision": "day",
        "total_tracks": 12,
        "type": "album",
        "uri": "spotify:album:1xAQ6kW7DQZxTghyepHtzm"
      },
      "artists": [
        {
          "external_urls": {
            "spotify": "https://open.spotify.com/artist/7HGNYPmbDrMkylWqeFCOIQ"
          },
          "href": "https://api.spotify.com/v1/artists/7HGNYPmbDrMkylWqeFCOIQ",
          "id": "7HGNYPmbDrMkylWqeFCOIQ",
          "name": "Caetano Veloso",
          "type": "artist",
          "uri": "spotify:artist:7HGNYPmbDrMkylWqeFCOIQ"
        }
      ],
      "available_markets": [
        "AR",
        "AU",
        "AT",
        "BE",
        "BO",
        "BR",
        "BG",
        "CA",
        "CL",
        "CO",
        "CR",
        "CY",
        "CZ",
        "DK",
        "DO",
        "DE",
        "EC",
        "EE",
        "SV",
        "FI",
        "FR",
        "GR",
        "GT",
        "HN",
        "HK",
        "HU",
        "IS",
        "IE",
        "IT",
        "LV",
        "LT",
        "LU",
        "MY",
        "MT",
        "MX",
        "NL",
        "NZ",
        "NI",
        "NO",
        "PA",
        "PY",
        "PE",
        "PH",
        "PL",
        "PT",
        "SG",
        "SK",
        "ES",
        "SE",
        "CH",
        "TW",
        "TR",
        "UY",
        "US",
        "GB",
        "AD",
        "LI",
        "MC",
        "ID",
        "JP",
        "TH",
        "VN",
        "RO",
        "IL",
        "ZA",
        "SA",
        "AE",
        "BH",
        "QA",
        "OM",
        "KW",
        "EG",
        "MA",
        "DZ",
        "TN",
        "LB",
        "JO",
        "PS",
        "IN",
        "BY",
        "KZ",
        "MD",
        "UA",
        "AL",
        "BA",
        "HR",
        "ME",
        "MK",
        "RS",
        "SI",
        "KR",
        "BD",
        "PK",
        "LK",
        "GH",
        "KE",
        "NG",
        "TZ",
        "UG",
        "AG",
        "AM",
        "BS",
        "BB",
        "BZ",
        "BT",
        "BW",
        "BF",
        "CV",
        "CW",
        "DM",
        "FJ",
        "GM",
        "GE",
        "GD",
        "GW",
        "GY",
        "HT",
        "JM",
        "KI",
        "LS",
        "LR",
        "MW",
        "MV",
        "ML",
        "MH",
        "FM",
        "NA",
        "NR",
        "NE",
        "PW",
        "PG",
        "WS",
        "SM",
        "ST",
        "SN",
        "SC",
        "SL",
        "SB",
        "KN",
        "LC",
        "VC",
        "SR",
        "TL",
        "TO",
        "TT",
        "TV",
        "VU",
        "AZ",
        "BN",
        "BI",
        "KH",
        "CM",
        "TD",
        "KM",
        "GQ",
        "SZ",
        "GA",
        "GN",
        "KG",
        "LA",
        "MO",
        "MR",
        "MN",
        "NP",
        "RW",
        "TG",
        "UZ",
        "ZW",
        "BJ",
        "MG",
        "MU",
        "MZ",
        "AO",
        "CI",
        "DJ",
        "ZM",
        "CD",
        "CG",
        "IQ",
        "LY",
        "TJ",
        "VE",
        "ET",
        "XK"
      ],
      "disc_number": 1,
      "duration_ms": 145733,
      "explicit": False,
      "external_ids": {
        "isrc": "BRMCA8200166"
      },
      "external_urls": {
        "spotify": "https://open.spotify.com/track/164RfzZqd5LYTsz8ZTfwFV"
      },
      "href": "https://api.spotify.com/v1/tracks/164RfzZqd5LYTsz8ZTfwFV",
      "id": "164RfzZqd5LYTsz8ZTfwFV",
      "is_local": False,
      "name": "Trem Das Cores",
      "popularity": 48,
      "preview_url": "null",
      "track_number": 3,
      "type": "track",
      "uri": "spotify:track:164RfzZqd5LYTsz8ZTfwFV"
    },
    {
      "album": {
        "album_type": "album",
        "artists": [
          {
            "external_urls": {
              "spotify": "https://open.spotify.com/artist/7HGNYPmbDrMkylWqeFCOIQ"
            },
            "href": "https://api.spotify.com/v1/artists/7HGNYPmbDrMkylWqeFCOIQ",
            "id": "7HGNYPmbDrMkylWqeFCOIQ",
            "name": "Caetano Veloso",
            "type": "artist",
            "uri": "spotify:artist:7HGNYPmbDrMkylWqeFCOIQ"
          }
        ],
        "available_markets": [
          "AR",
          "AU",
          "AT",
          "BE",
          "BO",
          "BR",
          "BG",
          "CA",
          "CL",
          "CO",
          "CR",
          "CY",
          "CZ",
          "DK",
          "DO",
          "DE",
          "EC",
          "EE",
          "SV",
          "FI",
          "FR",
          "GR",
          "GT",
          "HN",
          "HK",
          "HU",
          "IS",
          "IE",
          "IT",
          "LV",
          "LT",
          "LU",
          "MY",
          "MT",
          "MX",
          "NL",
          "NZ",
          "NI",
          "NO",
          "PA",
          "PY",
          "PE",
          "PH",
          "PL",
          "PT",
          "SG",
          "SK",
          "ES",
          "SE",
          "CH",
          "TW",
          "TR",
          "UY",
          "US",
          "GB",
          "AD",
          "LI",
          "MC",
          "ID",
          "JP",
          "TH",
          "VN",
          "RO",
          "IL",
          "ZA",
          "SA",
          "AE",
          "BH",
          "QA",
          "OM",
          "KW",
          "EG",
          "MA",
          "DZ",
          "TN",
          "LB",
          "JO",
          "PS",
          "IN",
          "BY",
          "KZ",
          "MD",
          "UA",
          "AL",
          "BA",
          "HR",
          "ME",
          "MK",
          "RS",
          "SI",
          "KR",
          "BD",
          "PK",
          "LK",
          "GH",
          "KE",
          "NG",
          "TZ",
          "UG",
          "AG",
          "AM",
          "BS",
          "BB",
          "BZ",
          "BT",
          "BW",
          "BF",
          "CV",
          "CW",
          "DM",
          "FJ",
          "GM",
          "GE",
          "GD",
          "GW",
          "GY",
          "HT",
          "JM",
          "KI",
          "LS",
          "LR",
          "MW",
          "MV",
          "ML",
          "MH",
          "FM",
          "NA",
          "NR",
          "NE",
          "PW",
          "PG",
          "WS",
          "SM",
          "ST",
          "SN",
          "SC",
          "SL",
          "SB",
          "KN",
          "LC",
          "VC",
          "SR",
          "TL",
          "TO",
          "TT",
          "TV",
          "VU",
          "AZ",
          "BN",
          "BI",
          "KH",
          "CM",
          "TD",
          "KM",
          "GQ",
          "SZ",
          "GA",
          "GN",
          "KG",
          "LA",
          "MO",
          "MR",
          "MN",
          "NP",
          "RW",
          "TG",
          "UZ",
          "ZW",
          "BJ",
          "MG",
          "MU",
          "MZ",
          "AO",
          "CI",
          "DJ",
          "ZM",
          "CD",
          "CG",
          "IQ",
          "LY",
          "TJ",
          "VE",
          "ET",
          "XK"
        ],
        "external_urls": {
          "spotify": "https://open.spotify.com/album/1xAQ6kW7DQZxTghyepHtzm"
        },
        "href": "https://api.spotify.com/v1/albums/1xAQ6kW7DQZxTghyepHtzm",
        "id": "1xAQ6kW7DQZxTghyepHtzm",
        "images": [
          {
            "height": 640,
            "url": "https://i.scdn.co/image/ab67616d0000b273d9e9436112102a62090fbff2",
            "width": 640
          },
          {
            "height": 300,
            "url": "https://i.scdn.co/image/ab67616d00001e02d9e9436112102a62090fbff2",
            "width": 300
          },
          {
            "height": 64,
            "url": "https://i.scdn.co/image/ab67616d00004851d9e9436112102a62090fbff2",
            "width": 64
          }
        ],
        "name": "Cores, Nomes",
        "release_date": "1982-01-01",
        "release_date_precision": "day",
        "total_tracks": 12,
        "type": "album",
        "uri": "spotify:album:1xAQ6kW7DQZxTghyepHtzm"
      },
      "artists": [
        {
          "external_urls": {
            "spotify": "https://open.spotify.com/artist/7HGNYPmbDrMkylWqeFCOIQ"
          },
          "href": "https://api.spotify.com/v1/artists/7HGNYPmbDrMkylWqeFCOIQ",
          "id": "7HGNYPmbDrMkylWqeFCOIQ",
          "name": "Caetano Veloso",
          "type": "artist",
          "uri": "spotify:artist:7HGNYPmbDrMkylWqeFCOIQ"
        }
      ],
      "available_markets": [
        "AR",
        "AU",
        "AT",
        "BE",
        "BO",
        "BR",
        "BG",
        "CA",
        "CL",
        "CO",
        "CR",
        "CY",
        "CZ",
        "DK",
        "DO",
        "DE",
        "EC",
        "EE",
        "SV",
        "FI",
        "FR",
        "GR",
        "GT",
        "HN",
        "HK",
        "HU",
        "IS",
        "IE",
        "IT",
        "LV",
        "LT",
        "LU",
        "MY",
        "MT",
        "MX",
        "NL",
        "NZ",
        "NI",
        "NO",
        "PA",
        "PY",
        "PE",
        "PH",
        "PL",
        "PT",
        "SG",
        "SK",
        "ES",
        "SE",
        "CH",
        "TW",
        "TR",
        "UY",
        "US",
        "GB",
        "AD",
        "LI",
        "MC",
        "ID",
        "JP",
        "TH",
        "VN",
        "RO",
        "IL",
        "ZA",
        "SA",
        "AE",
        "BH",
        "QA",
        "OM",
        "KW",
        "EG",
        "MA",
        "DZ",
        "TN",
        "LB",
        "JO",
        "PS",
        "IN",
        "BY",
        "KZ",
        "MD",
        "UA",
        "AL",
        "BA",
        "HR",
        "ME",
        "MK",
        "RS",
        "SI",
        "KR",
        "BD",
        "PK",
        "LK",
        "GH",
        "KE",
        "NG",
        "TZ",
        "UG",
        "AG",
        "AM",
        "BS",
        "BB",
        "BZ",
        "BT",
        "BW",
        "BF",
        "CV",
        "CW",
        "DM",
        "FJ",
        "GM",
        "GE",
        "GD",
        "GW",
        "GY",
        "HT",
        "JM",
        "KI",
        "LS",
        "LR",
        "MW",
        "MV",
        "ML",
        "MH",
        "FM",
        "NA",
        "NR",
        "NE",
        "PW",
        "PG",
        "WS",
        "SM",
        "ST",
        "SN",
        "SC",
        "SL",
        "SB",
        "KN",
        "LC",
        "VC",
        "SR",
        "TL",
        "TO",
        "TT",
        "TV",
        "VU",
        "AZ",
        "BN",
        "BI",
        "KH",
        "CM",
        "TD",
        "KM",
        "GQ",
        "SZ",
        "GA",
        "GN",
        "KG",
        "LA",
        "MO",
        "MR",
        "MN",
        "NP",
        "RW",
        "TG",
        "UZ",
        "ZW",
        "BJ",
        "MG",
        "MU",
        "MZ",
        "AO",
        "CI",
        "DJ",
        "ZM",
        "CD",
        "CG",
        "IQ",
        "LY",
        "TJ",
        "VE",
        "ET",
        "XK"
      ],
      "disc_number": 1,
      "duration_ms": 139493,
      "explicit": False,
      "external_ids": {
        "isrc": "BRMCA8200167"
      },
      "external_urls": {
        "spotify": "https://open.spotify.com/track/5bjZ9DtsiaUFRj3NPR6D0w"
      },
      "href": "https://api.spotify.com/v1/tracks/5bjZ9DtsiaUFRj3NPR6D0w",
      "id": "5bjZ9DtsiaUFRj3NPR6D0w",
      "is_local": False,
      "name": "Sete Mil Vezes",
      "popularity": 25,
      "preview_url": "null",
      "track_number": 4,
      "type": "track",
      "uri": "spotify:track:5bjZ9DtsiaUFRj3NPR6D0w"
    },
    {
      "album": {
        "album_type": "album",
        "artists": [
          {
            "external_urls": {
              "spotify": "https://open.spotify.com/artist/7HGNYPmbDrMkylWqeFCOIQ"
            },
            "href": "https://api.spotify.com/v1/artists/7HGNYPmbDrMkylWqeFCOIQ",
            "id": "7HGNYPmbDrMkylWqeFCOIQ",
            "name": "Caetano Veloso",
            "type": "artist",
            "uri": "spotify:artist:7HGNYPmbDrMkylWqeFCOIQ"
          }
        ],
        "available_markets": [
          "AR",
          "AU",
          "AT",
          "BE",
          "BO",
          "BR",
          "BG",
          "CA",
          "CL",
          "CO",
          "CR",
          "CY",
          "CZ",
          "DK",
          "DO",
          "DE",
          "EC",
          "EE",
          "SV",
          "FI",
          "FR",
          "GR",
          "GT",
          "HN",
          "HK",
          "HU",
          "IS",
          "IE",
          "IT",
          "LV",
          "LT",
          "LU",
          "MY",
          "MT",
          "MX",
          "NL",
          "NZ",
          "NI",
          "NO",
          "PA",
          "PY",
          "PE",
          "PH",
          "PL",
          "PT",
          "SG",
          "SK",
          "ES",
          "SE",
          "CH",
          "TW",
          "TR",
          "UY",
          "US",
          "GB",
          "AD",
          "LI",
          "MC",
          "ID",
          "JP",
          "TH",
          "VN",
          "RO",
          "IL",
          "ZA",
          "SA",
          "AE",
          "BH",
          "QA",
          "OM",
          "KW",
          "EG",
          "MA",
          "DZ",
          "TN",
          "LB",
          "JO",
          "PS",
          "IN",
          "BY",
          "KZ",
          "MD",
          "UA",
          "AL",
          "BA",
          "HR",
          "ME",
          "MK",
          "RS",
          "SI",
          "KR",
          "BD",
          "PK",
          "LK",
          "GH",
          "KE",
          "NG",
          "TZ",
          "UG",
          "AG",
          "AM",
          "BS",
          "BB",
          "BZ",
          "BT",
          "BW",
          "BF",
          "CV",
          "CW",
          "DM",
          "FJ",
          "GM",
          "GE",
          "GD",
          "GW",
          "GY",
          "HT",
          "JM",
          "KI",
          "LS",
          "LR",
          "MW",
          "MV",
          "ML",
          "MH",
          "FM",
          "NA",
          "NR",
          "NE",
          "PW",
          "PG",
          "WS",
          "SM",
          "ST",
          "SN",
          "SC",
          "SL",
          "SB",
          "KN",
          "LC",
          "VC",
          "SR",
          "TL",
          "TO",
          "TT",
          "TV",
          "VU",
          "AZ",
          "BN",
          "BI",
          "KH",
          "CM",
          "TD",
          "KM",
          "GQ",
          "SZ",
          "GA",
          "GN",
          "KG",
          "LA",
          "MO",
          "MR",
          "MN",
          "NP",
          "RW",
          "TG",
          "UZ",
          "ZW",
          "BJ",
          "MG",
          "MU",
          "MZ",
          "AO",
          "CI",
          "DJ",
          "ZM",
          "CD",
          "CG",
          "IQ",
          "LY",
          "TJ",
          "VE",
          "ET",
          "XK"
        ],
        "external_urls": {
          "spotify": "https://open.spotify.com/album/1xAQ6kW7DQZxTghyepHtzm"
        },
        "href": "https://api.spotify.com/v1/albums/1xAQ6kW7DQZxTghyepHtzm",
        "id": "1xAQ6kW7DQZxTghyepHtzm",
        "images": [
          {
            "height": 640,
            "url": "https://i.scdn.co/image/ab67616d0000b273d9e9436112102a62090fbff2",
            "width": 640
          },
          {
            "height": 300,
            "url": "https://i.scdn.co/image/ab67616d00001e02d9e9436112102a62090fbff2",
            "width": 300
          },
          {
            "height": 64,
            "url": "https://i.scdn.co/image/ab67616d00004851d9e9436112102a62090fbff2",
            "width": 64
          }
        ],
        "name": "Cores, Nomes",
        "release_date": "1982-01-01",
        "release_date_precision": "day",
        "total_tracks": 12,
        "type": "album",
        "uri": "spotify:album:1xAQ6kW7DQZxTghyepHtzm"
      },
      "artists": [
        {
          "external_urls": {
            "spotify": "https://open.spotify.com/artist/7HGNYPmbDrMkylWqeFCOIQ"
          },
          "href": "https://api.spotify.com/v1/artists/7HGNYPmbDrMkylWqeFCOIQ",
          "id": "7HGNYPmbDrMkylWqeFCOIQ",
          "name": "Caetano Veloso",
          "type": "artist",
          "uri": "spotify:artist:7HGNYPmbDrMkylWqeFCOIQ"
        }
      ],
      "available_markets": [
        "AR",
        "AU",
        "AT",
        "BE",
        "BO",
        "BR",
        "BG",
        "CA",
        "CL",
        "CO",
        "CR",
        "CY",
        "CZ",
        "DK",
        "DO",
        "DE",
        "EC",
        "EE",
        "SV",
        "FI",
        "FR",
        "GR",
        "GT",
        "HN",
        "HK",
        "HU",
        "IS",
        "IE",
        "IT",
        "LV",
        "LT",
        "LU",
        "MY",
        "MT",
        "MX",
        "NL",
        "NZ",
        "NI",
        "NO",
        "PA",
        "PY",
        "PE",
        "PH",
        "PL",
        "PT",
        "SG",
        "SK",
        "ES",
        "SE",
        "CH",
        "TW",
        "TR",
        "UY",
        "US",
        "GB",
        "AD",
        "LI",
        "MC",
        "ID",
        "JP",
        "TH",
        "VN",
        "RO",
        "IL",
        "ZA",
        "SA",
        "AE",
        "BH",
        "QA",
        "OM",
        "KW",
        "EG",
        "MA",
        "DZ",
        "TN",
        "LB",
        "JO",
        "PS",
        "IN",
        "BY",
        "KZ",
        "MD",
        "UA",
        "AL",
        "BA",
        "HR",
        "ME",
        "MK",
        "RS",
        "SI",
        "KR",
        "BD",
        "PK",
        "LK",
        "GH",
        "KE",
        "NG",
        "TZ",
        "UG",
        "AG",
        "AM",
        "BS",
        "BB",
        "BZ",
        "BT",
        "BW",
        "BF",
        "CV",
        "CW",
        "DM",
        "FJ",
        "GM",
        "GE",
        "GD",
        "GW",
        "GY",
        "HT",
        "JM",
        "KI",
        "LS",
        "LR",
        "MW",
        "MV",
        "ML",
        "MH",
        "FM",
        "NA",
        "NR",
        "NE",
        "PW",
        "PG",
        "WS",
        "SM",
        "ST",
        "SN",
        "SC",
        "SL",
        "SB",
        "KN",
        "LC",
        "VC",
        "SR",
        "TL",
        "TO",
        "TT",
        "TV",
        "VU",
        "AZ",
        "BN",
        "BI",
        "KH",
        "CM",
        "TD",
        "KM",
        "GQ",
        "SZ",
        "GA",
        "GN",
        "KG",
        "LA",
        "MO",
        "MR",
        "MN",
        "NP",
        "RW",
        "TG",
        "UZ",
        "ZW",
        "BJ",
        "MG",
        "MU",
        "MZ",
        "AO",
        "CI",
        "DJ",
        "ZM",
        "CD",
        "CG",
        "IQ",
        "LY",
        "TJ",
        "VE",
        "ET",
        "XK"
      ],
      "disc_number": 1,
      "duration_ms": 155480,
      "explicit": False,
      "external_ids": {
        "isrc": "BRMCA8200168"
      },
      "external_urls": {
        "spotify": "https://open.spotify.com/track/4m692gebzDAVR4uG5kaGL2"
      },
      "href": "https://api.spotify.com/v1/tracks/4m692gebzDAVR4uG5kaGL2",
      "id": "4m692gebzDAVR4uG5kaGL2",
      "is_local": False,
      "name": "Coqueiro De Itapoã",
      "popularity": 26,
      "preview_url": "null",
      "track_number": 5,
      "type": "track",
      "uri": "spotify:track:4m692gebzDAVR4uG5kaGL2"
    },
    {
      "album": {
        "album_type": "album",
        "artists": [
          {
            "external_urls": {
              "spotify": "https://open.spotify.com/artist/7HGNYPmbDrMkylWqeFCOIQ"
            },
            "href": "https://api.spotify.com/v1/artists/7HGNYPmbDrMkylWqeFCOIQ",
            "id": "7HGNYPmbDrMkylWqeFCOIQ",
            "name": "Caetano Veloso",
            "type": "artist",
            "uri": "spotify:artist:7HGNYPmbDrMkylWqeFCOIQ"
          }
        ],
        "available_markets": [
          "AR",
          "AU",
          "AT",
          "BE",
          "BO",
          "BR",
          "BG",
          "CA",
          "CL",
          "CO",
          "CR",
          "CY",
          "CZ",
          "DK",
          "DO",
          "DE",
          "EC",
          "EE",
          "SV",
          "FI",
          "FR",
          "GR",
          "GT",
          "HN",
          "HK",
          "HU",
          "IS",
          "IE",
          "IT",
          "LV",
          "LT",
          "LU",
          "MY",
          "MT",
          "MX",
          "NL",
          "NZ",
          "NI",
          "NO",
          "PA",
          "PY",
          "PE",
          "PH",
          "PL",
          "PT",
          "SG",
          "SK",
          "ES",
          "SE",
          "CH",
          "TW",
          "TR",
          "UY",
          "US",
          "GB",
          "AD",
          "LI",
          "MC",
          "ID",
          "JP",
          "TH",
          "VN",
          "RO",
          "IL",
          "ZA",
          "SA",
          "AE",
          "BH",
          "QA",
          "OM",
          "KW",
          "EG",
          "MA",
          "DZ",
          "TN",
          "LB",
          "JO",
          "PS",
          "IN",
          "BY",
          "KZ",
          "MD",
          "UA",
          "AL",
          "BA",
          "HR",
          "ME",
          "MK",
          "RS",
          "SI",
          "KR",
          "BD",
          "PK",
          "LK",
          "GH",
          "KE",
          "NG",
          "TZ",
          "UG",
          "AG",
          "AM",
          "BS",
          "BB",
          "BZ",
          "BT",
          "BW",
          "BF",
          "CV",
          "CW",
          "DM",
          "FJ",
          "GM",
          "GE",
          "GD",
          "GW",
          "GY",
          "HT",
          "JM",
          "KI",
          "LS",
          "LR",
          "MW",
          "MV",
          "ML",
          "MH",
          "FM",
          "NA",
          "NR",
          "NE",
          "PW",
          "PG",
          "WS",
          "SM",
          "ST",
          "SN",
          "SC",
          "SL",
          "SB",
          "KN",
          "LC",
          "VC",
          "SR",
          "TL",
          "TO",
          "TT",
          "TV",
          "VU",
          "AZ",
          "BN",
          "BI",
          "KH",
          "CM",
          "TD",
          "KM",
          "GQ",
          "SZ",
          "GA",
          "GN",
          "KG",
          "LA",
          "MO",
          "MR",
          "MN",
          "NP",
          "RW",
          "TG",
          "UZ",
          "ZW",
          "BJ",
          "MG",
          "MU",
          "MZ",
          "AO",
          "CI",
          "DJ",
          "ZM",
          "CD",
          "CG",
          "IQ",
          "LY",
          "TJ",
          "VE",
          "ET",
          "XK"
        ],
        "external_urls": {
          "spotify": "https://open.spotify.com/album/1xAQ6kW7DQZxTghyepHtzm"
        },
        "href": "https://api.spotify.com/v1/albums/1xAQ6kW7DQZxTghyepHtzm",
        "id": "1xAQ6kW7DQZxTghyepHtzm",
        "images": [
          {
            "height": 640,
            "url": "https://i.scdn.co/image/ab67616d0000b273d9e9436112102a62090fbff2",
            "width": 640
          },
          {
            "height": 300,
            "url": "https://i.scdn.co/image/ab67616d00001e02d9e9436112102a62090fbff2",
            "width": 300
          },
          {
            "height": 64,
            "url": "https://i.scdn.co/image/ab67616d00004851d9e9436112102a62090fbff2",
            "width": 64
          }
        ],
        "name": "Cores, Nomes",
        "release_date": "1982-01-01",
        "release_date_precision": "day",
        "total_tracks": 12,
        "type": "album",
        "uri": "spotify:album:1xAQ6kW7DQZxTghyepHtzm"
      },
      "artists": [
        {
          "external_urls": {
            "spotify": "https://open.spotify.com/artist/7HGNYPmbDrMkylWqeFCOIQ"
          },
          "href": "https://api.spotify.com/v1/artists/7HGNYPmbDrMkylWqeFCOIQ",
          "id": "7HGNYPmbDrMkylWqeFCOIQ",
          "name": "Caetano Veloso",
          "type": "artist",
          "uri": "spotify:artist:7HGNYPmbDrMkylWqeFCOIQ"
        }
      ],
      "available_markets": [
        "AR",
        "AU",
        "AT",
        "BE",
        "BO",
        "BR",
        "BG",
        "CA",
        "CL",
        "CO",
        "CR",
        "CY",
        "CZ",
        "DK",
        "DO",
        "DE",
        "EC",
        "EE",
        "SV",
        "FI",
        "FR",
        "GR",
        "GT",
        "HN",
        "HK",
        "HU",
        "IS",
        "IE",
        "IT",
        "LV",
        "LT",
        "LU",
        "MY",
        "MT",
        "MX",
        "NL",
        "NZ",
        "NI",
        "NO",
        "PA",
        "PY",
        "PE",
        "PH",
        "PL",
        "PT",
        "SG",
        "SK",
        "ES",
        "SE",
        "CH",
        "TW",
        "TR",
        "UY",
        "US",
        "GB",
        "AD",
        "LI",
        "MC",
        "ID",
        "JP",
        "TH",
        "VN",
        "RO",
        "IL",
        "ZA",
        "SA",
        "AE",
        "BH",
        "QA",
        "OM",
        "KW",
        "EG",
        "MA",
        "DZ",
        "TN",
        "LB",
        "JO",
        "PS",
        "IN",
        "BY",
        "KZ",
        "MD",
        "UA",
        "AL",
        "BA",
        "HR",
        "ME",
        "MK",
        "RS",
        "SI",
        "KR",
        "BD",
        "PK",
        "LK",
        "GH",
        "KE",
        "NG",
        "TZ",
        "UG",
        "AG",
        "AM",
        "BS",
        "BB",
        "BZ",
        "BT",
        "BW",
        "BF",
        "CV",
        "CW",
        "DM",
        "FJ",
        "GM",
        "GE",
        "GD",
        "GW",
        "GY",
        "HT",
        "JM",
        "KI",
        "LS",
        "LR",
        "MW",
        "MV",
        "ML",
        "MH",
        "FM",
        "NA",
        "NR",
        "NE",
        "PW",
        "PG",
        "WS",
        "SM",
        "ST",
        "SN",
        "SC",
        "SL",
        "SB",
        "KN",
        "LC",
        "VC",
        "SR",
        "TL",
        "TO",
        "TT",
        "TV",
        "VU",
        "AZ",
        "BN",
        "BI",
        "KH",
        "CM",
        "TD",
        "KM",
        "GQ",
        "SZ",
        "GA",
        "GN",
        "KG",
        "LA",
        "MO",
        "MR",
        "MN",
        "NP",
        "RW",
        "TG",
        "UZ",
        "ZW",
        "BJ",
        "MG",
        "MU",
        "MZ",
        "AO",
        "CI",
        "DJ",
        "ZM",
        "CD",
        "CG",
        "IQ",
        "LY",
        "TJ",
        "VE",
        "ET",
        "XK"
      ],
      "disc_number": 1,
      "duration_ms": 182226,
      "explicit": False,
      "external_ids": {
        "isrc": "BRMCA8200169"
      },
      "external_urls": {
        "spotify": "https://open.spotify.com/track/1kQoWGnB64fQcjg8TOHT8g"
      },
      "href": "https://api.spotify.com/v1/tracks/1kQoWGnB64fQcjg8TOHT8g",
      "id": "1kQoWGnB64fQcjg8TOHT8g",
      "is_local": False,
      "name": "Um Canto De Afoxé Para O Bloco Do Ilê",
      "popularity": 33,
      "preview_url": "null",
      "track_number": 6,
      "type": "track",
      "uri": "spotify:track:1kQoWGnB64fQcjg8TOHT8g"
    },
    {
      "album": {
        "album_type": "album",
        "artists": [
          {
            "external_urls": {
              "spotify": "https://open.spotify.com/artist/7HGNYPmbDrMkylWqeFCOIQ"
            },
            "href": "https://api.spotify.com/v1/artists/7HGNYPmbDrMkylWqeFCOIQ",
            "id": "7HGNYPmbDrMkylWqeFCOIQ",
            "name": "Caetano Veloso",
            "type": "artist",
            "uri": "spotify:artist:7HGNYPmbDrMkylWqeFCOIQ"
          }
        ],
        "available_markets": [
          "AR",
          "AU",
          "AT",
          "BE",
          "BO",
          "BR",
          "BG",
          "CA",
          "CL",
          "CO",
          "CR",
          "CY",
          "CZ",
          "DK",
          "DO",
          "DE",
          "EC",
          "EE",
          "SV",
          "FI",
          "FR",
          "GR",
          "GT",
          "HN",
          "HK",
          "HU",
          "IS",
          "IE",
          "IT",
          "LV",
          "LT",
          "LU",
          "MY",
          "MT",
          "MX",
          "NL",
          "NZ",
          "NI",
          "NO",
          "PA",
          "PY",
          "PE",
          "PH",
          "PL",
          "PT",
          "SG",
          "SK",
          "ES",
          "SE",
          "CH",
          "TW",
          "TR",
          "UY",
          "US",
          "GB",
          "AD",
          "LI",
          "MC",
          "ID",
          "JP",
          "TH",
          "VN",
          "RO",
          "IL",
          "ZA",
          "SA",
          "AE",
          "BH",
          "QA",
          "OM",
          "KW",
          "EG",
          "MA",
          "DZ",
          "TN",
          "LB",
          "JO",
          "PS",
          "IN",
          "BY",
          "KZ",
          "MD",
          "UA",
          "AL",
          "BA",
          "HR",
          "ME",
          "MK",
          "RS",
          "SI",
          "KR",
          "BD",
          "PK",
          "LK",
          "GH",
          "KE",
          "NG",
          "TZ",
          "UG",
          "AG",
          "AM",
          "BS",
          "BB",
          "BZ",
          "BT",
          "BW",
          "BF",
          "CV",
          "CW",
          "DM",
          "FJ",
          "GM",
          "GE",
          "GD",
          "GW",
          "GY",
          "HT",
          "JM",
          "KI",
          "LS",
          "LR",
          "MW",
          "MV",
          "ML",
          "MH",
          "FM",
          "NA",
          "NR",
          "NE",
          "PW",
          "PG",
          "WS",
          "SM",
          "ST",
          "SN",
          "SC",
          "SL",
          "SB",
          "KN",
          "LC",
          "VC",
          "SR",
          "TL",
          "TO",
          "TT",
          "TV",
          "VU",
          "AZ",
          "BN",
          "BI",
          "KH",
          "CM",
          "TD",
          "KM",
          "GQ",
          "SZ",
          "GA",
          "GN",
          "KG",
          "LA",
          "MO",
          "MR",
          "MN",
          "NP",
          "RW",
          "TG",
          "UZ",
          "ZW",
          "BJ",
          "MG",
          "MU",
          "MZ",
          "AO",
          "CI",
          "DJ",
          "ZM",
          "CD",
          "CG",
          "IQ",
          "LY",
          "TJ",
          "VE",
          "ET",
          "XK"
        ],
        "external_urls": {
          "spotify": "https://open.spotify.com/album/1xAQ6kW7DQZxTghyepHtzm"
        },
        "href": "https://api.spotify.com/v1/albums/1xAQ6kW7DQZxTghyepHtzm",
        "id": "1xAQ6kW7DQZxTghyepHtzm",
        "images": [
          {
            "height": 640,
            "url": "https://i.scdn.co/image/ab67616d0000b273d9e9436112102a62090fbff2",
            "width": 640
          },
          {
            "height": 300,
            "url": "https://i.scdn.co/image/ab67616d00001e02d9e9436112102a62090fbff2",
            "width": 300
          },
          {
            "height": 64,
            "url": "https://i.scdn.co/image/ab67616d00004851d9e9436112102a62090fbff2",
            "width": 64
          }
        ],
        "name": "Cores, Nomes",
        "release_date": "1982-01-01",
        "release_date_precision": "day",
        "total_tracks": 12,
        "type": "album",
        "uri": "spotify:album:1xAQ6kW7DQZxTghyepHtzm"
      },
      "artists": [
        {
          "external_urls": {
            "spotify": "https://open.spotify.com/artist/7HGNYPmbDrMkylWqeFCOIQ"
          },
          "href": "https://api.spotify.com/v1/artists/7HGNYPmbDrMkylWqeFCOIQ",
          "id": "7HGNYPmbDrMkylWqeFCOIQ",
          "name": "Caetano Veloso",
          "type": "artist",
          "uri": "spotify:artist:7HGNYPmbDrMkylWqeFCOIQ"
        }
      ],
      "available_markets": [
        "AR",
        "AU",
        "AT",
        "BE",
        "BO",
        "BR",
        "BG",
        "CA",
        "CL",
        "CO",
        "CR",
        "CY",
        "CZ",
        "DK",
        "DO",
        "DE",
        "EC",
        "EE",
        "SV",
        "FI",
        "FR",
        "GR",
        "GT",
        "HN",
        "HK",
        "HU",
        "IS",
        "IE",
        "IT",
        "LV",
        "LT",
        "LU",
        "MY",
        "MT",
        "MX",
        "NL",
        "NZ",
        "NI",
        "NO",
        "PA",
        "PY",
        "PE",
        "PH",
        "PL",
        "PT",
        "SG",
        "SK",
        "ES",
        "SE",
        "CH",
        "TW",
        "TR",
        "UY",
        "US",
        "GB",
        "AD",
        "LI",
        "MC",
        "ID",
        "JP",
        "TH",
        "VN",
        "RO",
        "IL",
        "ZA",
        "SA",
        "AE",
        "BH",
        "QA",
        "OM",
        "KW",
        "EG",
        "MA",
        "DZ",
        "TN",
        "LB",
        "JO",
        "PS",
        "IN",
        "BY",
        "KZ",
        "MD",
        "UA",
        "AL",
        "BA",
        "HR",
        "ME",
        "MK",
        "RS",
        "SI",
        "KR",
        "BD",
        "PK",
        "LK",
        "GH",
        "KE",
        "NG",
        "TZ",
        "UG",
        "AG",
        "AM",
        "BS",
        "BB",
        "BZ",
        "BT",
        "BW",
        "BF",
        "CV",
        "CW",
        "DM",
        "FJ",
        "GM",
        "GE",
        "GD",
        "GW",
        "GY",
        "HT",
        "JM",
        "KI",
        "LS",
        "LR",
        "MW",
        "MV",
        "ML",
        "MH",
        "FM",
        "NA",
        "NR",
        "NE",
        "PW",
        "PG",
        "WS",
        "SM",
        "ST",
        "SN",
        "SC",
        "SL",
        "SB",
        "KN",
        "LC",
        "VC",
        "SR",
        "TL",
        "TO",
        "TT",
        "TV",
        "VU",
        "AZ",
        "BN",
        "BI",
        "KH",
        "CM",
        "TD",
        "KM",
        "GQ",
        "SZ",
        "GA",
        "GN",
        "KG",
        "LA",
        "MO",
        "MR",
        "MN",
        "NP",
        "RW",
        "TG",
        "UZ",
        "ZW",
        "BJ",
        "MG",
        "MU",
        "MZ",
        "AO",
        "CI",
        "DJ",
        "ZM",
        "CD",
        "CG",
        "IQ",
        "LY",
        "TJ",
        "VE",
        "ET",
        "XK"
      ],
      "disc_number": 1,
      "duration_ms": 223466,
      "explicit": False,
      "external_ids": {
        "isrc": "BRMCA8200175"
      },
      "external_urls": {
        "spotify": "https://open.spotify.com/track/3kuAEbv5CUREb4010lHCdw"
      },
      "href": "https://api.spotify.com/v1/tracks/3kuAEbv5CUREb4010lHCdw",
      "id": "3kuAEbv5CUREb4010lHCdw",
      "is_local": False,
      "name": "Cavaleiro De Jorge",
      "popularity": 24,
      "preview_url": "null",
      "track_number": 7,
      "type": "track",
      "uri": "spotify:track:3kuAEbv5CUREb4010lHCdw"
    },
    {
      "album": {
        "album_type": "album",
        "artists": [
          {
            "external_urls": {
              "spotify": "https://open.spotify.com/artist/7HGNYPmbDrMkylWqeFCOIQ"
            },
            "href": "https://api.spotify.com/v1/artists/7HGNYPmbDrMkylWqeFCOIQ",
            "id": "7HGNYPmbDrMkylWqeFCOIQ",
            "name": "Caetano Veloso",
            "type": "artist",
            "uri": "spotify:artist:7HGNYPmbDrMkylWqeFCOIQ"
          }
        ],
        "available_markets": [
          "AR",
          "AU",
          "AT",
          "BE",
          "BO",
          "BR",
          "BG",
          "CA",
          "CL",
          "CO",
          "CR",
          "CY",
          "CZ",
          "DK",
          "DO",
          "DE",
          "EC",
          "EE",
          "SV",
          "FI",
          "FR",
          "GR",
          "GT",
          "HN",
          "HK",
          "HU",
          "IS",
          "IE",
          "IT",
          "LV",
          "LT",
          "LU",
          "MY",
          "MT",
          "MX",
          "NL",
          "NZ",
          "NI",
          "NO",
          "PA",
          "PY",
          "PE",
          "PH",
          "PL",
          "PT",
          "SG",
          "SK",
          "ES",
          "SE",
          "CH",
          "TW",
          "TR",
          "UY",
          "US",
          "GB",
          "AD",
          "LI",
          "MC",
          "ID",
          "JP",
          "TH",
          "VN",
          "RO",
          "IL",
          "ZA",
          "SA",
          "AE",
          "BH",
          "QA",
          "OM",
          "KW",
          "EG",
          "MA",
          "DZ",
          "TN",
          "LB",
          "JO",
          "PS",
          "IN",
          "BY",
          "KZ",
          "MD",
          "UA",
          "AL",
          "BA",
          "HR",
          "ME",
          "MK",
          "RS",
          "SI",
          "KR",
          "BD",
          "PK",
          "LK",
          "GH",
          "KE",
          "NG",
          "TZ",
          "UG",
          "AG",
          "AM",
          "BS",
          "BB",
          "BZ",
          "BT",
          "BW",
          "BF",
          "CV",
          "CW",
          "DM",
          "FJ",
          "GM",
          "GE",
          "GD",
          "GW",
          "GY",
          "HT",
          "JM",
          "KI",
          "LS",
          "LR",
          "MW",
          "MV",
          "ML",
          "MH",
          "FM",
          "NA",
          "NR",
          "NE",
          "PW",
          "PG",
          "WS",
          "SM",
          "ST",
          "SN",
          "SC",
          "SL",
          "SB",
          "KN",
          "LC",
          "VC",
          "SR",
          "TL",
          "TO",
          "TT",
          "TV",
          "VU",
          "AZ",
          "BN",
          "BI",
          "KH",
          "CM",
          "TD",
          "KM",
          "GQ",
          "SZ",
          "GA",
          "GN",
          "KG",
          "LA",
          "MO",
          "MR",
          "MN",
          "NP",
          "RW",
          "TG",
          "UZ",
          "ZW",
          "BJ",
          "MG",
          "MU",
          "MZ",
          "AO",
          "CI",
          "DJ",
          "ZM",
          "CD",
          "CG",
          "IQ",
          "LY",
          "TJ",
          "VE",
          "ET",
          "XK"
        ],
        "external_urls": {
          "spotify": "https://open.spotify.com/album/1xAQ6kW7DQZxTghyepHtzm"
        },
        "href": "https://api.spotify.com/v1/albums/1xAQ6kW7DQZxTghyepHtzm",
        "id": "1xAQ6kW7DQZxTghyepHtzm",
        "images": [
          {
            "height": 640,
            "url": "https://i.scdn.co/image/ab67616d0000b273d9e9436112102a62090fbff2",
            "width": 640
          },
          {
            "height": 300,
            "url": "https://i.scdn.co/image/ab67616d00001e02d9e9436112102a62090fbff2",
            "width": 300
          },
          {
            "height": 64,
            "url": "https://i.scdn.co/image/ab67616d00004851d9e9436112102a62090fbff2",
            "width": 64
          }
        ],
        "name": "Cores, Nomes",
        "release_date": "1982-01-01",
        "release_date_precision": "day",
        "total_tracks": 12,
        "type": "album",
        "uri": "spotify:album:1xAQ6kW7DQZxTghyepHtzm"
      },
      "artists": [
        {
          "external_urls": {
            "spotify": "https://open.spotify.com/artist/7HGNYPmbDrMkylWqeFCOIQ"
          },
          "href": "https://api.spotify.com/v1/artists/7HGNYPmbDrMkylWqeFCOIQ",
          "id": "7HGNYPmbDrMkylWqeFCOIQ",
          "name": "Caetano Veloso",
          "type": "artist",
          "uri": "spotify:artist:7HGNYPmbDrMkylWqeFCOIQ"
        },
        {
          "external_urls": {
            "spotify": "https://open.spotify.com/artist/5rrmaoBXZ7Jcs4Qb77j0YA"
          },
          "href": "https://api.spotify.com/v1/artists/5rrmaoBXZ7Jcs4Qb77j0YA",
          "id": "5rrmaoBXZ7Jcs4Qb77j0YA",
          "name": "Djavan",
          "type": "artist",
          "uri": "spotify:artist:5rrmaoBXZ7Jcs4Qb77j0YA"
        }
      ],
      "available_markets": [
        "AR",
        "AU",
        "AT",
        "BE",
        "BO",
        "BR",
        "BG",
        "CA",
        "CL",
        "CO",
        "CR",
        "CY",
        "CZ",
        "DK",
        "DO",
        "DE",
        "EC",
        "EE",
        "SV",
        "FI",
        "FR",
        "GR",
        "GT",
        "HN",
        "HK",
        "HU",
        "IS",
        "IE",
        "IT",
        "LV",
        "LT",
        "LU",
        "MY",
        "MT",
        "MX",
        "NL",
        "NZ",
        "NI",
        "NO",
        "PA",
        "PY",
        "PE",
        "PH",
        "PL",
        "PT",
        "SG",
        "SK",
        "ES",
        "SE",
        "CH",
        "TW",
        "TR",
        "UY",
        "US",
        "GB",
        "AD",
        "LI",
        "MC",
        "ID",
        "JP",
        "TH",
        "VN",
        "RO",
        "IL",
        "ZA",
        "SA",
        "AE",
        "BH",
        "QA",
        "OM",
        "KW",
        "EG",
        "MA",
        "DZ",
        "TN",
        "LB",
        "JO",
        "PS",
        "IN",
        "BY",
        "KZ",
        "MD",
        "UA",
        "AL",
        "BA",
        "HR",
        "ME",
        "MK",
        "RS",
        "SI",
        "KR",
        "BD",
        "PK",
        "LK",
        "GH",
        "KE",
        "NG",
        "TZ",
        "UG",
        "AG",
        "AM",
        "BS",
        "BB",
        "BZ",
        "BT",
        "BW",
        "BF",
        "CV",
        "CW",
        "DM",
        "FJ",
        "GM",
        "GE",
        "GD",
        "GW",
        "GY",
        "HT",
        "JM",
        "KI",
        "LS",
        "LR",
        "MW",
        "MV",
        "ML",
        "MH",
        "FM",
        "NA",
        "NR",
        "NE",
        "PW",
        "PG",
        "WS",
        "SM",
        "ST",
        "SN",
        "SC",
        "SL",
        "SB",
        "KN",
        "LC",
        "VC",
        "SR",
        "TL",
        "TO",
        "TT",
        "TV",
        "VU",
        "AZ",
        "BN",
        "BI",
        "KH",
        "CM",
        "TD",
        "KM",
        "GQ",
        "SZ",
        "GA",
        "GN",
        "KG",
        "LA",
        "MO",
        "MR",
        "MN",
        "NP",
        "RW",
        "TG",
        "UZ",
        "ZW",
        "BJ",
        "MG",
        "MU",
        "MZ",
        "AO",
        "CI",
        "DJ",
        "ZM",
        "CD",
        "CG",
        "IQ",
        "LY",
        "TJ",
        "VE",
        "ET",
        "XK"
      ],
      "disc_number": 1,
      "duration_ms": 259693,
      "explicit": False,
      "external_ids": {
        "isrc": "BRMCA8200170"
      },
      "external_urls": {
        "spotify": "https://open.spotify.com/track/6ULfijAfhmca5k2fmzTS37"
      },
      "href": "https://api.spotify.com/v1/tracks/6ULfijAfhmca5k2fmzTS37",
      "id": "6ULfijAfhmca5k2fmzTS37",
      "is_local": False,
      "name": "Sina",
      "popularity": 35,
      "preview_url": "null",
      "track_number": 8,
      "type": "track",
      "uri": "spotify:track:6ULfijAfhmca5k2fmzTS37"
    },
    {
      "album": {
        "album_type": "album",
        "artists": [
          {
            "external_urls": {
              "spotify": "https://open.spotify.com/artist/7HGNYPmbDrMkylWqeFCOIQ"
            },
            "href": "https://api.spotify.com/v1/artists/7HGNYPmbDrMkylWqeFCOIQ",
            "id": "7HGNYPmbDrMkylWqeFCOIQ",
            "name": "Caetano Veloso",
            "type": "artist",
            "uri": "spotify:artist:7HGNYPmbDrMkylWqeFCOIQ"
          }
        ],
        "available_markets": [
          "AR",
          "AU",
          "AT",
          "BE",
          "BO",
          "BR",
          "BG",
          "CA",
          "CL",
          "CO",
          "CR",
          "CY",
          "CZ",
          "DK",
          "DO",
          "DE",
          "EC",
          "EE",
          "SV",
          "FI",
          "FR",
          "GR",
          "GT",
          "HN",
          "HK",
          "HU",
          "IS",
          "IE",
          "IT",
          "LV",
          "LT",
          "LU",
          "MY",
          "MT",
          "MX",
          "NL",
          "NZ",
          "NI",
          "NO",
          "PA",
          "PY",
          "PE",
          "PH",
          "PL",
          "PT",
          "SG",
          "SK",
          "ES",
          "SE",
          "CH",
          "TW",
          "TR",
          "UY",
          "US",
          "GB",
          "AD",
          "LI",
          "MC",
          "ID",
          "JP",
          "TH",
          "VN",
          "RO",
          "IL",
          "ZA",
          "SA",
          "AE",
          "BH",
          "QA",
          "OM",
          "KW",
          "EG",
          "MA",
          "DZ",
          "TN",
          "LB",
          "JO",
          "PS",
          "IN",
          "BY",
          "KZ",
          "MD",
          "UA",
          "AL",
          "BA",
          "HR",
          "ME",
          "MK",
          "RS",
          "SI",
          "KR",
          "BD",
          "PK",
          "LK",
          "GH",
          "KE",
          "NG",
          "TZ",
          "UG",
          "AG",
          "AM",
          "BS",
          "BB",
          "BZ",
          "BT",
          "BW",
          "BF",
          "CV",
          "CW",
          "DM",
          "FJ",
          "GM",
          "GE",
          "GD",
          "GW",
          "GY",
          "HT",
          "JM",
          "KI",
          "LS",
          "LR",
          "MW",
          "MV",
          "ML",
          "MH",
          "FM",
          "NA",
          "NR",
          "NE",
          "PW",
          "PG",
          "WS",
          "SM",
          "ST",
          "SN",
          "SC",
          "SL",
          "SB",
          "KN",
          "LC",
          "VC",
          "SR",
          "TL",
          "TO",
          "TT",
          "TV",
          "VU",
          "AZ",
          "BN",
          "BI",
          "KH",
          "CM",
          "TD",
          "KM",
          "GQ",
          "SZ",
          "GA",
          "GN",
          "KG",
          "LA",
          "MO",
          "MR",
          "MN",
          "NP",
          "RW",
          "TG",
          "UZ",
          "ZW",
          "BJ",
          "MG",
          "MU",
          "MZ",
          "AO",
          "CI",
          "DJ",
          "ZM",
          "CD",
          "CG",
          "IQ",
          "LY",
          "TJ",
          "VE",
          "ET",
          "XK"
        ],
        "external_urls": {
          "spotify": "https://open.spotify.com/album/1xAQ6kW7DQZxTghyepHtzm"
        },
        "href": "https://api.spotify.com/v1/albums/1xAQ6kW7DQZxTghyepHtzm",
        "id": "1xAQ6kW7DQZxTghyepHtzm",
        "images": [
          {
            "height": 640,
            "url": "https://i.scdn.co/image/ab67616d0000b273d9e9436112102a62090fbff2",
            "width": 640
          },
          {
            "height": 300,
            "url": "https://i.scdn.co/image/ab67616d00001e02d9e9436112102a62090fbff2",
            "width": 300
          },
          {
            "height": 64,
            "url": "https://i.scdn.co/image/ab67616d00004851d9e9436112102a62090fbff2",
            "width": 64
          }
        ],
        "name": "Cores, Nomes",
        "release_date": "1982-01-01",
        "release_date_precision": "day",
        "total_tracks": 12,
        "type": "album",
        "uri": "spotify:album:1xAQ6kW7DQZxTghyepHtzm"
      },
      "artists": [
        {
          "external_urls": {
            "spotify": "https://open.spotify.com/artist/7HGNYPmbDrMkylWqeFCOIQ"
          },
          "href": "https://api.spotify.com/v1/artists/7HGNYPmbDrMkylWqeFCOIQ",
          "id": "7HGNYPmbDrMkylWqeFCOIQ",
          "name": "Caetano Veloso",
          "type": "artist",
          "uri": "spotify:artist:7HGNYPmbDrMkylWqeFCOIQ"
        }
      ],
      "available_markets": [
        "AR",
        "AU",
        "AT",
        "BE",
        "BO",
        "BR",
        "BG",
        "CA",
        "CL",
        "CO",
        "CR",
        "CY",
        "CZ",
        "DK",
        "DO",
        "DE",
        "EC",
        "EE",
        "SV",
        "FI",
        "FR",
        "GR",
        "GT",
        "HN",
        "HK",
        "HU",
        "IS",
        "IE",
        "IT",
        "LV",
        "LT",
        "LU",
        "MY",
        "MT",
        "MX",
        "NL",
        "NZ",
        "NI",
        "NO",
        "PA",
        "PY",
        "PE",
        "PH",
        "PL",
        "PT",
        "SG",
        "SK",
        "ES",
        "SE",
        "CH",
        "TW",
        "TR",
        "UY",
        "US",
        "GB",
        "AD",
        "LI",
        "MC",
        "ID",
        "JP",
        "TH",
        "VN",
        "RO",
        "IL",
        "ZA",
        "SA",
        "AE",
        "BH",
        "QA",
        "OM",
        "KW",
        "EG",
        "MA",
        "DZ",
        "TN",
        "LB",
        "JO",
        "PS",
        "IN",
        "BY",
        "KZ",
        "MD",
        "UA",
        "AL",
        "BA",
        "HR",
        "ME",
        "MK",
        "RS",
        "SI",
        "KR",
        "BD",
        "PK",
        "LK",
        "GH",
        "KE",
        "NG",
        "TZ",
        "UG",
        "AG",
        "AM",
        "BS",
        "BB",
        "BZ",
        "BT",
        "BW",
        "BF",
        "CV",
        "CW",
        "DM",
        "FJ",
        "GM",
        "GE",
        "GD",
        "GW",
        "GY",
        "HT",
        "JM",
        "KI",
        "LS",
        "LR",
        "MW",
        "MV",
        "ML",
        "MH",
        "FM",
        "NA",
        "NR",
        "NE",
        "PW",
        "PG",
        "WS",
        "SM",
        "ST",
        "SN",
        "SC",
        "SL",
        "SB",
        "KN",
        "LC",
        "VC",
        "SR",
        "TL",
        "TO",
        "TT",
        "TV",
        "VU",
        "AZ",
        "BN",
        "BI",
        "KH",
        "CM",
        "TD",
        "KM",
        "GQ",
        "SZ",
        "GA",
        "GN",
        "KG",
        "LA",
        "MO",
        "MR",
        "MN",
        "NP",
        "RW",
        "TG",
        "UZ",
        "ZW",
        "BJ",
        "MG",
        "MU",
        "MZ",
        "AO",
        "CI",
        "DJ",
        "ZM",
        "CD",
        "CG",
        "IQ",
        "LY",
        "TJ",
        "VE",
        "ET",
        "XK"
      ],
      "disc_number": 1,
      "duration_ms": 242186,
      "explicit": False,
      "external_ids": {
        "isrc": "BRMCA8200171"
      },
      "external_urls": {
        "spotify": "https://open.spotify.com/track/6oh2Nc25ee22xu3srg3AIz"
      },
      "href": "https://api.spotify.com/v1/tracks/6oh2Nc25ee22xu3srg3AIz",
      "id": "6oh2Nc25ee22xu3srg3AIz",
      "is_local": False,
      "name": "Meu Bem, Meu Mal",
      "popularity": 32,
      "preview_url": "null",
      "track_number": 9,
      "type": "track",
      "uri": "spotify:track:6oh2Nc25ee22xu3srg3AIz"
    },
    {
      "album": {
        "album_type": "album",
        "artists": [
          {
            "external_urls": {
              "spotify": "https://open.spotify.com/artist/7HGNYPmbDrMkylWqeFCOIQ"
            },
            "href": "https://api.spotify.com/v1/artists/7HGNYPmbDrMkylWqeFCOIQ",
            "id": "7HGNYPmbDrMkylWqeFCOIQ",
            "name": "Caetano Veloso",
            "type": "artist",
            "uri": "spotify:artist:7HGNYPmbDrMkylWqeFCOIQ"
          }
        ],
        "available_markets": [
          "AR",
          "AU",
          "AT",
          "BE",
          "BO",
          "BR",
          "BG",
          "CA",
          "CL",
          "CO",
          "CR",
          "CY",
          "CZ",
          "DK",
          "DO",
          "DE",
          "EC",
          "EE",
          "SV",
          "FI",
          "FR",
          "GR",
          "GT",
          "HN",
          "HK",
          "HU",
          "IS",
          "IE",
          "IT",
          "LV",
          "LT",
          "LU",
          "MY",
          "MT",
          "MX",
          "NL",
          "NZ",
          "NI",
          "NO",
          "PA",
          "PY",
          "PE",
          "PH",
          "PL",
          "PT",
          "SG",
          "SK",
          "ES",
          "SE",
          "CH",
          "TW",
          "TR",
          "UY",
          "US",
          "GB",
          "AD",
          "LI",
          "MC",
          "ID",
          "JP",
          "TH",
          "VN",
          "RO",
          "IL",
          "ZA",
          "SA",
          "AE",
          "BH",
          "QA",
          "OM",
          "KW",
          "EG",
          "MA",
          "DZ",
          "TN",
          "LB",
          "JO",
          "PS",
          "IN",
          "BY",
          "KZ",
          "MD",
          "UA",
          "AL",
          "BA",
          "HR",
          "ME",
          "MK",
          "RS",
          "SI",
          "KR",
          "BD",
          "PK",
          "LK",
          "GH",
          "KE",
          "NG",
          "TZ",
          "UG",
          "AG",
          "AM",
          "BS",
          "BB",
          "BZ",
          "BT",
          "BW",
          "BF",
          "CV",
          "CW",
          "DM",
          "FJ",
          "GM",
          "GE",
          "GD",
          "GW",
          "GY",
          "HT",
          "JM",
          "KI",
          "LS",
          "LR",
          "MW",
          "MV",
          "ML",
          "MH",
          "FM",
          "NA",
          "NR",
          "NE",
          "PW",
          "PG",
          "WS",
          "SM",
          "ST",
          "SN",
          "SC",
          "SL",
          "SB",
          "KN",
          "LC",
          "VC",
          "SR",
          "TL",
          "TO",
          "TT",
          "TV",
          "VU",
          "AZ",
          "BN",
          "BI",
          "KH",
          "CM",
          "TD",
          "KM",
          "GQ",
          "SZ",
          "GA",
          "GN",
          "KG",
          "LA",
          "MO",
          "MR",
          "MN",
          "NP",
          "RW",
          "TG",
          "UZ",
          "ZW",
          "BJ",
          "MG",
          "MU",
          "MZ",
          "AO",
          "CI",
          "DJ",
          "ZM",
          "CD",
          "CG",
          "IQ",
          "LY",
          "TJ",
          "VE",
          "ET",
          "XK"
        ],
        "external_urls": {
          "spotify": "https://open.spotify.com/album/1xAQ6kW7DQZxTghyepHtzm"
        },
        "href": "https://api.spotify.com/v1/albums/1xAQ6kW7DQZxTghyepHtzm",
        "id": "1xAQ6kW7DQZxTghyepHtzm",
        "images": [
          {
            "height": 640,
            "url": "https://i.scdn.co/image/ab67616d0000b273d9e9436112102a62090fbff2",
            "width": 640
          },
          {
            "height": 300,
            "url": "https://i.scdn.co/image/ab67616d00001e02d9e9436112102a62090fbff2",
            "width": 300
          },
          {
            "height": 64,
            "url": "https://i.scdn.co/image/ab67616d00004851d9e9436112102a62090fbff2",
            "width": 64
          }
        ],
        "name": "Cores, Nomes",
        "release_date": "1982-01-01",
        "release_date_precision": "day",
        "total_tracks": 12,
        "type": "album",
        "uri": "spotify:album:1xAQ6kW7DQZxTghyepHtzm"
      },
      "artists": [
        {
          "external_urls": {
            "spotify": "https://open.spotify.com/artist/7HGNYPmbDrMkylWqeFCOIQ"
          },
          "href": "https://api.spotify.com/v1/artists/7HGNYPmbDrMkylWqeFCOIQ",
          "id": "7HGNYPmbDrMkylWqeFCOIQ",
          "name": "Caetano Veloso",
          "type": "artist",
          "uri": "spotify:artist:7HGNYPmbDrMkylWqeFCOIQ"
        }
      ],
      "available_markets": [
        "AR",
        "AU",
        "AT",
        "BE",
        "BO",
        "BR",
        "BG",
        "CA",
        "CL",
        "CO",
        "CR",
        "CY",
        "CZ",
        "DK",
        "DO",
        "DE",
        "EC",
        "EE",
        "SV",
        "FI",
        "FR",
        "GR",
        "GT",
        "HN",
        "HK",
        "HU",
        "IS",
        "IE",
        "IT",
        "LV",
        "LT",
        "LU",
        "MY",
        "MT",
        "MX",
        "NL",
        "NZ",
        "NI",
        "NO",
        "PA",
        "PY",
        "PE",
        "PH",
        "PL",
        "PT",
        "SG",
        "SK",
        "ES",
        "SE",
        "CH",
        "TW",
        "TR",
        "UY",
        "US",
        "GB",
        "AD",
        "LI",
        "MC",
        "ID",
        "JP",
        "TH",
        "VN",
        "RO",
        "IL",
        "ZA",
        "SA",
        "AE",
        "BH",
        "QA",
        "OM",
        "KW",
        "EG",
        "MA",
        "DZ",
        "TN",
        "LB",
        "JO",
        "PS",
        "IN",
        "BY",
        "KZ",
        "MD",
        "UA",
        "AL",
        "BA",
        "HR",
        "ME",
        "MK",
        "RS",
        "SI",
        "KR",
        "BD",
        "PK",
        "LK",
        "GH",
        "KE",
        "NG",
        "TZ",
        "UG",
        "AG",
        "AM",
        "BS",
        "BB",
        "BZ",
        "BT",
        "BW",
        "BF",
        "CV",
        "CW",
        "DM",
        "FJ",
        "GM",
        "GE",
        "GD",
        "GW",
        "GY",
        "HT",
        "JM",
        "KI",
        "LS",
        "LR",
        "MW",
        "MV",
        "ML",
        "MH",
        "FM",
        "NA",
        "NR",
        "NE",
        "PW",
        "PG",
        "WS",
        "SM",
        "ST",
        "SN",
        "SC",
        "SL",
        "SB",
        "KN",
        "LC",
        "VC",
        "SR",
        "TL",
        "TO",
        "TT",
        "TV",
        "VU",
        "AZ",
        "BN",
        "BI",
        "KH",
        "CM",
        "TD",
        "KM",
        "GQ",
        "SZ",
        "GA",
        "GN",
        "KG",
        "LA",
        "MO",
        "MR",
        "MN",
        "NP",
        "RW",
        "TG",
        "UZ",
        "ZW",
        "BJ",
        "MG",
        "MU",
        "MZ",
        "AO",
        "CI",
        "DJ",
        "ZM",
        "CD",
        "CG",
        "IQ",
        "LY",
        "TJ",
        "VE",
        "ET",
        "XK"
      ],
      "disc_number": 1,
      "duration_ms": 177773,
      "explicit": False,
      "external_ids": {
        "isrc": "BRMCA8200172"
      },
      "external_urls": {
        "spotify": "https://open.spotify.com/track/3RCb6vZYTFFg8HrGM5R9Us"
      },
      "href": "https://api.spotify.com/v1/tracks/3RCb6vZYTFFg8HrGM5R9Us",
      "id": "3RCb6vZYTFFg8HrGM5R9Us",
      "is_local": False,
      "name": "Genesis",
      "popularity": 21,
      "preview_url": "null",
      "track_number": 10,
      "type": "track",
      "uri": "spotify:track:3RCb6vZYTFFg8HrGM5R9Us"
    },
    {
      "album": {
        "album_type": "album",
        "artists": [
          {
            "external_urls": {
              "spotify": "https://open.spotify.com/artist/7HGNYPmbDrMkylWqeFCOIQ"
            },
            "href": "https://api.spotify.com/v1/artists/7HGNYPmbDrMkylWqeFCOIQ",
            "id": "7HGNYPmbDrMkylWqeFCOIQ",
            "name": "Caetano Veloso",
            "type": "artist",
            "uri": "spotify:artist:7HGNYPmbDrMkylWqeFCOIQ"
          }
        ],
        "available_markets": [
          "AR",
          "AU",
          "AT",
          "BE",
          "BO",
          "BR",
          "BG",
          "CA",
          "CL",
          "CO",
          "CR",
          "CY",
          "CZ",
          "DK",
          "DO",
          "DE",
          "EC",
          "EE",
          "SV",
          "FI",
          "FR",
          "GR",
          "GT",
          "HN",
          "HK",
          "HU",
          "IS",
          "IE",
          "IT",
          "LV",
          "LT",
          "LU",
          "MY",
          "MT",
          "MX",
          "NL",
          "NZ",
          "NI",
          "NO",
          "PA",
          "PY",
          "PE",
          "PH",
          "PL",
          "PT",
          "SG",
          "SK",
          "ES",
          "SE",
          "CH",
          "TW",
          "TR",
          "UY",
          "US",
          "GB",
          "AD",
          "LI",
          "MC",
          "ID",
          "JP",
          "TH",
          "VN",
          "RO",
          "IL",
          "ZA",
          "SA",
          "AE",
          "BH",
          "QA",
          "OM",
          "KW",
          "EG",
          "MA",
          "DZ",
          "TN",
          "LB",
          "JO",
          "PS",
          "IN",
          "BY",
          "KZ",
          "MD",
          "UA",
          "AL",
          "BA",
          "HR",
          "ME",
          "MK",
          "RS",
          "SI",
          "KR",
          "BD",
          "PK",
          "LK",
          "GH",
          "KE",
          "NG",
          "TZ",
          "UG",
          "AG",
          "AM",
          "BS",
          "BB",
          "BZ",
          "BT",
          "BW",
          "BF",
          "CV",
          "CW",
          "DM",
          "FJ",
          "GM",
          "GE",
          "GD",
          "GW",
          "GY",
          "HT",
          "JM",
          "KI",
          "LS",
          "LR",
          "MW",
          "MV",
          "ML",
          "MH",
          "FM",
          "NA",
          "NR",
          "NE",
          "PW",
          "PG",
          "WS",
          "SM",
          "ST",
          "SN",
          "SC",
          "SL",
          "SB",
          "KN",
          "LC",
          "VC",
          "SR",
          "TL",
          "TO",
          "TT",
          "TV",
          "VU",
          "AZ",
          "BN",
          "BI",
          "KH",
          "CM",
          "TD",
          "KM",
          "GQ",
          "SZ",
          "GA",
          "GN",
          "KG",
          "LA",
          "MO",
          "MR",
          "MN",
          "NP",
          "RW",
          "TG",
          "UZ",
          "ZW",
          "BJ",
          "MG",
          "MU",
          "MZ",
          "AO",
          "CI",
          "DJ",
          "ZM",
          "CD",
          "CG",
          "IQ",
          "LY",
          "TJ",
          "VE",
          "ET",
          "XK"
        ],
        "external_urls": {
          "spotify": "https://open.spotify.com/album/1xAQ6kW7DQZxTghyepHtzm"
        },
        "href": "https://api.spotify.com/v1/albums/1xAQ6kW7DQZxTghyepHtzm",
        "id": "1xAQ6kW7DQZxTghyepHtzm",
        "images": [
          {
            "height": 640,
            "url": "https://i.scdn.co/image/ab67616d0000b273d9e9436112102a62090fbff2",
            "width": 640
          },
          {
            "height": 300,
            "url": "https://i.scdn.co/image/ab67616d00001e02d9e9436112102a62090fbff2",
            "width": 300
          },
          {
            "height": 64,
            "url": "https://i.scdn.co/image/ab67616d00004851d9e9436112102a62090fbff2",
            "width": 64
          }
        ],
        "name": "Cores, Nomes",
        "release_date": "1982-01-01",
        "release_date_precision": "day",
        "total_tracks": 12,
        "type": "album",
        "uri": "spotify:album:1xAQ6kW7DQZxTghyepHtzm"
      },
      "artists": [
        {
          "external_urls": {
            "spotify": "https://open.spotify.com/artist/7HGNYPmbDrMkylWqeFCOIQ"
          },
          "href": "https://api.spotify.com/v1/artists/7HGNYPmbDrMkylWqeFCOIQ",
          "id": "7HGNYPmbDrMkylWqeFCOIQ",
          "name": "Caetano Veloso",
          "type": "artist",
          "uri": "spotify:artist:7HGNYPmbDrMkylWqeFCOIQ"
        }
      ],
      "available_markets": [
        "AR",
        "AU",
        "AT",
        "BE",
        "BO",
        "BR",
        "BG",
        "CA",
        "CL",
        "CO",
        "CR",
        "CY",
        "CZ",
        "DK",
        "DO",
        "DE",
        "EC",
        "EE",
        "SV",
        "FI",
        "FR",
        "GR",
        "GT",
        "HN",
        "HK",
        "HU",
        "IS",
        "IE",
        "IT",
        "LV",
        "LT",
        "LU",
        "MY",
        "MT",
        "MX",
        "NL",
        "NZ",
        "NI",
        "NO",
        "PA",
        "PY",
        "PE",
        "PH",
        "PL",
        "PT",
        "SG",
        "SK",
        "ES",
        "SE",
        "CH",
        "TW",
        "TR",
        "UY",
        "US",
        "GB",
        "AD",
        "LI",
        "MC",
        "ID",
        "JP",
        "TH",
        "VN",
        "RO",
        "IL",
        "ZA",
        "SA",
        "AE",
        "BH",
        "QA",
        "OM",
        "KW",
        "EG",
        "MA",
        "DZ",
        "TN",
        "LB",
        "JO",
        "PS",
        "IN",
        "BY",
        "KZ",
        "MD",
        "UA",
        "AL",
        "BA",
        "HR",
        "ME",
        "MK",
        "RS",
        "SI",
        "KR",
        "BD",
        "PK",
        "LK",
        "GH",
        "KE",
        "NG",
        "TZ",
        "UG",
        "AG",
        "AM",
        "BS",
        "BB",
        "BZ",
        "BT",
        "BW",
        "BF",
        "CV",
        "CW",
        "DM",
        "FJ",
        "GM",
        "GE",
        "GD",
        "GW",
        "GY",
        "HT",
        "JM",
        "KI",
        "LS",
        "LR",
        "MW",
        "MV",
        "ML",
        "MH",
        "FM",
        "NA",
        "NR",
        "NE",
        "PW",
        "PG",
        "WS",
        "SM",
        "ST",
        "SN",
        "SC",
        "SL",
        "SB",
        "KN",
        "LC",
        "VC",
        "SR",
        "TL",
        "TO",
        "TT",
        "TV",
        "VU",
        "AZ",
        "BN",
        "BI",
        "KH",
        "CM",
        "TD",
        "KM",
        "GQ",
        "SZ",
        "GA",
        "GN",
        "KG",
        "LA",
        "MO",
        "MR",
        "MN",
        "NP",
        "RW",
        "TG",
        "UZ",
        "ZW",
        "BJ",
        "MG",
        "MU",
        "MZ",
        "AO",
        "CI",
        "DJ",
        "ZM",
        "CD",
        "CG",
        "IQ",
        "LY",
        "TJ",
        "VE",
        "ET",
        "XK"
      ],
      "disc_number": 1,
      "duration_ms": 180453,
      "explicit": False,
      "external_ids": {
        "isrc": "BRMCA8200173"
      },
      "external_urls": {
        "spotify": "https://open.spotify.com/track/6kCjKljGsnyzXaKKH9Cbgu"
      },
      "href": "https://api.spotify.com/v1/tracks/6kCjKljGsnyzXaKKH9Cbgu",
      "id": "6kCjKljGsnyzXaKKH9Cbgu",
      "is_local": False,
      "name": "Sonhos",
      "popularity": 50,
      "preview_url": "null",
      "track_number": 11,
      "type": "track",
      "uri": "spotify:track:6kCjKljGsnyzXaKKH9Cbgu"
    },
    {
      "album": {
        "album_type": "album",
        "artists": [
          {
            "external_urls": {
              "spotify": "https://open.spotify.com/artist/7HGNYPmbDrMkylWqeFCOIQ"
            },
            "href": "https://api.spotify.com/v1/artists/7HGNYPmbDrMkylWqeFCOIQ",
            "id": "7HGNYPmbDrMkylWqeFCOIQ",
            "name": "Caetano Veloso",
            "type": "artist",
            "uri": "spotify:artist:7HGNYPmbDrMkylWqeFCOIQ"
          }
        ],
        "available_markets": [
          "AR",
          "AU",
          "AT",
          "BE",
          "BO",
          "BR",
          "BG",
          "CA",
          "CL",
          "CO",
          "CR",
          "CY",
          "CZ",
          "DK",
          "DO",
          "DE",
          "EC",
          "EE",
          "SV",
          "FI",
          "FR",
          "GR",
          "GT",
          "HN",
          "HK",
          "HU",
          "IS",
          "IE",
          "IT",
          "LV",
          "LT",
          "LU",
          "MY",
          "MT",
          "MX",
          "NL",
          "NZ",
          "NI",
          "NO",
          "PA",
          "PY",
          "PE",
          "PH",
          "PL",
          "PT",
          "SG",
          "SK",
          "ES",
          "SE",
          "CH",
          "TW",
          "TR",
          "UY",
          "US",
          "GB",
          "AD",
          "LI",
          "MC",
          "ID",
          "JP",
          "TH",
          "VN",
          "RO",
          "IL",
          "ZA",
          "SA",
          "AE",
          "BH",
          "QA",
          "OM",
          "KW",
          "EG",
          "MA",
          "DZ",
          "TN",
          "LB",
          "JO",
          "PS",
          "IN",
          "BY",
          "KZ",
          "MD",
          "UA",
          "AL",
          "BA",
          "HR",
          "ME",
          "MK",
          "RS",
          "SI",
          "KR",
          "BD",
          "PK",
          "LK",
          "GH",
          "KE",
          "NG",
          "TZ",
          "UG",
          "AG",
          "AM",
          "BS",
          "BB",
          "BZ",
          "BT",
          "BW",
          "BF",
          "CV",
          "CW",
          "DM",
          "FJ",
          "GM",
          "GE",
          "GD",
          "GW",
          "GY",
          "HT",
          "JM",
          "KI",
          "LS",
          "LR",
          "MW",
          "MV",
          "ML",
          "MH",
          "FM",
          "NA",
          "NR",
          "NE",
          "PW",
          "PG",
          "WS",
          "SM",
          "ST",
          "SN",
          "SC",
          "SL",
          "SB",
          "KN",
          "LC",
          "VC",
          "SR",
          "TL",
          "TO",
          "TT",
          "TV",
          "VU",
          "AZ",
          "BN",
          "BI",
          "KH",
          "CM",
          "TD",
          "KM",
          "GQ",
          "SZ",
          "GA",
          "GN",
          "KG",
          "LA",
          "MO",
          "MR",
          "MN",
          "NP",
          "RW",
          "TG",
          "UZ",
          "ZW",
          "BJ",
          "MG",
          "MU",
          "MZ",
          "AO",
          "CI",
          "DJ",
          "ZM",
          "CD",
          "CG",
          "IQ",
          "LY",
          "TJ",
          "VE",
          "ET",
          "XK"
        ],
        "external_urls": {
          "spotify": "https://open.spotify.com/album/1xAQ6kW7DQZxTghyepHtzm"
        },
        "href": "https://api.spotify.com/v1/albums/1xAQ6kW7DQZxTghyepHtzm",
        "id": "1xAQ6kW7DQZxTghyepHtzm",
        "images": [
          {
            "height": 640,
            "url": "https://i.scdn.co/image/ab67616d0000b273d9e9436112102a62090fbff2",
            "width": 640
          },
          {
            "height": 300,
            "url": "https://i.scdn.co/image/ab67616d00001e02d9e9436112102a62090fbff2",
            "width": 300
          },
          {
            "height": 64,
            "url": "https://i.scdn.co/image/ab67616d00004851d9e9436112102a62090fbff2",
            "width": 64
          }
        ],
        "name": "Cores, Nomes",
        "release_date": "1982-01-01",
        "release_date_precision": "day",
        "total_tracks": 12,
        "type": "album",
        "uri": "spotify:album:1xAQ6kW7DQZxTghyepHtzm"
      },
      "artists": [
        {
          "external_urls": {
            "spotify": "https://open.spotify.com/artist/7HGNYPmbDrMkylWqeFCOIQ"
          },
          "href": "https://api.spotify.com/v1/artists/7HGNYPmbDrMkylWqeFCOIQ",
          "id": "7HGNYPmbDrMkylWqeFCOIQ",
          "name": "Caetano Veloso",
          "type": "artist",
          "uri": "spotify:artist:7HGNYPmbDrMkylWqeFCOIQ"
        }
      ],
      "available_markets": [
        "AR",
        "AU",
        "AT",
        "BE",
        "BO",
        "BR",
        "BG",
        "CA",
        "CL",
        "CO",
        "CR",
        "CY",
        "CZ",
        "DK",
        "DO",
        "DE",
        "EC",
        "EE",
        "SV",
        "FI",
        "FR",
        "GR",
        "GT",
        "HN",
        "HK",
        "HU",
        "IS",
        "IE",
        "IT",
        "LV",
        "LT",
        "LU",
        "MY",
        "MT",
        "MX",
        "NL",
        "NZ",
        "NI",
        "NO",
        "PA",
        "PY",
        "PE",
        "PH",
        "PL",
        "PT",
        "SG",
        "SK",
        "ES",
        "SE",
        "CH",
        "TW",
        "TR",
        "UY",
        "US",
        "GB",
        "AD",
        "LI",
        "MC",
        "ID",
        "JP",
        "TH",
        "VN",
        "RO",
        "IL",
        "ZA",
        "SA",
        "AE",
        "BH",
        "QA",
        "OM",
        "KW",
        "EG",
        "MA",
        "DZ",
        "TN",
        "LB",
        "JO",
        "PS",
        "IN",
        "BY",
        "KZ",
        "MD",
        "UA",
        "AL",
        "BA",
        "HR",
        "ME",
        "MK",
        "RS",
        "SI",
        "KR",
        "BD",
        "PK",
        "LK",
        "GH",
        "KE",
        "NG",
        "TZ",
        "UG",
        "AG",
        "AM",
        "BS",
        "BB",
        "BZ",
        "BT",
        "BW",
        "BF",
        "CV",
        "CW",
        "DM",
        "FJ",
        "GM",
        "GE",
        "GD",
        "GW",
        "GY",
        "HT",
        "JM",
        "KI",
        "LS",
        "LR",
        "MW",
        "MV",
        "ML",
        "MH",
        "FM",
        "NA",
        "NR",
        "NE",
        "PW",
        "PG",
        "WS",
        "SM",
        "ST",
        "SN",
        "SC",
        "SL",
        "SB",
        "KN",
        "LC",
        "VC",
        "SR",
        "TL",
        "TO",
        "TT",
        "TV",
        "VU",
        "AZ",
        "BN",
        "BI",
        "KH",
        "CM",
        "TD",
        "KM",
        "GQ",
        "SZ",
        "GA",
        "GN",
        "KG",
        "LA",
        "MO",
        "MR",
        "MN",
        "NP",
        "RW",
        "TG",
        "UZ",
        "ZW",
        "BJ",
        "MG",
        "MU",
        "MZ",
        "AO",
        "CI",
        "DJ",
        "ZM",
        "CD",
        "CG",
        "IQ",
        "LY",
        "TJ",
        "VE",
        "ET",
        "XK"
      ],
      "disc_number": 1,
      "duration_ms": 199853,
      "explicit": False,
      "external_ids": {
        "isrc": "BRMCA8200174"
      },
      "external_urls": {
        "spotify": "https://open.spotify.com/track/3faSQBFkpubrMOlZTAsK6F"
      },
      "href": "https://api.spotify.com/v1/tracks/3faSQBFkpubrMOlZTAsK6F",
      "id": "3faSQBFkpubrMOlZTAsK6F",
      "is_local": False,
      "name": "Surpresa",
      "popularity": 22,
      "preview_url": "null",
      "track_number": 12,
      "type": "track",
      "uri": "spotify:track:3faSQBFkpubrMOlZTAsK6F"
    },
    {
      "album": {
        "album_type": "album",
        "artists": [
          {
            "external_urls": {
              "spotify": "https://open.spotify.com/artist/7HGNYPmbDrMkylWqeFCOIQ"
            },
            "href": "https://api.spotify.com/v1/artists/7HGNYPmbDrMkylWqeFCOIQ",
            "id": "7HGNYPmbDrMkylWqeFCOIQ",
            "name": "Caetano Veloso",
            "type": "artist",
            "uri": "spotify:artist:7HGNYPmbDrMkylWqeFCOIQ"
          }
        ],
        "available_markets": [
          "AR",
          "AU",
          "AT",
          "BE",
          "BO",
          "BR",
          "BG",
          "CA",
          "CL",
          "CO",
          "CR",
          "CY",
          "CZ",
          "DK",
          "DO",
          "DE",
          "EC",
          "EE",
          "SV",
          "FI",
          "FR",
          "GR",
          "GT",
          "HN",
          "HK",
          "HU",
          "IS",
          "IE",
          "IT",
          "LV",
          "LT",
          "LU",
          "MY",
          "MT",
          "MX",
          "NL",
          "NZ",
          "NI",
          "NO",
          "PA",
          "PY",
          "PE",
          "PH",
          "PL",
          "PT",
          "SG",
          "SK",
          "ES",
          "SE",
          "CH",
          "TW",
          "TR",
          "UY",
          "US",
          "GB",
          "AD",
          "LI",
          "MC",
          "ID",
          "JP",
          "TH",
          "VN",
          "RO",
          "IL",
          "ZA",
          "SA",
          "AE",
          "BH",
          "QA",
          "OM",
          "KW",
          "EG",
          "MA",
          "DZ",
          "TN",
          "LB",
          "JO",
          "PS",
          "IN",
          "BY",
          "KZ",
          "MD",
          "UA",
          "AL",
          "BA",
          "HR",
          "ME",
          "MK",
          "RS",
          "SI",
          "KR",
          "BD",
          "PK",
          "LK",
          "GH",
          "KE",
          "NG",
          "TZ",
          "UG",
          "AG",
          "AM",
          "BS",
          "BB",
          "BZ",
          "BT",
          "BW",
          "BF",
          "CV",
          "CW",
          "DM",
          "FJ",
          "GM",
          "GE",
          "GD",
          "GW",
          "GY",
          "HT",
          "JM",
          "KI",
          "LS",
          "LR",
          "MW",
          "MV",
          "ML",
          "MH",
          "FM",
          "NA",
          "NR",
          "NE",
          "PW",
          "PG",
          "WS",
          "SM",
          "ST",
          "SN",
          "SC",
          "SL",
          "SB",
          "KN",
          "LC",
          "VC",
          "SR",
          "TL",
          "TO",
          "TT",
          "TV",
          "VU",
          "AZ",
          "BN",
          "BI",
          "KH",
          "CM",
          "TD",
          "KM",
          "GQ",
          "SZ",
          "GA",
          "GN",
          "KG",
          "LA",
          "MO",
          "MR",
          "MN",
          "NP",
          "RW",
          "TG",
          "UZ",
          "ZW",
          "BJ",
          "MG",
          "MU",
          "MZ",
          "AO",
          "CI",
          "DJ",
          "ZM",
          "CD",
          "CG",
          "IQ",
          "LY",
          "TJ",
          "VE",
          "ET",
          "XK"
        ],
        "external_urls": {
          "spotify": "https://open.spotify.com/album/1xAQ6kW7DQZxTghyepHtzm"
        },
        "href": "https://api.spotify.com/v1/albums/1xAQ6kW7DQZxTghyepHtzm",
        "id": "1xAQ6kW7DQZxTghyepHtzm",
        "images": [
          {
            "height": 640,
            "url": "https://i.scdn.co/image/ab67616d0000b273d9e9436112102a62090fbff2",
            "width": 640
          },
          {
            "height": 300,
            "url": "https://i.scdn.co/image/ab67616d00001e02d9e9436112102a62090fbff2",
            "width": 300
          },
          {
            "height": 64,
            "url": "https://i.scdn.co/image/ab67616d00004851d9e9436112102a62090fbff2",
            "width": 64
          }
        ],
        "name": "Cores, Nomes",
        "release_date": "1982-01-01",
        "release_date_precision": "day",
        "total_tracks": 12,
        "type": "album",
        "uri": "spotify:album:1xAQ6kW7DQZxTghyepHtzm"
      },
      "artists": [
        {
          "external_urls": {
            "spotify": "https://open.spotify.com/artist/7HGNYPmbDrMkylWqeFCOIQ"
          },
          "href": "https://api.spotify.com/v1/artists/7HGNYPmbDrMkylWqeFCOIQ",
          "id": "7HGNYPmbDrMkylWqeFCOIQ",
          "name": "Caetano Veloso",
          "type": "artist",
          "uri": "spotify:artist:7HGNYPmbDrMkylWqeFCOIQ"
        }
      ],
      "available_markets": [
        "AR",
        "AU",
        "AT",
        "BE",
        "BO",
        "BR",
        "BG",
        "CA",
        "CL",
        "CO",
        "CR",
        "CY",
        "CZ",
        "DK",
        "DO",
        "DE",
        "EC",
        "EE",
        "SV",
        "FI",
        "FR",
        "GR",
        "GT",
        "HN",
        "HK",
        "HU",
        "IS",
        "IE",
        "IT",
        "LV",
        "LT",
        "LU",
        "MY",
        "MT",
        "MX",
        "NL",
        "NZ",
        "NI",
        "NO",
        "PA",
        "PY",
        "PE",
        "PH",
        "PL",
        "PT",
        "SG",
        "SK",
        "ES",
        "SE",
        "CH",
        "TW",
        "TR",
        "UY",
        "US",
        "GB",
        "AD",
        "LI",
        "MC",
        "ID",
        "JP",
        "TH",
        "VN",
        "RO",
        "IL",
        "ZA",
        "SA",
        "AE",
        "BH",
        "QA",
        "OM",
        "KW",
        "EG",
        "MA",
        "DZ",
        "TN",
        "LB",
        "JO",
        "PS",
        "IN",
        "BY",
        "KZ",
        "MD",
        "UA",
        "AL",
        "BA",
        "HR",
        "ME",
        "MK",
        "RS",
        "SI",
        "KR",
        "BD",
        "PK",
        "LK",
        "GH",
        "KE",
        "NG",
        "TZ",
        "UG",
        "AG",
        "AM",
        "BS",
        "BB",
        "BZ",
        "BT",
        "BW",
        "BF",
        "CV",
        "CW",
        "DM",
        "FJ",
        "GM",
        "GE",
        "GD",
        "GW",
        "GY",
        "HT",
        "JM",
        "KI",
        "LS",
        "LR",
        "MW",
        "MV",
        "ML",
        "MH",
        "FM",
        "NA",
        "NR",
        "NE",
        "PW",
        "PG",
        "WS",
        "SM",
        "ST",
        "SN",
        "SC",
        "SL",
        "SB",
        "KN",
        "LC",
        "VC",
        "SR",
        "TL",
        "TO",
        "TT",
        "TV",
        "VU",
        "AZ",
        "BN",
        "BI",
        "KH",
        "CM",
        "TD",
        "KM",
        "GQ",
        "SZ",
        "GA",
        "GN",
        "KG",
        "LA",
        "MO",
        "MR",
        "MN",
        "NP",
        "RW",
        "TG",
        "UZ",
        "ZW",
        "BJ",
        "MG",
        "MU",
        "MZ",
        "AO",
        "CI",
        "DJ",
        "ZM",
        "CD",
        "CG",
        "IQ",
        "LY",
        "TJ",
        "VE",
        "ET",
        "XK"
      ],
      "disc_number": 1,
      "duration_ms": 263373,
      "explicit": False,
      "external_ids": {
        "isrc": "BRMCA8200164"
      },
      "external_urls": {
        "spotify": "https://open.spotify.com/track/1NIAQbzrcpqoaZd3sNFFKJ"
      },
      "href": "https://api.spotify.com/v1/tracks/1NIAQbzrcpqoaZd3sNFFKJ",
      "id": "1NIAQbzrcpqoaZd3sNFFKJ",
      "is_local": False,
      "name": "Queixa",
      "popularity": 51,
      "preview_url": "null",
      "track_number": 1,
      "type": "track",
      "uri": "spotify:track:1NIAQbzrcpqoaZd3sNFFKJ"
    },
    {
      "album": {
        "album_type": "album",
        "artists": [
          {
            "external_urls": {
              "spotify": "https://open.spotify.com/artist/7HGNYPmbDrMkylWqeFCOIQ"
            },
            "href": "https://api.spotify.com/v1/artists/7HGNYPmbDrMkylWqeFCOIQ",
            "id": "7HGNYPmbDrMkylWqeFCOIQ",
            "name": "Caetano Veloso",
            "type": "artist",
            "uri": "spotify:artist:7HGNYPmbDrMkylWqeFCOIQ"
          }
        ],
        "available_markets": [
          "AR",
          "AU",
          "AT",
          "BE",
          "BO",
          "BR",
          "BG",
          "CA",
          "CL",
          "CO",
          "CR",
          "CY",
          "CZ",
          "DK",
          "DO",
          "DE",
          "EC",
          "EE",
          "SV",
          "FI",
          "FR",
          "GR",
          "GT",
          "HN",
          "HK",
          "HU",
          "IS",
          "IE",
          "IT",
          "LV",
          "LT",
          "LU",
          "MY",
          "MT",
          "MX",
          "NL",
          "NZ",
          "NI",
          "NO",
          "PA",
          "PY",
          "PE",
          "PH",
          "PL",
          "PT",
          "SG",
          "SK",
          "ES",
          "SE",
          "CH",
          "TW",
          "TR",
          "UY",
          "US",
          "GB",
          "AD",
          "LI",
          "MC",
          "ID",
          "JP",
          "TH",
          "VN",
          "RO",
          "IL",
          "ZA",
          "SA",
          "AE",
          "BH",
          "QA",
          "OM",
          "KW",
          "EG",
          "MA",
          "DZ",
          "TN",
          "LB",
          "JO",
          "PS",
          "IN",
          "BY",
          "KZ",
          "MD",
          "UA",
          "AL",
          "BA",
          "HR",
          "ME",
          "MK",
          "RS",
          "SI",
          "KR",
          "BD",
          "PK",
          "LK",
          "GH",
          "KE",
          "NG",
          "TZ",
          "UG",
          "AG",
          "AM",
          "BS",
          "BB",
          "BZ",
          "BT",
          "BW",
          "BF",
          "CV",
          "CW",
          "DM",
          "FJ",
          "GM",
          "GE",
          "GD",
          "GW",
          "GY",
          "HT",
          "JM",
          "KI",
          "LS",
          "LR",
          "MW",
          "MV",
          "ML",
          "MH",
          "FM",
          "NA",
          "NR",
          "NE",
          "PW",
          "PG",
          "WS",
          "SM",
          "ST",
          "SN",
          "SC",
          "SL",
          "SB",
          "KN",
          "LC",
          "VC",
          "SR",
          "TL",
          "TO",
          "TT",
          "TV",
          "VU",
          "AZ",
          "BN",
          "BI",
          "KH",
          "CM",
          "TD",
          "KM",
          "GQ",
          "SZ",
          "GA",
          "GN",
          "KG",
          "LA",
          "MO",
          "MR",
          "MN",
          "NP",
          "RW",
          "TG",
          "UZ",
          "ZW",
          "BJ",
          "MG",
          "MU",
          "MZ",
          "AO",
          "CI",
          "DJ",
          "ZM",
          "CD",
          "CG",
          "IQ",
          "LY",
          "TJ",
          "VE",
          "ET",
          "XK"
        ],
        "external_urls": {
          "spotify": "https://open.spotify.com/album/1xAQ6kW7DQZxTghyepHtzm"
        },
        "href": "https://api.spotify.com/v1/albums/1xAQ6kW7DQZxTghyepHtzm",
        "id": "1xAQ6kW7DQZxTghyepHtzm",
        "images": [
          {
            "height": 640,
            "url": "https://i.scdn.co/image/ab67616d0000b273d9e9436112102a62090fbff2",
            "width": 640
          },
          {
            "height": 300,
            "url": "https://i.scdn.co/image/ab67616d00001e02d9e9436112102a62090fbff2",
            "width": 300
          },
          {
            "height": 64,
            "url": "https://i.scdn.co/image/ab67616d00004851d9e9436112102a62090fbff2",
            "width": 64
          }
        ],
        "name": "Cores, Nomes",
        "release_date": "1982-01-01",
        "release_date_precision": "day",
        "total_tracks": 12,
        "type": "album",
        "uri": "spotify:album:1xAQ6kW7DQZxTghyepHtzm"
      },
      "artists": [
        {
          "external_urls": {
            "spotify": "https://open.spotify.com/artist/7HGNYPmbDrMkylWqeFCOIQ"
          },
          "href": "https://api.spotify.com/v1/artists/7HGNYPmbDrMkylWqeFCOIQ",
          "id": "7HGNYPmbDrMkylWqeFCOIQ",
          "name": "Caetano Veloso",
          "type": "artist",
          "uri": "spotify:artist:7HGNYPmbDrMkylWqeFCOIQ"
        }
      ],
      "available_markets": [
        "AR",
        "AU",
        "AT",
        "BE",
        "BO",
        "BR",
        "BG",
        "CA",
        "CL",
        "CO",
        "CR",
        "CY",
        "CZ",
        "DK",
        "DO",
        "DE",
        "EC",
        "EE",
        "SV",
        "FI",
        "FR",
        "GR",
        "GT",
        "HN",
        "HK",
        "HU",
        "IS",
        "IE",
        "IT",
        "LV",
        "LT",
        "LU",
        "MY",
        "MT",
        "MX",
        "NL",
        "NZ",
        "NI",
        "NO",
        "PA",
        "PY",
        "PE",
        "PH",
        "PL",
        "PT",
        "SG",
        "SK",
        "ES",
        "SE",
        "CH",
        "TW",
        "TR",
        "UY",
        "US",
        "GB",
        "AD",
        "LI",
        "MC",
        "ID",
        "JP",
        "TH",
        "VN",
        "RO",
        "IL",
        "ZA",
        "SA",
        "AE",
        "BH",
        "QA",
        "OM",
        "KW",
        "EG",
        "MA",
        "DZ",
        "TN",
        "LB",
        "JO",
        "PS",
        "IN",
        "BY",
        "KZ",
        "MD",
        "UA",
        "AL",
        "BA",
        "HR",
        "ME",
        "MK",
        "RS",
        "SI",
        "KR",
        "BD",
        "PK",
        "LK",
        "GH",
        "KE",
        "NG",
        "TZ",
        "UG",
        "AG",
        "AM",
        "BS",
        "BB",
        "BZ",
        "BT",
        "BW",
        "BF",
        "CV",
        "CW",
        "DM",
        "FJ",
        "GM",
        "GE",
        "GD",
        "GW",
        "GY",
        "HT",
        "JM",
        "KI",
        "LS",
        "LR",
        "MW",
        "MV",
        "ML",
        "MH",
        "FM",
        "NA",
        "NR",
        "NE",
        "PW",
        "PG",
        "WS",
        "SM",
        "ST",
        "SN",
        "SC",
        "SL",
        "SB",
        "KN",
        "LC",
        "VC",
        "SR",
        "TL",
        "TO",
        "TT",
        "TV",
        "VU",
        "AZ",
        "BN",
        "BI",
        "KH",
        "CM",
        "TD",
        "KM",
        "GQ",
        "SZ",
        "GA",
        "GN",
        "KG",
        "LA",
        "MO",
        "MR",
        "MN",
        "NP",
        "RW",
        "TG",
        "UZ",
        "ZW",
        "BJ",
        "MG",
        "MU",
        "MZ",
        "AO",
        "CI",
        "DJ",
        "ZM",
        "CD",
        "CG",
        "IQ",
        "LY",
        "TJ",
        "VE",
        "ET",
        "XK"
      ],
      "disc_number": 1,
      "duration_ms": 434960,
      "explicit": False,
      "external_ids": {
        "isrc": "BRMCA8200165"
      },
      "external_urls": {
        "spotify": "https://open.spotify.com/track/0WpeZok7zzqy1MHTcyWra0"
      },
      "href": "https://api.spotify.com/v1/tracks/0WpeZok7zzqy1MHTcyWra0",
      "id": "0WpeZok7zzqy1MHTcyWra0",
      "is_local": False,
      "name": "Ele Me Deu Um Beijo Na Boca (He Gave Me A Kiss On The Mouth)",
      "popularity": 27,
      "preview_url": "null",
      "track_number": 2,
      "type": "track",
      "uri": "spotify:track:0WpeZok7zzqy1MHTcyWra0"
    },
    {
      "album": {
        "album_type": "album",
        "artists": [
          {
            "external_urls": {
              "spotify": "https://open.spotify.com/artist/7HGNYPmbDrMkylWqeFCOIQ"
            },
            "href": "https://api.spotify.com/v1/artists/7HGNYPmbDrMkylWqeFCOIQ",
            "id": "7HGNYPmbDrMkylWqeFCOIQ",
            "name": "Caetano Veloso",
            "type": "artist",
            "uri": "spotify:artist:7HGNYPmbDrMkylWqeFCOIQ"
          }
        ],
        "available_markets": [
          "AR",
          "AU",
          "AT",
          "BE",
          "BO",
          "BR",
          "BG",
          "CA",
          "CL",
          "CO",
          "CR",
          "CY",
          "CZ",
          "DK",
          "DO",
          "DE",
          "EC",
          "EE",
          "SV",
          "FI",
          "FR",
          "GR",
          "GT",
          "HN",
          "HK",
          "HU",
          "IS",
          "IE",
          "IT",
          "LV",
          "LT",
          "LU",
          "MY",
          "MT",
          "MX",
          "NL",
          "NZ",
          "NI",
          "NO",
          "PA",
          "PY",
          "PE",
          "PH",
          "PL",
          "PT",
          "SG",
          "SK",
          "ES",
          "SE",
          "CH",
          "TW",
          "TR",
          "UY",
          "US",
          "GB",
          "AD",
          "LI",
          "MC",
          "ID",
          "JP",
          "TH",
          "VN",
          "RO",
          "IL",
          "ZA",
          "SA",
          "AE",
          "BH",
          "QA",
          "OM",
          "KW",
          "EG",
          "MA",
          "DZ",
          "TN",
          "LB",
          "JO",
          "PS",
          "IN",
          "BY",
          "KZ",
          "MD",
          "UA",
          "AL",
          "BA",
          "HR",
          "ME",
          "MK",
          "RS",
          "SI",
          "KR",
          "BD",
          "PK",
          "LK",
          "GH",
          "KE",
          "NG",
          "TZ",
          "UG",
          "AG",
          "AM",
          "BS",
          "BB",
          "BZ",
          "BT",
          "BW",
          "BF",
          "CV",
          "CW",
          "DM",
          "FJ",
          "GM",
          "GE",
          "GD",
          "GW",
          "GY",
          "HT",
          "JM",
          "KI",
          "LS",
          "LR",
          "MW",
          "MV",
          "ML",
          "MH",
          "FM",
          "NA",
          "NR",
          "NE",
          "PW",
          "PG",
          "WS",
          "SM",
          "ST",
          "SN",
          "SC",
          "SL",
          "SB",
          "KN",
          "LC",
          "VC",
          "SR",
          "TL",
          "TO",
          "TT",
          "TV",
          "VU",
          "AZ",
          "BN",
          "BI",
          "KH",
          "CM",
          "TD",
          "KM",
          "GQ",
          "SZ",
          "GA",
          "GN",
          "KG",
          "LA",
          "MO",
          "MR",
          "MN",
          "NP",
          "RW",
          "TG",
          "UZ",
          "ZW",
          "BJ",
          "MG",
          "MU",
          "MZ",
          "AO",
          "CI",
          "DJ",
          "ZM",
          "CD",
          "CG",
          "IQ",
          "LY",
          "TJ",
          "VE",
          "ET",
          "XK"
        ],
        "external_urls": {
          "spotify": "https://open.spotify.com/album/1xAQ6kW7DQZxTghyepHtzm"
        },
        "href": "https://api.spotify.com/v1/albums/1xAQ6kW7DQZxTghyepHtzm",
        "id": "1xAQ6kW7DQZxTghyepHtzm",
        "images": [
          {
            "height": 640,
            "url": "https://i.scdn.co/image/ab67616d0000b273d9e9436112102a62090fbff2",
            "width": 640
          },
          {
            "height": 300,
            "url": "https://i.scdn.co/image/ab67616d00001e02d9e9436112102a62090fbff2",
            "width": 300
          },
          {
            "height": 64,
            "url": "https://i.scdn.co/image/ab67616d00004851d9e9436112102a62090fbff2",
            "width": 64
          }
        ],
        "name": "Cores, Nomes",
        "release_date": "1982-01-01",
        "release_date_precision": "day",
        "total_tracks": 12,
        "type": "album",
        "uri": "spotify:album:1xAQ6kW7DQZxTghyepHtzm"
      },
      "artists": [
        {
          "external_urls": {
            "spotify": "https://open.spotify.com/artist/7HGNYPmbDrMkylWqeFCOIQ"
          },
          "href": "https://api.spotify.com/v1/artists/7HGNYPmbDrMkylWqeFCOIQ",
          "id": "7HGNYPmbDrMkylWqeFCOIQ",
          "name": "Caetano Veloso",
          "type": "artist",
          "uri": "spotify:artist:7HGNYPmbDrMkylWqeFCOIQ"
        }
      ],
      "available_markets": [
        "AR",
        "AU",
        "AT",
        "BE",
        "BO",
        "BR",
        "BG",
        "CA",
        "CL",
        "CO",
        "CR",
        "CY",
        "CZ",
        "DK",
        "DO",
        "DE",
        "EC",
        "EE",
        "SV",
        "FI",
        "FR",
        "GR",
        "GT",
        "HN",
        "HK",
        "HU",
        "IS",
        "IE",
        "IT",
        "LV",
        "LT",
        "LU",
        "MY",
        "MT",
        "MX",
        "NL",
        "NZ",
        "NI",
        "NO",
        "PA",
        "PY",
        "PE",
        "PH",
        "PL",
        "PT",
        "SG",
        "SK",
        "ES",
        "SE",
        "CH",
        "TW",
        "TR",
        "UY",
        "US",
        "GB",
        "AD",
        "LI",
        "MC",
        "ID",
        "JP",
        "TH",
        "VN",
        "RO",
        "IL",
        "ZA",
        "SA",
        "AE",
        "BH",
        "QA",
        "OM",
        "KW",
        "EG",
        "MA",
        "DZ",
        "TN",
        "LB",
        "JO",
        "PS",
        "IN",
        "BY",
        "KZ",
        "MD",
        "UA",
        "AL",
        "BA",
        "HR",
        "ME",
        "MK",
        "RS",
        "SI",
        "KR",
        "BD",
        "PK",
        "LK",
        "GH",
        "KE",
        "NG",
        "TZ",
        "UG",
        "AG",
        "AM",
        "BS",
        "BB",
        "BZ",
        "BT",
        "BW",
        "BF",
        "CV",
        "CW",
        "DM",
        "FJ",
        "GM",
        "GE",
        "GD",
        "GW",
        "GY",
        "HT",
        "JM",
        "KI",
        "LS",
        "LR",
        "MW",
        "MV",
        "ML",
        "MH",
        "FM",
        "NA",
        "NR",
        "NE",
        "PW",
        "PG",
        "WS",
        "SM",
        "ST",
        "SN",
        "SC",
        "SL",
        "SB",
        "KN",
        "LC",
        "VC",
        "SR",
        "TL",
        "TO",
        "TT",
        "TV",
        "VU",
        "AZ",
        "BN",
        "BI",
        "KH",
        "CM",
        "TD",
        "KM",
        "GQ",
        "SZ",
        "GA",
        "GN",
        "KG",
        "LA",
        "MO",
        "MR",
        "MN",
        "NP",
        "RW",
        "TG",
        "UZ",
        "ZW",
        "BJ",
        "MG",
        "MU",
        "MZ",
        "AO",
        "CI",
        "DJ",
        "ZM",
        "CD",
        "CG",
        "IQ",
        "LY",
        "TJ",
        "VE",
        "ET",
        "XK"
      ],
      "disc_number": 1,
      "duration_ms": 145733,
      "explicit": False,
      "external_ids": {
        "isrc": "BRMCA8200166"
      },
      "external_urls": {
        "spotify": "https://open.spotify.com/track/164RfzZqd5LYTsz8ZTfwFV"
      },
      "href": "https://api.spotify.com/v1/tracks/164RfzZqd5LYTsz8ZTfwFV",
      "id": "164RfzZqd5LYTsz8ZTfwFV",
      "is_local": False,
      "name": "Trem Das Cores",
      "popularity": 48,
      "preview_url": "null",
      "track_number": 3,
      "type": "track",
      "uri": "spotify:track:164RfzZqd5LYTsz8ZTfwFV"
    },
    {
      "album": {
        "album_type": "album",
        "artists": [
          {
            "external_urls": {
              "spotify": "https://open.spotify.com/artist/7HGNYPmbDrMkylWqeFCOIQ"
            },
            "href": "https://api.spotify.com/v1/artists/7HGNYPmbDrMkylWqeFCOIQ",
            "id": "7HGNYPmbDrMkylWqeFCOIQ",
            "name": "Caetano Veloso",
            "type": "artist",
            "uri": "spotify:artist:7HGNYPmbDrMkylWqeFCOIQ"
          }
        ],
        "available_markets": [
          "AR",
          "AU",
          "AT",
          "BE",
          "BO",
          "BR",
          "BG",
          "CA",
          "CL",
          "CO",
          "CR",
          "CY",
          "CZ",
          "DK",
          "DO",
          "DE",
          "EC",
          "EE",
          "SV",
          "FI",
          "FR",
          "GR",
          "GT",
          "HN",
          "HK",
          "HU",
          "IS",
          "IE",
          "IT",
          "LV",
          "LT",
          "LU",
          "MY",
          "MT",
          "MX",
          "NL",
          "NZ",
          "NI",
          "NO",
          "PA",
          "PY",
          "PE",
          "PH",
          "PL",
          "PT",
          "SG",
          "SK",
          "ES",
          "SE",
          "CH",
          "TW",
          "TR",
          "UY",
          "US",
          "GB",
          "AD",
          "LI",
          "MC",
          "ID",
          "JP",
          "TH",
          "VN",
          "RO",
          "IL",
          "ZA",
          "SA",
          "AE",
          "BH",
          "QA",
          "OM",
          "KW",
          "EG",
          "MA",
          "DZ",
          "TN",
          "LB",
          "JO",
          "PS",
          "IN",
          "BY",
          "KZ",
          "MD",
          "UA",
          "AL",
          "BA",
          "HR",
          "ME",
          "MK",
          "RS",
          "SI",
          "KR",
          "BD",
          "PK",
          "LK",
          "GH",
          "KE",
          "NG",
          "TZ",
          "UG",
          "AG",
          "AM",
          "BS",
          "BB",
          "BZ",
          "BT",
          "BW",
          "BF",
          "CV",
          "CW",
          "DM",
          "FJ",
          "GM",
          "GE",
          "GD",
          "GW",
          "GY",
          "HT",
          "JM",
          "KI",
          "LS",
          "LR",
          "MW",
          "MV",
          "ML",
          "MH",
          "FM",
          "NA",
          "NR",
          "NE",
          "PW",
          "PG",
          "WS",
          "SM",
          "ST",
          "SN",
          "SC",
          "SL",
          "SB",
          "KN",
          "LC",
          "VC",
          "SR",
          "TL",
          "TO",
          "TT",
          "TV",
          "VU",
          "AZ",
          "BN",
          "BI",
          "KH",
          "CM",
          "TD",
          "KM",
          "GQ",
          "SZ",
          "GA",
          "GN",
          "KG",
          "LA",
          "MO",
          "MR",
          "MN",
          "NP",
          "RW",
          "TG",
          "UZ",
          "ZW",
          "BJ",
          "MG",
          "MU",
          "MZ",
          "AO",
          "CI",
          "DJ",
          "ZM",
          "CD",
          "CG",
          "IQ",
          "LY",
          "TJ",
          "VE",
          "ET",
          "XK"
        ],
        "external_urls": {
          "spotify": "https://open.spotify.com/album/1xAQ6kW7DQZxTghyepHtzm"
        },
        "href": "https://api.spotify.com/v1/albums/1xAQ6kW7DQZxTghyepHtzm",
        "id": "1xAQ6kW7DQZxTghyepHtzm",
        "images": [
          {
            "height": 640,
            "url": "https://i.scdn.co/image/ab67616d0000b273d9e9436112102a62090fbff2",
            "width": 640
          },
          {
            "height": 300,
            "url": "https://i.scdn.co/image/ab67616d00001e02d9e9436112102a62090fbff2",
            "width": 300
          },
          {
            "height": 64,
            "url": "https://i.scdn.co/image/ab67616d00004851d9e9436112102a62090fbff2",
            "width": 64
          }
        ],
        "name": "Cores, Nomes",
        "release_date": "1982-01-01",
        "release_date_precision": "day",
        "total_tracks": 12,
        "type": "album",
        "uri": "spotify:album:1xAQ6kW7DQZxTghyepHtzm"
      },
      "artists": [
        {
          "external_urls": {
            "spotify": "https://open.spotify.com/artist/7HGNYPmbDrMkylWqeFCOIQ"
          },
          "href": "https://api.spotify.com/v1/artists/7HGNYPmbDrMkylWqeFCOIQ",
          "id": "7HGNYPmbDrMkylWqeFCOIQ",
          "name": "Caetano Veloso",
          "type": "artist",
          "uri": "spotify:artist:7HGNYPmbDrMkylWqeFCOIQ"
        }
      ],
      "available_markets": [
        "AR",
        "AU",
        "AT",
        "BE",
        "BO",
        "BR",
        "BG",
        "CA",
        "CL",
        "CO",
        "CR",
        "CY",
        "CZ",
        "DK",
        "DO",
        "DE",
        "EC",
        "EE",
        "SV",
        "FI",
        "FR",
        "GR",
        "GT",
        "HN",
        "HK",
        "HU",
        "IS",
        "IE",
        "IT",
        "LV",
        "LT",
        "LU",
        "MY",
        "MT",
        "MX",
        "NL",
        "NZ",
        "NI",
        "NO",
        "PA",
        "PY",
        "PE",
        "PH",
        "PL",
        "PT",
        "SG",
        "SK",
        "ES",
        "SE",
        "CH",
        "TW",
        "TR",
        "UY",
        "US",
        "GB",
        "AD",
        "LI",
        "MC",
        "ID",
        "JP",
        "TH",
        "VN",
        "RO",
        "IL",
        "ZA",
        "SA",
        "AE",
        "BH",
        "QA",
        "OM",
        "KW",
        "EG",
        "MA",
        "DZ",
        "TN",
        "LB",
        "JO",
        "PS",
        "IN",
        "BY",
        "KZ",
        "MD",
        "UA",
        "AL",
        "BA",
        "HR",
        "ME",
        "MK",
        "RS",
        "SI",
        "KR",
        "BD",
        "PK",
        "LK",
        "GH",
        "KE",
        "NG",
        "TZ",
        "UG",
        "AG",
        "AM",
        "BS",
        "BB",
        "BZ",
        "BT",
        "BW",
        "BF",
        "CV",
        "CW",
        "DM",
        "FJ",
        "GM",
        "GE",
        "GD",
        "GW",
        "GY",
        "HT",
        "JM",
        "KI",
        "LS",
        "LR",
        "MW",
        "MV",
        "ML",
        "MH",
        "FM",
        "NA",
        "NR",
        "NE",
        "PW",
        "PG",
        "WS",
        "SM",
        "ST",
        "SN",
        "SC",
        "SL",
        "SB",
        "KN",
        "LC",
        "VC",
        "SR",
        "TL",
        "TO",
        "TT",
        "TV",
        "VU",
        "AZ",
        "BN",
        "BI",
        "KH",
        "CM",
        "TD",
        "KM",
        "GQ",
        "SZ",
        "GA",
        "GN",
        "KG",
        "LA",
        "MO",
        "MR",
        "MN",
        "NP",
        "RW",
        "TG",
        "UZ",
        "ZW",
        "BJ",
        "MG",
        "MU",
        "MZ",
        "AO",
        "CI",
        "DJ",
        "ZM",
        "CD",
        "CG",
        "IQ",
        "LY",
        "TJ",
        "VE",
        "ET",
        "XK"
      ],
      "disc_number": 1,
      "duration_ms": 139493,
      "explicit": False,
      "external_ids": {
        "isrc": "BRMCA8200167"
      },
      "external_urls": {
        "spotify": "https://open.spotify.com/track/5bjZ9DtsiaUFRj3NPR6D0w"
      },
      "href": "https://api.spotify.com/v1/tracks/5bjZ9DtsiaUFRj3NPR6D0w",
      "id": "5bjZ9DtsiaUFRj3NPR6D0w",
      "is_local": False,
      "name": "Sete Mil Vezes",
      "popularity": 25,
      "preview_url": "null",
      "track_number": 4,
      "type": "track",
      "uri": "spotify:track:5bjZ9DtsiaUFRj3NPR6D0w"
    },
    {
      "album": {
        "album_type": "album",
        "artists": [
          {
            "external_urls": {
              "spotify": "https://open.spotify.com/artist/7HGNYPmbDrMkylWqeFCOIQ"
            },
            "href": "https://api.spotify.com/v1/artists/7HGNYPmbDrMkylWqeFCOIQ",
            "id": "7HGNYPmbDrMkylWqeFCOIQ",
            "name": "Caetano Veloso",
            "type": "artist",
            "uri": "spotify:artist:7HGNYPmbDrMkylWqeFCOIQ"
          }
        ],
        "available_markets": [
          "AR",
          "AU",
          "AT",
          "BE",
          "BO",
          "BR",
          "BG",
          "CA",
          "CL",
          "CO",
          "CR",
          "CY",
          "CZ",
          "DK",
          "DO",
          "DE",
          "EC",
          "EE",
          "SV",
          "FI",
          "FR",
          "GR",
          "GT",
          "HN",
          "HK",
          "HU",
          "IS",
          "IE",
          "IT",
          "LV",
          "LT",
          "LU",
          "MY",
          "MT",
          "MX",
          "NL",
          "NZ",
          "NI",
          "NO",
          "PA",
          "PY",
          "PE",
          "PH",
          "PL",
          "PT",
          "SG",
          "SK",
          "ES",
          "SE",
          "CH",
          "TW",
          "TR",
          "UY",
          "US",
          "GB",
          "AD",
          "LI",
          "MC",
          "ID",
          "JP",
          "TH",
          "VN",
          "RO",
          "IL",
          "ZA",
          "SA",
          "AE",
          "BH",
          "QA",
          "OM",
          "KW",
          "EG",
          "MA",
          "DZ",
          "TN",
          "LB",
          "JO",
          "PS",
          "IN",
          "BY",
          "KZ",
          "MD",
          "UA",
          "AL",
          "BA",
          "HR",
          "ME",
          "MK",
          "RS",
          "SI",
          "KR",
          "BD",
          "PK",
          "LK",
          "GH",
          "KE",
          "NG",
          "TZ",
          "UG",
          "AG",
          "AM",
          "BS",
          "BB",
          "BZ",
          "BT",
          "BW",
          "BF",
          "CV",
          "CW",
          "DM",
          "FJ",
          "GM",
          "GE",
          "GD",
          "GW",
          "GY",
          "HT",
          "JM",
          "KI",
          "LS",
          "LR",
          "MW",
          "MV",
          "ML",
          "MH",
          "FM",
          "NA",
          "NR",
          "NE",
          "PW",
          "PG",
          "WS",
          "SM",
          "ST",
          "SN",
          "SC",
          "SL",
          "SB",
          "KN",
          "LC",
          "VC",
          "SR",
          "TL",
          "TO",
          "TT",
          "TV",
          "VU",
          "AZ",
          "BN",
          "BI",
          "KH",
          "CM",
          "TD",
          "KM",
          "GQ",
          "SZ",
          "GA",
          "GN",
          "KG",
          "LA",
          "MO",
          "MR",
          "MN",
          "NP",
          "RW",
          "TG",
          "UZ",
          "ZW",
          "BJ",
          "MG",
          "MU",
          "MZ",
          "AO",
          "CI",
          "DJ",
          "ZM",
          "CD",
          "CG",
          "IQ",
          "LY",
          "TJ",
          "VE",
          "ET",
          "XK"
        ],
        "external_urls": {
          "spotify": "https://open.spotify.com/album/1xAQ6kW7DQZxTghyepHtzm"
        },
        "href": "https://api.spotify.com/v1/albums/1xAQ6kW7DQZxTghyepHtzm",
        "id": "1xAQ6kW7DQZxTghyepHtzm",
        "images": [
          {
            "height": 640,
            "url": "https://i.scdn.co/image/ab67616d0000b273d9e9436112102a62090fbff2",
            "width": 640
          },
          {
            "height": 300,
            "url": "https://i.scdn.co/image/ab67616d00001e02d9e9436112102a62090fbff2",
            "width": 300
          },
          {
            "height": 64,
            "url": "https://i.scdn.co/image/ab67616d00004851d9e9436112102a62090fbff2",
            "width": 64
          }
        ],
        "name": "Cores, Nomes",
        "release_date": "1982-01-01",
        "release_date_precision": "day",
        "total_tracks": 12,
        "type": "album",
        "uri": "spotify:album:1xAQ6kW7DQZxTghyepHtzm"
      },
      "artists": [
        {
          "external_urls": {
            "spotify": "https://open.spotify.com/artist/7HGNYPmbDrMkylWqeFCOIQ"
          },
          "href": "https://api.spotify.com/v1/artists/7HGNYPmbDrMkylWqeFCOIQ",
          "id": "7HGNYPmbDrMkylWqeFCOIQ",
          "name": "Caetano Veloso",
          "type": "artist",
          "uri": "spotify:artist:7HGNYPmbDrMkylWqeFCOIQ"
        }
      ],
      "available_markets": [
        "AR",
        "AU",
        "AT",
        "BE",
        "BO",
        "BR",
        "BG",
        "CA",
        "CL",
        "CO",
        "CR",
        "CY",
        "CZ",
        "DK",
        "DO",
        "DE",
        "EC",
        "EE",
        "SV",
        "FI",
        "FR",
        "GR",
        "GT",
        "HN",
        "HK",
        "HU",
        "IS",
        "IE",
        "IT",
        "LV",
        "LT",
        "LU",
        "MY",
        "MT",
        "MX",
        "NL",
        "NZ",
        "NI",
        "NO",
        "PA",
        "PY",
        "PE",
        "PH",
        "PL",
        "PT",
        "SG",
        "SK",
        "ES",
        "SE",
        "CH",
        "TW",
        "TR",
        "UY",
        "US",
        "GB",
        "AD",
        "LI",
        "MC",
        "ID",
        "JP",
        "TH",
        "VN",
        "RO",
        "IL",
        "ZA",
        "SA",
        "AE",
        "BH",
        "QA",
        "OM",
        "KW",
        "EG",
        "MA",
        "DZ",
        "TN",
        "LB",
        "JO",
        "PS",
        "IN",
        "BY",
        "KZ",
        "MD",
        "UA",
        "AL",
        "BA",
        "HR",
        "ME",
        "MK",
        "RS",
        "SI",
        "KR",
        "BD",
        "PK",
        "LK",
        "GH",
        "KE",
        "NG",
        "TZ",
        "UG",
        "AG",
        "AM",
        "BS",
        "BB",
        "BZ",
        "BT",
        "BW",
        "BF",
        "CV",
        "CW",
        "DM",
        "FJ",
        "GM",
        "GE",
        "GD",
        "GW",
        "GY",
        "HT",
        "JM",
        "KI",
        "LS",
        "LR",
        "MW",
        "MV",
        "ML",
        "MH",
        "FM",
        "NA",
        "NR",
        "NE",
        "PW",
        "PG",
        "WS",
        "SM",
        "ST",
        "SN",
        "SC",
        "SL",
        "SB",
        "KN",
        "LC",
        "VC",
        "SR",
        "TL",
        "TO",
        "TT",
        "TV",
        "VU",
        "AZ",
        "BN",
        "BI",
        "KH",
        "CM",
        "TD",
        "KM",
        "GQ",
        "SZ",
        "GA",
        "GN",
        "KG",
        "LA",
        "MO",
        "MR",
        "MN",
        "NP",
        "RW",
        "TG",
        "UZ",
        "ZW",
        "BJ",
        "MG",
        "MU",
        "MZ",
        "AO",
        "CI",
        "DJ",
        "ZM",
        "CD",
        "CG",
        "IQ",
        "LY",
        "TJ",
        "VE",
        "ET",
        "XK"
      ],
      "disc_number": 1,
      "duration_ms": 155480,
      "explicit": False,
      "external_ids": {
        "isrc": "BRMCA8200168"
      },
      "external_urls": {
        "spotify": "https://open.spotify.com/track/4m692gebzDAVR4uG5kaGL2"
      },
      "href": "https://api.spotify.com/v1/tracks/4m692gebzDAVR4uG5kaGL2",
      "id": "4m692gebzDAVR4uG5kaGL2",
      "is_local": False,
      "name": "Coqueiro De Itapoã",
      "popularity": 26,
      "preview_url": "null",
      "track_number": 5,
      "type": "track",
      "uri": "spotify:track:4m692gebzDAVR4uG5kaGL2"
    },
    {
      "album": {
        "album_type": "album",
        "artists": [
          {
            "external_urls": {
              "spotify": "https://open.spotify.com/artist/7HGNYPmbDrMkylWqeFCOIQ"
            },
            "href": "https://api.spotify.com/v1/artists/7HGNYPmbDrMkylWqeFCOIQ",
            "id": "7HGNYPmbDrMkylWqeFCOIQ",
            "name": "Caetano Veloso",
            "type": "artist",
            "uri": "spotify:artist:7HGNYPmbDrMkylWqeFCOIQ"
          }
        ],
        "available_markets": [
          "AR",
          "AU",
          "AT",
          "BE",
          "BO",
          "BR",
          "BG",
          "CA",
          "CL",
          "CO",
          "CR",
          "CY",
          "CZ",
          "DK",
          "DO",
          "DE",
          "EC",
          "EE",
          "SV",
          "FI",
          "FR",
          "GR",
          "GT",
          "HN",
          "HK",
          "HU",
          "IS",
          "IE",
          "IT",
          "LV",
          "LT",
          "LU",
          "MY",
          "MT",
          "MX",
          "NL",
          "NZ",
          "NI",
          "NO",
          "PA",
          "PY",
          "PE",
          "PH",
          "PL",
          "PT",
          "SG",
          "SK",
          "ES",
          "SE",
          "CH",
          "TW",
          "TR",
          "UY",
          "US",
          "GB",
          "AD",
          "LI",
          "MC",
          "ID",
          "JP",
          "TH",
          "VN",
          "RO",
          "IL",
          "ZA",
          "SA",
          "AE",
          "BH",
          "QA",
          "OM",
          "KW",
          "EG",
          "MA",
          "DZ",
          "TN",
          "LB",
          "JO",
          "PS",
          "IN",
          "BY",
          "KZ",
          "MD",
          "UA",
          "AL",
          "BA",
          "HR",
          "ME",
          "MK",
          "RS",
          "SI",
          "KR",
          "BD",
          "PK",
          "LK",
          "GH",
          "KE",
          "NG",
          "TZ",
          "UG",
          "AG",
          "AM",
          "BS",
          "BB",
          "BZ",
          "BT",
          "BW",
          "BF",
          "CV",
          "CW",
          "DM",
          "FJ",
          "GM",
          "GE",
          "GD",
          "GW",
          "GY",
          "HT",
          "JM",
          "KI",
          "LS",
          "LR",
          "MW",
          "MV",
          "ML",
          "MH",
          "FM",
          "NA",
          "NR",
          "NE",
          "PW",
          "PG",
          "WS",
          "SM",
          "ST",
          "SN",
          "SC",
          "SL",
          "SB",
          "KN",
          "LC",
          "VC",
          "SR",
          "TL",
          "TO",
          "TT",
          "TV",
          "VU",
          "AZ",
          "BN",
          "BI",
          "KH",
          "CM",
          "TD",
          "KM",
          "GQ",
          "SZ",
          "GA",
          "GN",
          "KG",
          "LA",
          "MO",
          "MR",
          "MN",
          "NP",
          "RW",
          "TG",
          "UZ",
          "ZW",
          "BJ",
          "MG",
          "MU",
          "MZ",
          "AO",
          "CI",
          "DJ",
          "ZM",
          "CD",
          "CG",
          "IQ",
          "LY",
          "TJ",
          "VE",
          "ET",
          "XK"
        ],
        "external_urls": {
          "spotify": "https://open.spotify.com/album/1xAQ6kW7DQZxTghyepHtzm"
        },
        "href": "https://api.spotify.com/v1/albums/1xAQ6kW7DQZxTghyepHtzm",
        "id": "1xAQ6kW7DQZxTghyepHtzm",
        "images": [
          {
            "height": 640,
            "url": "https://i.scdn.co/image/ab67616d0000b273d9e9436112102a62090fbff2",
            "width": 640
          },
          {
            "height": 300,
            "url": "https://i.scdn.co/image/ab67616d00001e02d9e9436112102a62090fbff2",
            "width": 300
          },
          {
            "height": 64,
            "url": "https://i.scdn.co/image/ab67616d00004851d9e9436112102a62090fbff2",
            "width": 64
          }
        ],
        "name": "Cores, Nomes",
        "release_date": "1982-01-01",
        "release_date_precision": "day",
        "total_tracks": 12,
        "type": "album",
        "uri": "spotify:album:1xAQ6kW7DQZxTghyepHtzm"
      },
      "artists": [
        {
          "external_urls": {
            "spotify": "https://open.spotify.com/artist/7HGNYPmbDrMkylWqeFCOIQ"
          },
          "href": "https://api.spotify.com/v1/artists/7HGNYPmbDrMkylWqeFCOIQ",
          "id": "7HGNYPmbDrMkylWqeFCOIQ",
          "name": "Caetano Veloso",
          "type": "artist",
          "uri": "spotify:artist:7HGNYPmbDrMkylWqeFCOIQ"
        }
      ],
      "available_markets": [
        "AR",
        "AU",
        "AT",
        "BE",
        "BO",
        "BR",
        "BG",
        "CA",
        "CL",
        "CO",
        "CR",
        "CY",
        "CZ",
        "DK",
        "DO",
        "DE",
        "EC",
        "EE",
        "SV",
        "FI",
        "FR",
        "GR",
        "GT",
        "HN",
        "HK",
        "HU",
        "IS",
        "IE",
        "IT",
        "LV",
        "LT",
        "LU",
        "MY",
        "MT",
        "MX",
        "NL",
        "NZ",
        "NI",
        "NO",
        "PA",
        "PY",
        "PE",
        "PH",
        "PL",
        "PT",
        "SG",
        "SK",
        "ES",
        "SE",
        "CH",
        "TW",
        "TR",
        "UY",
        "US",
        "GB",
        "AD",
        "LI",
        "MC",
        "ID",
        "JP",
        "TH",
        "VN",
        "RO",
        "IL",
        "ZA",
        "SA",
        "AE",
        "BH",
        "QA",
        "OM",
        "KW",
        "EG",
        "MA",
        "DZ",
        "TN",
        "LB",
        "JO",
        "PS",
        "IN",
        "BY",
        "KZ",
        "MD",
        "UA",
        "AL",
        "BA",
        "HR",
        "ME",
        "MK",
        "RS",
        "SI",
        "KR",
        "BD",
        "PK",
        "LK",
        "GH",
        "KE",
        "NG",
        "TZ",
        "UG",
        "AG",
        "AM",
        "BS",
        "BB",
        "BZ",
        "BT",
        "BW",
        "BF",
        "CV",
        "CW",
        "DM",
        "FJ",
        "GM",
        "GE",
        "GD",
        "GW",
        "GY",
        "HT",
        "JM",
        "KI",
        "LS",
        "LR",
        "MW",
        "MV",
        "ML",
        "MH",
        "FM",
        "NA",
        "NR",
        "NE",
        "PW",
        "PG",
        "WS",
        "SM",
        "ST",
        "SN",
        "SC",
        "SL",
        "SB",
        "KN",
        "LC",
        "VC",
        "SR",
        "TL",
        "TO",
        "TT",
        "TV",
        "VU",
        "AZ",
        "BN",
        "BI",
        "KH",
        "CM",
        "TD",
        "KM",
        "GQ",
        "SZ",
        "GA",
        "GN",
        "KG",
        "LA",
        "MO",
        "MR",
        "MN",
        "NP",
        "RW",
        "TG",
        "UZ",
        "ZW",
        "BJ",
        "MG",
        "MU",
        "MZ",
        "AO",
        "CI",
        "DJ",
        "ZM",
        "CD",
        "CG",
        "IQ",
        "LY",
        "TJ",
        "VE",
        "ET",
        "XK"
      ],
      "disc_number": 1,
      "duration_ms": 182226,
      "explicit": False,
      "external_ids": {
        "isrc": "BRMCA8200169"
      },
      "external_urls": {
        "spotify": "https://open.spotify.com/track/1kQoWGnB64fQcjg8TOHT8g"
      },
      "href": "https://api.spotify.com/v1/tracks/1kQoWGnB64fQcjg8TOHT8g",
      "id": "1kQoWGnB64fQcjg8TOHT8g",
      "is_local": False,
      "name": "Um Canto De Afoxé Para O Bloco Do Ilê",
      "popularity": 33,
      "preview_url": "null",
      "track_number": 6,
      "type": "track",
      "uri": "spotify:track:1kQoWGnB64fQcjg8TOHT8g"
    },
    {
      "album": {
        "album_type": "album",
        "artists": [
          {
            "external_urls": {
              "spotify": "https://open.spotify.com/artist/7HGNYPmbDrMkylWqeFCOIQ"
            },
            "href": "https://api.spotify.com/v1/artists/7HGNYPmbDrMkylWqeFCOIQ",
            "id": "7HGNYPmbDrMkylWqeFCOIQ",
            "name": "Caetano Veloso",
            "type": "artist",
            "uri": "spotify:artist:7HGNYPmbDrMkylWqeFCOIQ"
          }
        ],
        "available_markets": [
          "AR",
          "AU",
          "AT",
          "BE",
          "BO",
          "BR",
          "BG",
          "CA",
          "CL",
          "CO",
          "CR",
          "CY",
          "CZ",
          "DK",
          "DO",
          "DE",
          "EC",
          "EE",
          "SV",
          "FI",
          "FR",
          "GR",
          "GT",
          "HN",
          "HK",
          "HU",
          "IS",
          "IE",
          "IT",
          "LV",
          "LT",
          "LU",
          "MY",
          "MT",
          "MX",
          "NL",
          "NZ",
          "NI",
          "NO",
          "PA",
          "PY",
          "PE",
          "PH",
          "PL",
          "PT",
          "SG",
          "SK",
          "ES",
          "SE",
          "CH",
          "TW",
          "TR",
          "UY",
          "US",
          "GB",
          "AD",
          "LI",
          "MC",
          "ID",
          "JP",
          "TH",
          "VN",
          "RO",
          "IL",
          "ZA",
          "SA",
          "AE",
          "BH",
          "QA",
          "OM",
          "KW",
          "EG",
          "MA",
          "DZ",
          "TN",
          "LB",
          "JO",
          "PS",
          "IN",
          "BY",
          "KZ",
          "MD",
          "UA",
          "AL",
          "BA",
          "HR",
          "ME",
          "MK",
          "RS",
          "SI",
          "KR",
          "BD",
          "PK",
          "LK",
          "GH",
          "KE",
          "NG",
          "TZ",
          "UG",
          "AG",
          "AM",
          "BS",
          "BB",
          "BZ",
          "BT",
          "BW",
          "BF",
          "CV",
          "CW",
          "DM",
          "FJ",
          "GM",
          "GE",
          "GD",
          "GW",
          "GY",
          "HT",
          "JM",
          "KI",
          "LS",
          "LR",
          "MW",
          "MV",
          "ML",
          "MH",
          "FM",
          "NA",
          "NR",
          "NE",
          "PW",
          "PG",
          "WS",
          "SM",
          "ST",
          "SN",
          "SC",
          "SL",
          "SB",
          "KN",
          "LC",
          "VC",
          "SR",
          "TL",
          "TO",
          "TT",
          "TV",
          "VU",
          "AZ",
          "BN",
          "BI",
          "KH",
          "CM",
          "TD",
          "KM",
          "GQ",
          "SZ",
          "GA",
          "GN",
          "KG",
          "LA",
          "MO",
          "MR",
          "MN",
          "NP",
          "RW",
          "TG",
          "UZ",
          "ZW",
          "BJ",
          "MG",
          "MU",
          "MZ",
          "AO",
          "CI",
          "DJ",
          "ZM",
          "CD",
          "CG",
          "IQ",
          "LY",
          "TJ",
          "VE",
          "ET",
          "XK"
        ],
        "external_urls": {
          "spotify": "https://open.spotify.com/album/1xAQ6kW7DQZxTghyepHtzm"
        },
        "href": "https://api.spotify.com/v1/albums/1xAQ6kW7DQZxTghyepHtzm",
        "id": "1xAQ6kW7DQZxTghyepHtzm",
        "images": [
          {
            "height": 640,
            "url": "https://i.scdn.co/image/ab67616d0000b273d9e9436112102a62090fbff2",
            "width": 640
          },
          {
            "height": 300,
            "url": "https://i.scdn.co/image/ab67616d00001e02d9e9436112102a62090fbff2",
            "width": 300
          },
          {
            "height": 64,
            "url": "https://i.scdn.co/image/ab67616d00004851d9e9436112102a62090fbff2",
            "width": 64
          }
        ],
        "name": "Cores, Nomes",
        "release_date": "1982-01-01",
        "release_date_precision": "day",
        "total_tracks": 12,
        "type": "album",
        "uri": "spotify:album:1xAQ6kW7DQZxTghyepHtzm"
      },
      "artists": [
        {
          "external_urls": {
            "spotify": "https://open.spotify.com/artist/7HGNYPmbDrMkylWqeFCOIQ"
          },
          "href": "https://api.spotify.com/v1/artists/7HGNYPmbDrMkylWqeFCOIQ",
          "id": "7HGNYPmbDrMkylWqeFCOIQ",
          "name": "Caetano Veloso",
          "type": "artist",
          "uri": "spotify:artist:7HGNYPmbDrMkylWqeFCOIQ"
        }
      ],
      "available_markets": [
        "AR",
        "AU",
        "AT",
        "BE",
        "BO",
        "BR",
        "BG",
        "CA",
        "CL",
        "CO",
        "CR",
        "CY",
        "CZ",
        "DK",
        "DO",
        "DE",
        "EC",
        "EE",
        "SV",
        "FI",
        "FR",
        "GR",
        "GT",
        "HN",
        "HK",
        "HU",
        "IS",
        "IE",
        "IT",
        "LV",
        "LT",
        "LU",
        "MY",
        "MT",
        "MX",
        "NL",
        "NZ",
        "NI",
        "NO",
        "PA",
        "PY",
        "PE",
        "PH",
        "PL",
        "PT",
        "SG",
        "SK",
        "ES",
        "SE",
        "CH",
        "TW",
        "TR",
        "UY",
        "US",
        "GB",
        "AD",
        "LI",
        "MC",
        "ID",
        "JP",
        "TH",
        "VN",
        "RO",
        "IL",
        "ZA",
        "SA",
        "AE",
        "BH",
        "QA",
        "OM",
        "KW",
        "EG",
        "MA",
        "DZ",
        "TN",
        "LB",
        "JO",
        "PS",
        "IN",
        "BY",
        "KZ",
        "MD",
        "UA",
        "AL",
        "BA",
        "HR",
        "ME",
        "MK",
        "RS",
        "SI",
        "KR",
        "BD",
        "PK",
        "LK",
        "GH",
        "KE",
        "NG",
        "TZ",
        "UG",
        "AG",
        "AM",
        "BS",
        "BB",
        "BZ",
        "BT",
        "BW",
        "BF",
        "CV",
        "CW",
        "DM",
        "FJ",
        "GM",
        "GE",
        "GD",
        "GW",
        "GY",
        "HT",
        "JM",
        "KI",
        "LS",
        "LR",
        "MW",
        "MV",
        "ML",
        "MH",
        "FM",
        "NA",
        "NR",
        "NE",
        "PW",
        "PG",
        "WS",
        "SM",
        "ST",
        "SN",
        "SC",
        "SL",
        "SB",
        "KN",
        "LC",
        "VC",
        "SR",
        "TL",
        "TO",
        "TT",
        "TV",
        "VU",
        "AZ",
        "BN",
        "BI",
        "KH",
        "CM",
        "TD",
        "KM",
        "GQ",
        "SZ",
        "GA",
        "GN",
        "KG",
        "LA",
        "MO",
        "MR",
        "MN",
        "NP",
        "RW",
        "TG",
        "UZ",
        "ZW",
        "BJ",
        "MG",
        "MU",
        "MZ",
        "AO",
        "CI",
        "DJ",
        "ZM",
        "CD",
        "CG",
        "IQ",
        "LY",
        "TJ",
        "VE",
        "ET",
        "XK"
      ],
      "disc_number": 1,
      "duration_ms": 223466,
      "explicit": False,
      "external_ids": {
        "isrc": "BRMCA8200175"
      },
      "external_urls": {
        "spotify": "https://open.spotify.com/track/3kuAEbv5CUREb4010lHCdw"
      },
      "href": "https://api.spotify.com/v1/tracks/3kuAEbv5CUREb4010lHCdw",
      "id": "3kuAEbv5CUREb4010lHCdw",
      "is_local": False,
      "name": "Cavaleiro De Jorge",
      "popularity": 24,
      "preview_url": "null",
      "track_number": 7,
      "type": "track",
      "uri": "spotify:track:3kuAEbv5CUREb4010lHCdw"
    }
  ]
}

# %%
def process_queue(resp, jk_list):

    np = resp['currently_playing']

    now_playing = {}
    now_playing['album_name'] = np['album']['name']
    now_playing['url'] = np['album']['images'][0]['url']
    now_playing['name'] = np['name']
    artistas = np['artists'][0]['name']
    if len(np['artists']) > 1:
        for artist in np['artists'][1:]:
            artistas = artistas + "&" + artist['name']
    now_playing['artist'] = artistas

    queue = resp['queue']
    juke_queue = []
    house_queue = []
    for song in queue:
        song_dict = {}
        song_dict['album_name'] = song['album']['name']
        song_dict['url'] = song['album']['images'][0]['url']
        song_dict['name'] = song['name']
        artistas = song['artists'][0]['name']
        if len(song['artists']) > 1:
            for artist in song['artists'][1:]:
                artistas = artistas + "&" + artist['name']
        song_dict['artist'] = artistas
        if song['id'] in jk_list:
            juke_queue.append(song_dict)
            jk_list.remove(song['id'])
        else:
            house_queue.append(song_dict)
    return now_playing, juke_queue, house_queue

# %%
now_playing, juke_queue, house_queue = process_queue(resp, ["1NIAQbzrcpqoaZd3sNFFKJ", "6Wk6A8k7NjjSsPQT9Z3FXM"])

# %%
juke_queue
# Out:
# [{'album_name': 'Cores, Nomes',
#   'url': 'https://i.scdn.co/image/ab67616d0000b273d9e9436112102a62090fbff2',
#   'name': 'Queixa',
#   'artist': 'Caetano Veloso'},
#  {'album_name': 'The Reckoning',
#   'url': 'https://i.scdn.co/image/ab67616d0000b273d8b7f29b1da971d65059d858',
#   'name': 'Reckoning Song',
#   'artist': 'Asaf Avidan&The Mojos'},
#  {'album_name': 'Cores, Nomes',
#   'url': 'https://i.scdn.co/image/ab67616d0000b273d9e9436112102a62090fbff2',
#   'name': 'Queixa',
#   'artist': 'Caetano Veloso'}]

# %%
search = {
  "tracks": {
    "href": "https://api.spotify.com/v1/search?offset=0&limit=20&query=Mutantes&type=track&market=BR&locale=pt-BR,pt;q%3D0.9,es-ES;q%3D0.8,es;q%3D0.7,zh-TW;q%3D0.6,zh;q%3D0.5",
    "limit": 20,
    "next": "https://api.spotify.com/v1/search?offset=20&limit=20&query=Mutantes&type=track&market=BR&locale=pt-BR,pt;q%3D0.9,es-ES;q%3D0.8,es;q%3D0.7,zh-TW;q%3D0.6,zh;q%3D0.5",
    "offset": 0,
    "previous": "null",
    "total": 907,
    "items": [
      {
        "album": {
          "album_type": "album",
          "artists": [
            {
              "external_urls": {
                "spotify": "https://open.spotify.com/artist/5C0gCCG8N5Dh5dZytIgzLX"
              },
              "href": "https://api.spotify.com/v1/artists/5C0gCCG8N5Dh5dZytIgzLX",
              "id": "5C0gCCG8N5Dh5dZytIgzLX",
              "name": "Os Mutantes",
              "type": "artist",
              "uri": "spotify:artist:5C0gCCG8N5Dh5dZytIgzLX"
            }
          ],
          "external_urls": {
            "spotify": "https://open.spotify.com/album/0RBkIFbQy91qv8Tqja20og"
          },
          "href": "https://api.spotify.com/v1/albums/0RBkIFbQy91qv8Tqja20og",
          "id": "0RBkIFbQy91qv8Tqja20og",
          "images": [
            {
              "height": 640,
              "width": 640,
              "url": "https://i.scdn.co/image/ab67616d0000b273cf5f9eaa0d3a164305c35b49"
            },
            {
              "height": 300,
              "width": 300,
              "url": "https://i.scdn.co/image/ab67616d00001e02cf5f9eaa0d3a164305c35b49"
            },
            {
              "height": 64,
              "width": 64,
              "url": "https://i.scdn.co/image/ab67616d00004851cf5f9eaa0d3a164305c35b49"
            }
          ],
          "is_playable": True,
          "name": "\"Os Mutantes\"",
          "release_date": "1968-01-01",
          "release_date_precision": "day",
          "total_tracks": 11,
          "type": "album",
          "uri": "spotify:album:0RBkIFbQy91qv8Tqja20og"
        },
        "artists": [
          {
            "external_urls": {
              "spotify": "https://open.spotify.com/artist/5C0gCCG8N5Dh5dZytIgzLX"
            },
            "href": "https://api.spotify.com/v1/artists/5C0gCCG8N5Dh5dZytIgzLX",
            "id": "5C0gCCG8N5Dh5dZytIgzLX",
            "name": "Os Mutantes",
            "type": "artist",
            "uri": "spotify:artist:5C0gCCG8N5Dh5dZytIgzLX"
          }
        ],
        "disc_number": 1,
        "duration_ms": 284986,
        "explicit": False,
        "external_ids": {
          "isrc": "BRPGD6800016"
        },
        "external_urls": {
          "spotify": "https://open.spotify.com/track/0lGEWOZvMexZFXckBJxlVO"
        },
        "href": "https://api.spotify.com/v1/tracks/0lGEWOZvMexZFXckBJxlVO",
        "id": "0lGEWOZvMexZFXckBJxlVO",
        "is_local": False,
        "is_playable": True,
        "name": "A Minha Menina",
        "popularity": 46,
        "preview_url": "null",
        "track_number": 2,
        "type": "track",
        "uri": "spotify:track:0lGEWOZvMexZFXckBJxlVO"
      },
      {
        "album": {
          "album_type": "album",
          "artists": [
            {
              "external_urls": {
                "spotify": "https://open.spotify.com/artist/5C0gCCG8N5Dh5dZytIgzLX"
              },
              "href": "https://api.spotify.com/v1/artists/5C0gCCG8N5Dh5dZytIgzLX",
              "id": "5C0gCCG8N5Dh5dZytIgzLX",
              "name": "Os Mutantes",
              "type": "artist",
              "uri": "spotify:artist:5C0gCCG8N5Dh5dZytIgzLX"
            }
          ],
          "external_urls": {
            "spotify": "https://open.spotify.com/album/6bWR1KoGNbHBHLYWxcN9dm"
          },
          "href": "https://api.spotify.com/v1/albums/6bWR1KoGNbHBHLYWxcN9dm",
          "id": "6bWR1KoGNbHBHLYWxcN9dm",
          "images": [
            {
              "height": 640,
              "width": 640,
              "url": "https://i.scdn.co/image/ab67616d0000b2738ca048d1b50af5d465c62459"
            },
            {
              "height": 300,
              "width": 300,
              "url": "https://i.scdn.co/image/ab67616d00001e028ca048d1b50af5d465c62459"
            },
            {
              "height": 64,
              "width": 64,
              "url": "https://i.scdn.co/image/ab67616d000048518ca048d1b50af5d465c62459"
            }
          ],
          "is_playable": True,
          "name": "\"Mutantes E Seus Cometas No Pais Do Baurets\"",
          "release_date": "1972-01-01",
          "release_date_precision": "day",
          "total_tracks": 10,
          "type": "album",
          "uri": "spotify:album:6bWR1KoGNbHBHLYWxcN9dm"
        },
        "artists": [
          {
            "external_urls": {
              "spotify": "https://open.spotify.com/artist/5C0gCCG8N5Dh5dZytIgzLX"
            },
            "href": "https://api.spotify.com/v1/artists/5C0gCCG8N5Dh5dZytIgzLX",
            "id": "5C0gCCG8N5Dh5dZytIgzLX",
            "name": "Os Mutantes",
            "type": "artist",
            "uri": "spotify:artist:5C0gCCG8N5Dh5dZytIgzLX"
          }
        ],
        "disc_number": 1,
        "duration_ms": 240706,
        "explicit": False,
        "external_ids": {
          "isrc": "BRPGD7200054"
        },
        "external_urls": {
          "spotify": "https://open.spotify.com/track/0Gj6ROsip9fKX9BTKSyVu6"
        },
        "href": "https://api.spotify.com/v1/tracks/0Gj6ROsip9fKX9BTKSyVu6",
        "id": "0Gj6ROsip9fKX9BTKSyVu6",
        "is_local": False,
        "is_playable": True,
        "name": "Balada Do Louco",
        "popularity": 43,
        "preview_url": "null",
        "track_number": 6,
        "type": "track",
        "uri": "spotify:track:0Gj6ROsip9fKX9BTKSyVu6"
      },
      {
        "album": {
          "album_type": "album",
          "artists": [
            {
              "external_urls": {
                "spotify": "https://open.spotify.com/artist/5C0gCCG8N5Dh5dZytIgzLX"
              },
              "href": "https://api.spotify.com/v1/artists/5C0gCCG8N5Dh5dZytIgzLX",
              "id": "5C0gCCG8N5Dh5dZytIgzLX",
              "name": "Os Mutantes",
              "type": "artist",
              "uri": "spotify:artist:5C0gCCG8N5Dh5dZytIgzLX"
            }
          ],
          "external_urls": {
            "spotify": "https://open.spotify.com/album/63cmfLGQUMuPRwgllZmz6a"
          },
          "href": "https://api.spotify.com/v1/albums/63cmfLGQUMuPRwgllZmz6a",
          "id": "63cmfLGQUMuPRwgllZmz6a",
          "images": [
            {
              "height": 640,
              "width": 640,
              "url": "https://i.scdn.co/image/ab67616d0000b2734c4f9ca2a116887fc303cb97"
            },
            {
              "height": 300,
              "width": 300,
              "url": "https://i.scdn.co/image/ab67616d00001e024c4f9ca2a116887fc303cb97"
            },
            {
              "height": 64,
              "width": 64,
              "url": "https://i.scdn.co/image/ab67616d000048514c4f9ca2a116887fc303cb97"
            }
          ],
          "is_playable": True,
          "name": "\"Mutantes\"",
          "release_date": "1969-01-01",
          "release_date_precision": "day",
          "total_tracks": 11,
          "type": "album",
          "uri": "spotify:album:63cmfLGQUMuPRwgllZmz6a"
        },
        "artists": [
          {
            "external_urls": {
              "spotify": "https://open.spotify.com/artist/5C0gCCG8N5Dh5dZytIgzLX"
            },
            "href": "https://api.spotify.com/v1/artists/5C0gCCG8N5Dh5dZytIgzLX",
            "id": "5C0gCCG8N5Dh5dZytIgzLX",
            "name": "Os Mutantes",
            "type": "artist",
            "uri": "spotify:artist:5C0gCCG8N5Dh5dZytIgzLX"
          }
        ],
        "disc_number": 1,
        "duration_ms": 196053,
        "explicit": False,
        "external_ids": {
          "isrc": "BRMCA0500359"
        },
        "external_urls": {
          "spotify": "https://open.spotify.com/track/4fM2DdT03XruTYZfIvALUv"
        },
        "href": "https://api.spotify.com/v1/tracks/4fM2DdT03XruTYZfIvALUv",
        "id": "4fM2DdT03XruTYZfIvALUv",
        "is_local": False,
        "is_playable": True,
        "name": "Não Vá Se Perder Por Aí",
        "popularity": 27,
        "preview_url": "null",
        "track_number": 2,
        "type": "track",
        "uri": "spotify:track:4fM2DdT03XruTYZfIvALUv"
      },
      {
        "album": {
          "album_type": "album",
          "artists": [
            {
              "external_urls": {
                "spotify": "https://open.spotify.com/artist/5C0gCCG8N5Dh5dZytIgzLX"
              },
              "href": "https://api.spotify.com/v1/artists/5C0gCCG8N5Dh5dZytIgzLX",
              "id": "5C0gCCG8N5Dh5dZytIgzLX",
              "name": "Os Mutantes",
              "type": "artist",
              "uri": "spotify:artist:5C0gCCG8N5Dh5dZytIgzLX"
            }
          ],
          "external_urls": {
            "spotify": "https://open.spotify.com/album/7Brj8kqhEO9Zg4daamMieT"
          },
          "href": "https://api.spotify.com/v1/albums/7Brj8kqhEO9Zg4daamMieT",
          "id": "7Brj8kqhEO9Zg4daamMieT",
          "images": [
            {
              "height": 640,
              "width": 640,
              "url": "https://i.scdn.co/image/ab67616d0000b2730e25f3e044f691f07b958ddd"
            },
            {
              "height": 300,
              "width": 300,
              "url": "https://i.scdn.co/image/ab67616d00001e020e25f3e044f691f07b958ddd"
            },
            {
              "height": 64,
              "width": 64,
              "url": "https://i.scdn.co/image/ab67616d000048510e25f3e044f691f07b958ddd"
            }
          ],
          "is_playable": True,
          "name": "\"A Divina Comédia Ou Ando Meio Desligado\"",
          "release_date": "1970-01-01",
          "release_date_precision": "day",
          "total_tracks": 11,
          "type": "album",
          "uri": "spotify:album:7Brj8kqhEO9Zg4daamMieT"
        },
        "artists": [
          {
            "external_urls": {
              "spotify": "https://open.spotify.com/artist/5C0gCCG8N5Dh5dZytIgzLX"
            },
            "href": "https://api.spotify.com/v1/artists/5C0gCCG8N5Dh5dZytIgzLX",
            "id": "5C0gCCG8N5Dh5dZytIgzLX",
            "name": "Os Mutantes",
            "type": "artist",
            "uri": "spotify:artist:5C0gCCG8N5Dh5dZytIgzLX"
          }
        ],
        "disc_number": 1,
        "duration_ms": 285920,
        "explicit": False,
        "external_ids": {
          "isrc": "BRPGD7000016"
        },
        "external_urls": {
          "spotify": "https://open.spotify.com/track/1MhkTY7vEuWR0VfDefE6Lf"
        },
        "href": "https://api.spotify.com/v1/tracks/1MhkTY7vEuWR0VfDefE6Lf",
        "id": "1MhkTY7vEuWR0VfDefE6Lf",
        "is_local": False,
        "is_playable": True,
        "name": "Ando Meio Desligado",
        "popularity": 47,
        "preview_url": "null",
        "track_number": 1,
        "type": "track",
        "uri": "spotify:track:1MhkTY7vEuWR0VfDefE6Lf"
      },
      {
        "album": {
          "album_type": "album",
          "artists": [
            {
              "external_urls": {
                "spotify": "https://open.spotify.com/artist/5C0gCCG8N5Dh5dZytIgzLX"
              },
              "href": "https://api.spotify.com/v1/artists/5C0gCCG8N5Dh5dZytIgzLX",
              "id": "5C0gCCG8N5Dh5dZytIgzLX",
              "name": "Os Mutantes",
              "type": "artist",
              "uri": "spotify:artist:5C0gCCG8N5Dh5dZytIgzLX"
            }
          ],
          "external_urls": {
            "spotify": "https://open.spotify.com/album/7Brj8kqhEO9Zg4daamMieT"
          },
          "href": "https://api.spotify.com/v1/albums/7Brj8kqhEO9Zg4daamMieT",
          "id": "7Brj8kqhEO9Zg4daamMieT",
          "images": [
            {
              "height": 640,
              "width": 640,
              "url": "https://i.scdn.co/image/ab67616d0000b2730e25f3e044f691f07b958ddd"
            },
            {
              "height": 300,
              "width": 300,
              "url": "https://i.scdn.co/image/ab67616d00001e020e25f3e044f691f07b958ddd"
            },
            {
              "height": 64,
              "width": 64,
              "url": "https://i.scdn.co/image/ab67616d000048510e25f3e044f691f07b958ddd"
            }
          ],
          "is_playable": True,
          "name": "\"A Divina Comédia Ou Ando Meio Desligado\"",
          "release_date": "1970-01-01",
          "release_date_precision": "day",
          "total_tracks": 11,
          "type": "album",
          "uri": "spotify:album:7Brj8kqhEO9Zg4daamMieT"
        },
        "artists": [
          {
            "external_urls": {
              "spotify": "https://open.spotify.com/artist/5C0gCCG8N5Dh5dZytIgzLX"
            },
            "href": "https://api.spotify.com/v1/artists/5C0gCCG8N5Dh5dZytIgzLX",
            "id": "5C0gCCG8N5Dh5dZytIgzLX",
            "name": "Os Mutantes",
            "type": "artist",
            "uri": "spotify:artist:5C0gCCG8N5Dh5dZytIgzLX"
          }
        ],
        "disc_number": 1,
        "duration_ms": 167760,
        "explicit": False,
        "external_ids": {
          "isrc": "BRMCA7000016"
        },
        "external_urls": {
          "spotify": "https://open.spotify.com/track/2aZUjb1RksBi5TR71jK3Or"
        },
        "href": "https://api.spotify.com/v1/tracks/2aZUjb1RksBi5TR71jK3Or",
        "id": "2aZUjb1RksBi5TR71jK3Or",
        "is_local": False,
        "is_playable": True,
        "name": "Hey Boy",
        "popularity": 39,
        "preview_url": "null",
        "track_number": 6,
        "type": "track",
        "uri": "spotify:track:2aZUjb1RksBi5TR71jK3Or"
      },
      {
        "album": {
          "album_type": "album",
          "artists": [
            {
              "external_urls": {
                "spotify": "https://open.spotify.com/artist/5C0gCCG8N5Dh5dZytIgzLX"
              },
              "href": "https://api.spotify.com/v1/artists/5C0gCCG8N5Dh5dZytIgzLX",
              "id": "5C0gCCG8N5Dh5dZytIgzLX",
              "name": "Os Mutantes",
              "type": "artist",
              "uri": "spotify:artist:5C0gCCG8N5Dh5dZytIgzLX"
            }
          ],
          "external_urls": {
            "spotify": "https://open.spotify.com/album/0RBkIFbQy91qv8Tqja20og"
          },
          "href": "https://api.spotify.com/v1/albums/0RBkIFbQy91qv8Tqja20og",
          "id": "0RBkIFbQy91qv8Tqja20og",
          "images": [
            {
              "height": 640,
              "width": 640,
              "url": "https://i.scdn.co/image/ab67616d0000b273cf5f9eaa0d3a164305c35b49"
            },
            {
              "height": 300,
              "width": 300,
              "url": "https://i.scdn.co/image/ab67616d00001e02cf5f9eaa0d3a164305c35b49"
            },
            {
              "height": 64,
              "width": 64,
              "url": "https://i.scdn.co/image/ab67616d00004851cf5f9eaa0d3a164305c35b49"
            }
          ],
          "is_playable": True,
          "name": "\"Os Mutantes\"",
          "release_date": "1968-01-01",
          "release_date_precision": "day",
          "total_tracks": 11,
          "type": "album",
          "uri": "spotify:album:0RBkIFbQy91qv8Tqja20og"
        },
        "artists": [
          {
            "external_urls": {
              "spotify": "https://open.spotify.com/artist/5C0gCCG8N5Dh5dZytIgzLX"
            },
            "href": "https://api.spotify.com/v1/artists/5C0gCCG8N5Dh5dZytIgzLX",
            "id": "5C0gCCG8N5Dh5dZytIgzLX",
            "name": "Os Mutantes",
            "type": "artist",
            "uri": "spotify:artist:5C0gCCG8N5Dh5dZytIgzLX"
          }
        ],
        "disc_number": 1,
        "duration_ms": 220453,
        "explicit": False,
        "external_ids": {
          "isrc": "BRPGD6800015"
        },
        "external_urls": {
          "spotify": "https://open.spotify.com/track/0Dmnb3C3GaGdyjlyWaWLDr"
        },
        "href": "https://api.spotify.com/v1/tracks/0Dmnb3C3GaGdyjlyWaWLDr",
        "id": "0Dmnb3C3GaGdyjlyWaWLDr",
        "is_local": False,
        "is_playable": True,
        "name": "Panis Et Circenses",
        "popularity": 41,
        "preview_url": "null",
        "track_number": 1,
        "type": "track",
        "uri": "spotify:track:0Dmnb3C3GaGdyjlyWaWLDr"
      },
      {
        "album": {
          "album_type": "album",
          "artists": [
            {
              "external_urls": {
                "spotify": "https://open.spotify.com/artist/5C0gCCG8N5Dh5dZytIgzLX"
              },
              "href": "https://api.spotify.com/v1/artists/5C0gCCG8N5Dh5dZytIgzLX",
              "id": "5C0gCCG8N5Dh5dZytIgzLX",
              "name": "Os Mutantes",
              "type": "artist",
              "uri": "spotify:artist:5C0gCCG8N5Dh5dZytIgzLX"
            }
          ],
          "external_urls": {
            "spotify": "https://open.spotify.com/album/0RBkIFbQy91qv8Tqja20og"
          },
          "href": "https://api.spotify.com/v1/albums/0RBkIFbQy91qv8Tqja20og",
          "id": "0RBkIFbQy91qv8Tqja20og",
          "images": [
            {
              "height": 640,
              "width": 640,
              "url": "https://i.scdn.co/image/ab67616d0000b273cf5f9eaa0d3a164305c35b49"
            },
            {
              "height": 300,
              "width": 300,
              "url": "https://i.scdn.co/image/ab67616d00001e02cf5f9eaa0d3a164305c35b49"
            },
            {
              "height": 64,
              "width": 64,
              "url": "https://i.scdn.co/image/ab67616d00004851cf5f9eaa0d3a164305c35b49"
            }
          ],
          "is_playable": True,
          "name": "\"Os Mutantes\"",
          "release_date": "1968-01-01",
          "release_date_precision": "day",
          "total_tracks": 11,
          "type": "album",
          "uri": "spotify:album:0RBkIFbQy91qv8Tqja20og"
        },
        "artists": [
          {
            "external_urls": {
              "spotify": "https://open.spotify.com/artist/5C0gCCG8N5Dh5dZytIgzLX"
            },
            "href": "https://api.spotify.com/v1/artists/5C0gCCG8N5Dh5dZytIgzLX",
            "id": "5C0gCCG8N5Dh5dZytIgzLX",
            "name": "Os Mutantes",
            "type": "artist",
            "uri": "spotify:artist:5C0gCCG8N5Dh5dZytIgzLX"
          }
        ],
        "disc_number": 1,
        "duration_ms": 182186,
        "explicit": False,
        "external_ids": {
          "isrc": "BRPGD6800019"
        },
        "external_urls": {
          "spotify": "https://open.spotify.com/track/29UHuao7AZ79dWgHNYGh5s"
        },
        "href": "https://api.spotify.com/v1/tracks/29UHuao7AZ79dWgHNYGh5s",
        "id": "29UHuao7AZ79dWgHNYGh5s",
        "is_local": False,
        "is_playable": True,
        "name": "Baby",
        "popularity": 42,
        "preview_url": "null",
        "track_number": 5,
        "type": "track",
        "uri": "spotify:track:29UHuao7AZ79dWgHNYGh5s"
      },
      {
        "album": {
          "album_type": "album",
          "artists": [
            {
              "external_urls": {
                "spotify": "https://open.spotify.com/artist/5C0gCCG8N5Dh5dZytIgzLX"
              },
              "href": "https://api.spotify.com/v1/artists/5C0gCCG8N5Dh5dZytIgzLX",
              "id": "5C0gCCG8N5Dh5dZytIgzLX",
              "name": "Os Mutantes",
              "type": "artist",
              "uri": "spotify:artist:5C0gCCG8N5Dh5dZytIgzLX"
            }
          ],
          "external_urls": {
            "spotify": "https://open.spotify.com/album/63cmfLGQUMuPRwgllZmz6a"
          },
          "href": "https://api.spotify.com/v1/albums/63cmfLGQUMuPRwgllZmz6a",
          "id": "63cmfLGQUMuPRwgllZmz6a",
          "images": [
            {
              "height": 640,
              "width": 640,
              "url": "https://i.scdn.co/image/ab67616d0000b2734c4f9ca2a116887fc303cb97"
            },
            {
              "height": 300,
              "width": 300,
              "url": "https://i.scdn.co/image/ab67616d00001e024c4f9ca2a116887fc303cb97"
            },
            {
              "height": 64,
              "width": 64,
              "url": "https://i.scdn.co/image/ab67616d000048514c4f9ca2a116887fc303cb97"
            }
          ],
          "is_playable": True,
          "name": "\"Mutantes\"",
          "release_date": "1969-01-01",
          "release_date_precision": "day",
          "total_tracks": 11,
          "type": "album",
          "uri": "spotify:album:63cmfLGQUMuPRwgllZmz6a"
        },
        "artists": [
          {
            "external_urls": {
              "spotify": "https://open.spotify.com/artist/5C0gCCG8N5Dh5dZytIgzLX"
            },
            "href": "https://api.spotify.com/v1/artists/5C0gCCG8N5Dh5dZytIgzLX",
            "id": "5C0gCCG8N5Dh5dZytIgzLX",
            "name": "Os Mutantes",
            "type": "artist",
            "uri": "spotify:artist:5C0gCCG8N5Dh5dZytIgzLX"
          }
        ],
        "disc_number": 1,
        "duration_ms": 237280,
        "explicit": False,
        "external_ids": {
          "isrc": "BRMCA0500360"
        },
        "external_urls": {
          "spotify": "https://open.spotify.com/track/1e0RVHOoVW6emvP9gDNypY"
        },
        "href": "https://api.spotify.com/v1/tracks/1e0RVHOoVW6emvP9gDNypY",
        "id": "1e0RVHOoVW6emvP9gDNypY",
        "is_local": False,
        "is_playable": True,
        "name": "2001 (Dois Mil E Um)",
        "popularity": 31,
        "preview_url": "null",
        "track_number": 4,
        "type": "track",
        "uri": "spotify:track:1e0RVHOoVW6emvP9gDNypY"
      },
      {
        "album": {
          "album_type": "album",
          "artists": [
            {
              "external_urls": {
                "spotify": "https://open.spotify.com/artist/5C0gCCG8N5Dh5dZytIgzLX"
              },
              "href": "https://api.spotify.com/v1/artists/5C0gCCG8N5Dh5dZytIgzLX",
              "id": "5C0gCCG8N5Dh5dZytIgzLX",
              "name": "Os Mutantes",
              "type": "artist",
              "uri": "spotify:artist:5C0gCCG8N5Dh5dZytIgzLX"
            }
          ],
          "external_urls": {
            "spotify": "https://open.spotify.com/album/6bWR1KoGNbHBHLYWxcN9dm"
          },
          "href": "https://api.spotify.com/v1/albums/6bWR1KoGNbHBHLYWxcN9dm",
          "id": "6bWR1KoGNbHBHLYWxcN9dm",
          "images": [
            {
              "height": 640,
              "width": 640,
              "url": "https://i.scdn.co/image/ab67616d0000b2738ca048d1b50af5d465c62459"
            },
            {
              "height": 300,
              "width": 300,
              "url": "https://i.scdn.co/image/ab67616d00001e028ca048d1b50af5d465c62459"
            },
            {
              "height": 64,
              "width": 64,
              "url": "https://i.scdn.co/image/ab67616d000048518ca048d1b50af5d465c62459"
            }
          ],
          "is_playable": True,
          "name": "\"Mutantes E Seus Cometas No Pais Do Baurets\"",
          "release_date": "1972-01-01",
          "release_date_precision": "day",
          "total_tracks": 10,
          "type": "album",
          "uri": "spotify:album:6bWR1KoGNbHBHLYWxcN9dm"
        },
        "artists": [
          {
            "external_urls": {
              "spotify": "https://open.spotify.com/artist/5C0gCCG8N5Dh5dZytIgzLX"
            },
            "href": "https://api.spotify.com/v1/artists/5C0gCCG8N5Dh5dZytIgzLX",
            "id": "5C0gCCG8N5Dh5dZytIgzLX",
            "name": "Os Mutantes",
            "type": "artist",
            "uri": "spotify:artist:5C0gCCG8N5Dh5dZytIgzLX"
          }
        ],
        "disc_number": 1,
        "duration_ms": 323173,
        "explicit": False,
        "external_ids": {
          "isrc": "BRMCA7200255"
        },
        "external_urls": {
          "spotify": "https://open.spotify.com/track/2amwph6wj13BILu9IADyOM"
        },
        "href": "https://api.spotify.com/v1/tracks/2amwph6wj13BILu9IADyOM",
        "id": "2amwph6wj13BILu9IADyOM",
        "is_local": False,
        "is_playable": True,
        "name": "Dune Buggy",
        "popularity": 16,
        "preview_url": "null",
        "track_number": 3,
        "type": "track",
        "uri": "spotify:track:2amwph6wj13BILu9IADyOM"
      },
      {
        "album": {
          "album_type": "album",
          "artists": [
            {
              "external_urls": {
                "spotify": "https://open.spotify.com/artist/5C0gCCG8N5Dh5dZytIgzLX"
              },
              "href": "https://api.spotify.com/v1/artists/5C0gCCG8N5Dh5dZytIgzLX",
              "id": "5C0gCCG8N5Dh5dZytIgzLX",
              "name": "Os Mutantes",
              "type": "artist",
              "uri": "spotify:artist:5C0gCCG8N5Dh5dZytIgzLX"
            }
          ],
          "external_urls": {
            "spotify": "https://open.spotify.com/album/6bWR1KoGNbHBHLYWxcN9dm"
          },
          "href": "https://api.spotify.com/v1/albums/6bWR1KoGNbHBHLYWxcN9dm",
          "id": "6bWR1KoGNbHBHLYWxcN9dm",
          "images": [
            {
              "height": 640,
              "width": 640,
              "url": "https://i.scdn.co/image/ab67616d0000b2738ca048d1b50af5d465c62459"
            },
            {
              "height": 300,
              "width": 300,
              "url": "https://i.scdn.co/image/ab67616d00001e028ca048d1b50af5d465c62459"
            },
            {
              "height": 64,
              "width": 64,
              "url": "https://i.scdn.co/image/ab67616d000048518ca048d1b50af5d465c62459"
            }
          ],
          "is_playable": True,
          "name": "\"Mutantes E Seus Cometas No Pais Do Baurets\"",
          "release_date": "1972-01-01",
          "release_date_precision": "day",
          "total_tracks": 10,
          "type": "album",
          "uri": "spotify:album:6bWR1KoGNbHBHLYWxcN9dm"
        },
        "artists": [
          {
            "external_urls": {
              "spotify": "https://open.spotify.com/artist/5C0gCCG8N5Dh5dZytIgzLX"
            },
            "href": "https://api.spotify.com/v1/artists/5C0gCCG8N5Dh5dZytIgzLX",
            "id": "5C0gCCG8N5Dh5dZytIgzLX",
            "name": "Os Mutantes",
            "type": "artist",
            "uri": "spotify:artist:5C0gCCG8N5Dh5dZytIgzLX"
          }
        ],
        "disc_number": 1,
        "duration_ms": 588800,
        "explicit": False,
        "external_ids": {
          "isrc": "BRMCA7200261"
        },
        "external_urls": {
          "spotify": "https://open.spotify.com/track/2qnrpUxtArf8mHLQx5FIWR"
        },
        "href": "https://api.spotify.com/v1/tracks/2qnrpUxtArf8mHLQx5FIWR",
        "id": "2qnrpUxtArf8mHLQx5FIWR",
        "is_local": False,
        "is_playable": True,
        "name": "Mutantes E Seus Cometas No País Do Baurets",
        "popularity": 14,
        "preview_url": "null",
        "track_number": 9,
        "type": "track",
        "uri": "spotify:track:2qnrpUxtArf8mHLQx5FIWR"
      },
      {
        "album": {
          "album_type": "album",
          "artists": [
            {
              "external_urls": {
                "spotify": "https://open.spotify.com/artist/5C0gCCG8N5Dh5dZytIgzLX"
              },
              "href": "https://api.spotify.com/v1/artists/5C0gCCG8N5Dh5dZytIgzLX",
              "id": "5C0gCCG8N5Dh5dZytIgzLX",
              "name": "Os Mutantes",
              "type": "artist",
              "uri": "spotify:artist:5C0gCCG8N5Dh5dZytIgzLX"
            }
          ],
          "external_urls": {
            "spotify": "https://open.spotify.com/album/0RBkIFbQy91qv8Tqja20og"
          },
          "href": "https://api.spotify.com/v1/albums/0RBkIFbQy91qv8Tqja20og",
          "id": "0RBkIFbQy91qv8Tqja20og",
          "images": [
            {
              "height": 640,
              "width": 640,
              "url": "https://i.scdn.co/image/ab67616d0000b273cf5f9eaa0d3a164305c35b49"
            },
            {
              "height": 300,
              "width": 300,
              "url": "https://i.scdn.co/image/ab67616d00001e02cf5f9eaa0d3a164305c35b49"
            },
            {
              "height": 64,
              "width": 64,
              "url": "https://i.scdn.co/image/ab67616d00004851cf5f9eaa0d3a164305c35b49"
            }
          ],
          "is_playable": True,
          "name": "\"Os Mutantes\"",
          "release_date": "1968-01-01",
          "release_date_precision": "day",
          "total_tracks": 11,
          "type": "album",
          "uri": "spotify:album:0RBkIFbQy91qv8Tqja20og"
        },
        "artists": [
          {
            "external_urls": {
              "spotify": "https://open.spotify.com/artist/5C0gCCG8N5Dh5dZytIgzLX"
            },
            "href": "https://api.spotify.com/v1/artists/5C0gCCG8N5Dh5dZytIgzLX",
            "id": "5C0gCCG8N5Dh5dZytIgzLX",
            "name": "Os Mutantes",
            "type": "artist",
            "uri": "spotify:artist:5C0gCCG8N5Dh5dZytIgzLX"
          }
        ],
        "disc_number": 1,
        "duration_ms": 108786,
        "explicit": False,
        "external_ids": {
          "isrc": "BRMCA6800112"
        },
        "external_urls": {
          "spotify": "https://open.spotify.com/track/2jgSHtEZ2UxQSz1lHrKoVl"
        },
        "href": "https://api.spotify.com/v1/tracks/2jgSHtEZ2UxQSz1lHrKoVl",
        "id": "2jgSHtEZ2UxQSz1lHrKoVl",
        "is_local": False,
        "is_playable": True,
        "name": "Tempo No Tempo",
        "popularity": 30,
        "preview_url": "null",
        "track_number": 10,
        "type": "track",
        "uri": "spotify:track:2jgSHtEZ2UxQSz1lHrKoVl"
      },
      {
        "album": {
          "album_type": "album",
          "artists": [
            {
              "external_urls": {
                "spotify": "https://open.spotify.com/artist/5obWz23lEqbJf7dyPSGvRv"
              },
              "href": "https://api.spotify.com/v1/artists/5obWz23lEqbJf7dyPSGvRv",
              "id": "5obWz23lEqbJf7dyPSGvRv",
              "name": "Bêbados Habilidosos",
              "type": "artist",
              "uri": "spotify:artist:5obWz23lEqbJf7dyPSGvRv"
            }
          ],
          "external_urls": {
            "spotify": "https://open.spotify.com/album/4vr1pqiffSonZr8S9701bW"
          },
          "href": "https://api.spotify.com/v1/albums/4vr1pqiffSonZr8S9701bW",
          "id": "4vr1pqiffSonZr8S9701bW",
          "images": [
            {
              "height": 640,
              "width": 640,
              "url": "https://i.scdn.co/image/ab67616d0000b27386727e4c1e5d2dcfd8550ee2"
            },
            {
              "height": 300,
              "width": 300,
              "url": "https://i.scdn.co/image/ab67616d00001e0286727e4c1e5d2dcfd8550ee2"
            },
            {
              "height": 64,
              "width": 64,
              "url": "https://i.scdn.co/image/ab67616d0000485186727e4c1e5d2dcfd8550ee2"
            }
          ],
          "is_playable": True,
          "name": "Envelhecido 12 Anos",
          "release_date": "2004-01-01",
          "release_date_precision": "day",
          "total_tracks": 12,
          "type": "album",
          "uri": "spotify:album:4vr1pqiffSonZr8S9701bW"
        },
        "artists": [
          {
            "external_urls": {
              "spotify": "https://open.spotify.com/artist/5obWz23lEqbJf7dyPSGvRv"
            },
            "href": "https://api.spotify.com/v1/artists/5obWz23lEqbJf7dyPSGvRv",
            "id": "5obWz23lEqbJf7dyPSGvRv",
            "name": "Bêbados Habilidosos",
            "type": "artist",
            "uri": "spotify:artist:5obWz23lEqbJf7dyPSGvRv"
          }
        ],
        "disc_number": 1,
        "duration_ms": 218758,
        "explicit": False,
        "external_ids": {
          "isrc": "BXIWW1700047"
        },
        "external_urls": {
          "spotify": "https://open.spotify.com/track/2s1ySIfKAQWMTLp8pOOHIO"
        },
        "href": "https://api.spotify.com/v1/tracks/2s1ySIfKAQWMTLp8pOOHIO",
        "id": "2s1ySIfKAQWMTLp8pOOHIO",
        "is_local": False,
        "is_playable": True,
        "name": "Mutantes",
        "popularity": 15,
        "preview_url": "null",
        "track_number": 4,
        "type": "track",
        "uri": "spotify:track:2s1ySIfKAQWMTLp8pOOHIO"
      },
      {
        "album": {
          "album_type": "single",
          "artists": [
            {
              "external_urls": {
                "spotify": "https://open.spotify.com/artist/50sftj2oW2iBviA6RkTzsz"
              },
              "href": "https://api.spotify.com/v1/artists/50sftj2oW2iBviA6RkTzsz",
              "id": "50sftj2oW2iBviA6RkTzsz",
              "name": "Silva",
              "type": "artist",
              "uri": "spotify:artist:50sftj2oW2iBviA6RkTzsz"
            },
            {
              "external_urls": {
                "spotify": "https://open.spotify.com/artist/2O6q06oNcmOIPg1qidSU3C"
              },
              "href": "https://api.spotify.com/v1/artists/2O6q06oNcmOIPg1qidSU3C",
              "id": "2O6q06oNcmOIPg1qidSU3C",
              "name": "Liniker",
              "type": "artist",
              "uri": "spotify:artist:2O6q06oNcmOIPg1qidSU3C"
            }
          ],
          "external_urls": {
            "spotify": "https://open.spotify.com/album/7KLR11ffMXPDqbsXVT9GtG"
          },
          "href": "https://api.spotify.com/v1/albums/7KLR11ffMXPDqbsXVT9GtG",
          "id": "7KLR11ffMXPDqbsXVT9GtG",
          "images": [
            {
              "height": 640,
              "width": 640,
              "url": "https://i.scdn.co/image/ab67616d0000b2737fd32001185535b939923da3"
            },
            {
              "height": 300,
              "width": 300,
              "url": "https://i.scdn.co/image/ab67616d00001e027fd32001185535b939923da3"
            },
            {
              "height": 64,
              "width": 64,
              "url": "https://i.scdn.co/image/ab67616d000048517fd32001185535b939923da3"
            }
          ],
          "is_playable": True,
          "name": "Silva & Liniker (Ao Vivo)",
          "release_date": "2023-09-22",
          "release_date_precision": "day",
          "total_tracks": 4,
          "type": "album",
          "uri": "spotify:album:7KLR11ffMXPDqbsXVT9GtG"
        },
        "artists": [
          {
            "external_urls": {
              "spotify": "https://open.spotify.com/artist/50sftj2oW2iBviA6RkTzsz"
            },
            "href": "https://api.spotify.com/v1/artists/50sftj2oW2iBviA6RkTzsz",
            "id": "50sftj2oW2iBviA6RkTzsz",
            "name": "Silva",
            "type": "artist",
            "uri": "spotify:artist:50sftj2oW2iBviA6RkTzsz"
          },
          {
            "external_urls": {
              "spotify": "https://open.spotify.com/artist/2O6q06oNcmOIPg1qidSU3C"
            },
            "href": "https://api.spotify.com/v1/artists/2O6q06oNcmOIPg1qidSU3C",
            "id": "2O6q06oNcmOIPg1qidSU3C",
            "name": "Liniker",
            "type": "artist",
            "uri": "spotify:artist:2O6q06oNcmOIPg1qidSU3C"
          }
        ],
        "disc_number": 1,
        "duration_ms": 248626,
        "explicit": False,
        "external_ids": {
          "isrc": "BRRGE2300491"
        },
        "external_urls": {
          "spotify": "https://open.spotify.com/track/6nFCdQkvmvOSO8Ceg5Uj9u"
        },
        "href": "https://api.spotify.com/v1/tracks/6nFCdQkvmvOSO8Ceg5Uj9u",
        "id": "6nFCdQkvmvOSO8Ceg5Uj9u",
        "is_local": False,
        "is_playable": True,
        "name": "Mutante - Ao Vivo",
        "popularity": 43,
        "preview_url": "null",
        "track_number": 4,
        "type": "track",
        "uri": "spotify:track:6nFCdQkvmvOSO8Ceg5Uj9u"
      },
      {
        "album": {
          "album_type": "single",
          "artists": [
            {
              "external_urls": {
                "spotify": "https://open.spotify.com/artist/6nVcjUJemqpJjc1WevwTvL"
              },
              "href": "https://api.spotify.com/v1/artists/6nVcjUJemqpJjc1WevwTvL",
              "id": "6nVcjUJemqpJjc1WevwTvL",
              "name": "La Vela Puerca",
              "type": "artist",
              "uri": "spotify:artist:6nVcjUJemqpJjc1WevwTvL"
            }
          ],
          "external_urls": {
            "spotify": "https://open.spotify.com/album/0lt6oS9QStYcgPwR6gZQVf"
          },
          "href": "https://api.spotify.com/v1/albums/0lt6oS9QStYcgPwR6gZQVf",
          "id": "0lt6oS9QStYcgPwR6gZQVf",
          "images": [
            {
              "height": 640,
              "width": 640,
              "url": "https://i.scdn.co/image/ab67616d0000b2733bf37653371b764a2268048e"
            },
            {
              "height": 300,
              "width": 300,
              "url": "https://i.scdn.co/image/ab67616d00001e023bf37653371b764a2268048e"
            },
            {
              "height": 64,
              "width": 64,
              "url": "https://i.scdn.co/image/ab67616d000048513bf37653371b764a2268048e"
            }
          ],
          "is_playable": True,
          "name": "Mutantes",
          "release_date": "2020-12-16",
          "release_date_precision": "day",
          "total_tracks": 1,
          "type": "album",
          "uri": "spotify:album:0lt6oS9QStYcgPwR6gZQVf"
        },
        "artists": [
          {
            "external_urls": {
              "spotify": "https://open.spotify.com/artist/6nVcjUJemqpJjc1WevwTvL"
            },
            "href": "https://api.spotify.com/v1/artists/6nVcjUJemqpJjc1WevwTvL",
            "id": "6nVcjUJemqpJjc1WevwTvL",
            "name": "La Vela Puerca",
            "type": "artist",
            "uri": "spotify:artist:6nVcjUJemqpJjc1WevwTvL"
          }
        ],
        "disc_number": 1,
        "duration_ms": 148565,
        "explicit": False,
        "external_ids": {
          "isrc": "UYE052000002"
        },
        "external_urls": {
          "spotify": "https://open.spotify.com/track/76JS66fQKVW2TEknyPNOoj"
        },
        "href": "https://api.spotify.com/v1/tracks/76JS66fQKVW2TEknyPNOoj",
        "id": "76JS66fQKVW2TEknyPNOoj",
        "is_local": False,
        "is_playable": True,
        "name": "Mutantes",
        "popularity": 20,
        "preview_url": "null",
        "track_number": 1,
        "type": "track",
        "uri": "spotify:track:76JS66fQKVW2TEknyPNOoj"
      },
      {
        "album": {
          "album_type": "compilation",
          "artists": [
            {
              "external_urls": {
                "spotify": "https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of"
              },
              "href": "https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of",
              "id": "0LyfQWJT6nXafLPZqxe9Of",
              "name": "Vários intérpretes",
              "type": "artist",
              "uri": "spotify:artist:0LyfQWJT6nXafLPZqxe9Of"
            }
          ],
          "external_urls": {
            "spotify": "https://open.spotify.com/album/0xcuAIfYHBTmmRDtoEXGGH"
          },
          "href": "https://api.spotify.com/v1/albums/0xcuAIfYHBTmmRDtoEXGGH",
          "id": "0xcuAIfYHBTmmRDtoEXGGH",
          "images": [
            {
              "height": 640,
              "width": 640,
              "url": "https://i.scdn.co/image/ab67616d0000b2730bc7d4289e3a9511e2f119e3"
            },
            {
              "height": 300,
              "width": 300,
              "url": "https://i.scdn.co/image/ab67616d00001e020bc7d4289e3a9511e2f119e3"
            },
            {
              "height": 64,
              "width": 64,
              "url": "https://i.scdn.co/image/ab67616d000048510bc7d4289e3a9511e2f119e3"
            }
          ],
          "is_playable": True,
          "name": "Mutantes (Trilha Sonora Original)",
          "release_date": "2021-02-12",
          "release_date_precision": "day",
          "total_tracks": 10,
          "type": "album",
          "uri": "spotify:album:0xcuAIfYHBTmmRDtoEXGGH"
        },
        "artists": [
          {
            "external_urls": {
              "spotify": "https://open.spotify.com/artist/3bKO3mmizIpDdwNVdp96B9"
            },
            "href": "https://api.spotify.com/v1/artists/3bKO3mmizIpDdwNVdp96B9",
            "id": "3bKO3mmizIpDdwNVdp96B9",
            "name": "Nenhum De Nós",
            "type": "artist",
            "uri": "spotify:artist:3bKO3mmizIpDdwNVdp96B9"
          }
        ],
        "disc_number": 1,
        "duration_ms": 220473,
        "explicit": False,
        "external_ids": {
          "isrc": "BRPJ70800707"
        },
        "external_urls": {
          "spotify": "https://open.spotify.com/track/0dnMNvzzYeE26sz7xw9xkT"
        },
        "href": "https://api.spotify.com/v1/tracks/0dnMNvzzYeE26sz7xw9xkT",
        "id": "0dnMNvzzYeE26sz7xw9xkT",
        "is_local": False,
        "is_playable": True,
        "name": "O Astronauta De Mármore",
        "popularity": 30,
        "preview_url": "null",
        "track_number": 1,
        "type": "track",
        "uri": "spotify:track:0dnMNvzzYeE26sz7xw9xkT"
      },
      {
        "album": {
          "album_type": "album",
          "artists": [
            {
              "external_urls": {
                "spotify": "https://open.spotify.com/artist/5E2lFPYLaaJMppQA2qDkur"
              },
              "href": "https://api.spotify.com/v1/artists/5E2lFPYLaaJMppQA2qDkur",
              "id": "5E2lFPYLaaJMppQA2qDkur",
              "name": "Soulstance",
              "type": "artist",
              "uri": "spotify:artist:5E2lFPYLaaJMppQA2qDkur"
            }
          ],
          "external_urls": {
            "spotify": "https://open.spotify.com/album/5nhmGAHOTqeyPTYNmlbHE1"
          },
          "href": "https://api.spotify.com/v1/albums/5nhmGAHOTqeyPTYNmlbHE1",
          "id": "5nhmGAHOTqeyPTYNmlbHE1",
          "images": [
            {
              "height": 640,
              "width": 640,
              "url": "https://i.scdn.co/image/ab67616d0000b27306b3de79f4f99c839d77d25e"
            },
            {
              "height": 300,
              "width": 300,
              "url": "https://i.scdn.co/image/ab67616d00001e0206b3de79f4f99c839d77d25e"
            },
            {
              "height": 64,
              "width": 64,
              "url": "https://i.scdn.co/image/ab67616d0000485106b3de79f4f99c839d77d25e"
            }
          ],
          "is_playable": True,
          "name": "Act On",
          "release_date": "2007-06-19",
          "release_date_precision": "day",
          "total_tracks": 11,
          "type": "album",
          "uri": "spotify:album:5nhmGAHOTqeyPTYNmlbHE1"
        },
        "artists": [
          {
            "external_urls": {
              "spotify": "https://open.spotify.com/artist/5E2lFPYLaaJMppQA2qDkur"
            },
            "href": "https://api.spotify.com/v1/artists/5E2lFPYLaaJMppQA2qDkur",
            "id": "5E2lFPYLaaJMppQA2qDkur",
            "name": "Soulstance",
            "type": "artist",
            "uri": "spotify:artist:5E2lFPYLaaJMppQA2qDkur"
          }
        ],
        "disc_number": 1,
        "duration_ms": 272195,
        "explicit": False,
        "external_ids": {
          "isrc": "ITO0P0000790"
        },
        "external_urls": {
          "spotify": "https://open.spotify.com/track/6BuBEFtGGngZPJpxMiAzqE"
        },
        "href": "https://api.spotify.com/v1/tracks/6BuBEFtGGngZPJpxMiAzqE",
        "id": "6BuBEFtGGngZPJpxMiAzqE",
        "is_local": False,
        "is_playable": True,
        "name": "Mutantes",
        "popularity": 7,
        "preview_url": "null",
        "track_number": 6,
        "type": "track",
        "uri": "spotify:track:6BuBEFtGGngZPJpxMiAzqE"
      },
      {
        "album": {
          "album_type": "single",
          "artists": [
            {
              "external_urls": {
                "spotify": "https://open.spotify.com/artist/4jQ84uzHTzIsRpZSstP5Sj"
              },
              "href": "https://api.spotify.com/v1/artists/4jQ84uzHTzIsRpZSstP5Sj",
              "id": "4jQ84uzHTzIsRpZSstP5Sj",
              "name": "Fermín Echeveste",
              "type": "artist",
              "uri": "spotify:artist:4jQ84uzHTzIsRpZSstP5Sj"
            }
          ],
          "external_urls": {
            "spotify": "https://open.spotify.com/album/091AtprQedZnucjTCOxybJ"
          },
          "href": "https://api.spotify.com/v1/albums/091AtprQedZnucjTCOxybJ",
          "id": "091AtprQedZnucjTCOxybJ",
          "images": [
            {
              "height": 640,
              "width": 640,
              "url": "https://i.scdn.co/image/ab67616d0000b2735b4237cc7ef22c36a65f45c2"
            },
            {
              "height": 300,
              "width": 300,
              "url": "https://i.scdn.co/image/ab67616d00001e025b4237cc7ef22c36a65f45c2"
            },
            {
              "height": 64,
              "width": 64,
              "url": "https://i.scdn.co/image/ab67616d000048515b4237cc7ef22c36a65f45c2"
            }
          ],
          "is_playable": True,
          "name": "Mutantes",
          "release_date": "2021-05-21",
          "release_date_precision": "day",
          "total_tracks": 1,
          "type": "album",
          "uri": "spotify:album:091AtprQedZnucjTCOxybJ"
        },
        "artists": [
          {
            "external_urls": {
              "spotify": "https://open.spotify.com/artist/4jQ84uzHTzIsRpZSstP5Sj"
            },
            "href": "https://api.spotify.com/v1/artists/4jQ84uzHTzIsRpZSstP5Sj",
            "id": "4jQ84uzHTzIsRpZSstP5Sj",
            "name": "Fermín Echeveste",
            "type": "artist",
            "uri": "spotify:artist:4jQ84uzHTzIsRpZSstP5Sj"
          },
          {
            "external_urls": {
              "spotify": "https://open.spotify.com/artist/0BqnaIeIaSncq1NPK4kpD2"
            },
            "href": "https://api.spotify.com/v1/artists/0BqnaIeIaSncq1NPK4kpD2",
            "id": "0BqnaIeIaSncq1NPK4kpD2",
            "name": "Juana Aguirre",
            "type": "artist",
            "uri": "spotify:artist:0BqnaIeIaSncq1NPK4kpD2"
          }
        ],
        "disc_number": 1,
        "duration_ms": 238125,
        "explicit": False,
        "external_ids": {
          "isrc": "ARPRO2100001"
        },
        "external_urls": {
          "spotify": "https://open.spotify.com/track/5rBSvKvPb03ZxF5FDlBjSu"
        },
        "href": "https://api.spotify.com/v1/tracks/5rBSvKvPb03ZxF5FDlBjSu",
        "id": "5rBSvKvPb03ZxF5FDlBjSu",
        "is_local": False,
        "is_playable": True,
        "name": "Mutantes",
        "popularity": 3,
        "preview_url": "null",
        "track_number": 1,
        "type": "track",
        "uri": "spotify:track:5rBSvKvPb03ZxF5FDlBjSu"
      },
      {
        "album": {
          "album_type": "single",
          "artists": [
            {
              "external_urls": {
                "spotify": "https://open.spotify.com/artist/7jQ5QIonunUiDi5JTZXwlI"
              },
              "href": "https://api.spotify.com/v1/artists/7jQ5QIonunUiDi5JTZXwlI",
              "id": "7jQ5QIonunUiDi5JTZXwlI",
              "name": "Fate Furbo",
              "type": "artist",
              "uri": "spotify:artist:7jQ5QIonunUiDi5JTZXwlI"
            }
          ],
          "external_urls": {
            "spotify": "https://open.spotify.com/album/3tSndovcBafme1x4Lg7mMG"
          },
          "href": "https://api.spotify.com/v1/albums/3tSndovcBafme1x4Lg7mMG",
          "id": "3tSndovcBafme1x4Lg7mMG",
          "images": [
            {
              "height": 640,
              "width": 640,
              "url": "https://i.scdn.co/image/ab67616d0000b27357190ea81bc5a6943c2c6612"
            },
            {
              "height": 300,
              "width": 300,
              "url": "https://i.scdn.co/image/ab67616d00001e0257190ea81bc5a6943c2c6612"
            },
            {
              "height": 64,
              "width": 64,
              "url": "https://i.scdn.co/image/ab67616d0000485157190ea81bc5a6943c2c6612"
            }
          ],
          "is_playable": True,
          "name": "Mutantes",
          "release_date": "2024-03-14",
          "release_date_precision": "day",
          "total_tracks": 1,
          "type": "album",
          "uri": "spotify:album:3tSndovcBafme1x4Lg7mMG"
        },
        "artists": [
          {
            "external_urls": {
              "spotify": "https://open.spotify.com/artist/7jQ5QIonunUiDi5JTZXwlI"
            },
            "href": "https://api.spotify.com/v1/artists/7jQ5QIonunUiDi5JTZXwlI",
            "id": "7jQ5QIonunUiDi5JTZXwlI",
            "name": "Fate Furbo",
            "type": "artist",
            "uri": "spotify:artist:7jQ5QIonunUiDi5JTZXwlI"
          }
        ],
        "disc_number": 1,
        "duration_ms": 199210,
        "explicit": False,
        "external_ids": {
          "isrc": "BKG382300008"
        },
        "external_urls": {
          "spotify": "https://open.spotify.com/track/5B2CoR1pjD9F1dN3qBRnN7"
        },
        "href": "https://api.spotify.com/v1/tracks/5B2CoR1pjD9F1dN3qBRnN7",
        "id": "5B2CoR1pjD9F1dN3qBRnN7",
        "is_local": False,
        "is_playable": True,
        "name": "Mutantes",
        "popularity": 10,
        "preview_url": "null",
        "track_number": 1,
        "type": "track",
        "uri": "spotify:track:5B2CoR1pjD9F1dN3qBRnN7"
      },
      {
        "album": {
          "album_type": "album",
          "artists": [
            {
              "external_urls": {
                "spotify": "https://open.spotify.com/artist/1V4q6YFYDISE1tTObYqoSG"
              },
              "href": "https://api.spotify.com/v1/artists/1V4q6YFYDISE1tTObYqoSG",
              "id": "1V4q6YFYDISE1tTObYqoSG",
              "name": "Julia Bosco",
              "type": "artist",
              "uri": "spotify:artist:1V4q6YFYDISE1tTObYqoSG"
            }
          ],
          "external_urls": {
            "spotify": "https://open.spotify.com/album/0DOxsVqn5NYF6ilwFqwLtz"
          },
          "href": "https://api.spotify.com/v1/albums/0DOxsVqn5NYF6ilwFqwLtz",
          "id": "0DOxsVqn5NYF6ilwFqwLtz",
          "images": [
            {
              "height": 640,
              "width": 640,
              "url": "https://i.scdn.co/image/ab67616d0000b2739dbdb6bcc72d47363be83df2"
            },
            {
              "height": 300,
              "width": 300,
              "url": "https://i.scdn.co/image/ab67616d00001e029dbdb6bcc72d47363be83df2"
            },
            {
              "height": 64,
              "width": 64,
              "url": "https://i.scdn.co/image/ab67616d000048519dbdb6bcc72d47363be83df2"
            }
          ],
          "is_playable": True,
          "name": "Tempo",
          "release_date": "2012-01-17",
          "release_date_precision": "day",
          "total_tracks": 13,
          "type": "album",
          "uri": "spotify:album:0DOxsVqn5NYF6ilwFqwLtz"
        },
        "artists": [
          {
            "external_urls": {
              "spotify": "https://open.spotify.com/artist/1V4q6YFYDISE1tTObYqoSG"
            },
            "href": "https://api.spotify.com/v1/artists/1V4q6YFYDISE1tTObYqoSG",
            "id": "1V4q6YFYDISE1tTObYqoSG",
            "name": "Julia Bosco",
            "type": "artist",
            "uri": "spotify:artist:1V4q6YFYDISE1tTObYqoSG"
          }
        ],
        "disc_number": 1,
        "duration_ms": 283653,
        "explicit": False,
        "external_ids": {
          "isrc": "BR7UL1100010"
        },
        "external_urls": {
          "spotify": "https://open.spotify.com/track/7zYuZnCvS7dixMltpLECBB"
        },
        "href": "https://api.spotify.com/v1/tracks/7zYuZnCvS7dixMltpLECBB",
        "id": "7zYuZnCvS7dixMltpLECBB",
        "is_local": False,
        "is_playable": True,
        "name": "Mutantes",
        "popularity": 0,
        "preview_url": "null",
        "track_number": 10,
        "type": "track",
        "uri": "spotify:track:7zYuZnCvS7dixMltpLECBB"
      },
      {
        "album": {
          "album_type": "album",
          "artists": [
            {
              "external_urls": {
                "spotify": "https://open.spotify.com/artist/3aGfO18EsB2EPp2PXStSod"
              },
              "href": "https://api.spotify.com/v1/artists/3aGfO18EsB2EPp2PXStSod",
              "id": "3aGfO18EsB2EPp2PXStSod",
              "name": "Nino Henz",
              "type": "artist",
              "uri": "spotify:artist:3aGfO18EsB2EPp2PXStSod"
            }
          ],
          "external_urls": {
            "spotify": "https://open.spotify.com/album/3cXCoEOsiReVP305xA8O0J"
          },
          "href": "https://api.spotify.com/v1/albums/3cXCoEOsiReVP305xA8O0J",
          "id": "3cXCoEOsiReVP305xA8O0J",
          "images": [
            {
              "height": 640,
              "width": 640,
              "url": "https://i.scdn.co/image/ab67616d0000b27390eee6b37f03d696c3a08c55"
            },
            {
              "height": 300,
              "width": 300,
              "url": "https://i.scdn.co/image/ab67616d00001e0290eee6b37f03d696c3a08c55"
            },
            {
              "height": 64,
              "width": 64,
              "url": "https://i.scdn.co/image/ab67616d0000485190eee6b37f03d696c3a08c55"
            }
          ],
          "is_playable": True,
          "name": "Ninohenz",
          "release_date": "2024-05-24",
          "release_date_precision": "day",
          "total_tracks": 10,
          "type": "album",
          "uri": "spotify:album:3cXCoEOsiReVP305xA8O0J"
        },
        "artists": [
          {
            "external_urls": {
              "spotify": "https://open.spotify.com/artist/3aGfO18EsB2EPp2PXStSod"
            },
            "href": "https://api.spotify.com/v1/artists/3aGfO18EsB2EPp2PXStSod",
            "id": "3aGfO18EsB2EPp2PXStSod",
            "name": "Nino Henz",
            "type": "artist",
            "uri": "spotify:artist:3aGfO18EsB2EPp2PXStSod"
          }
        ],
        "disc_number": 1,
        "duration_ms": 219653,
        "explicit": False,
        "external_ids": {
          "isrc": "BRZAM0800228"
        },
        "external_urls": {
          "spotify": "https://open.spotify.com/track/0ub5Rqj9mYythvs2eQjGma"
        },
        "href": "https://api.spotify.com/v1/tracks/0ub5Rqj9mYythvs2eQjGma",
        "id": "0ub5Rqj9mYythvs2eQjGma",
        "is_local": False,
        "is_playable": True,
        "name": "Mutantes",
        "popularity": 0,
        "preview_url": "null",
        "track_number": 5,
        "type": "track",
        "uri": "spotify:track:0ub5Rqj9mYythvs2eQjGma"
      }
    ]
  }
}

# %%
track = search['tracks']['items'][0]
track.keys()
# Out:
# dict_keys(['album', 'artists', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'is_playable', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %%
track['album']['images'][0]['url']
# Out:
# 'https://i.scdn.co/image/ab67616d0000b273cf5f9eaa0d3a164305c35b49'

# %%
def process_search(resp):

    tracks = resp['tracks']['items']

    search_result = []
    for track in tracks:
        track_dict = {}
        track_dict['album_name'] = track['album']['name']
        track_dict['url'] = track['album']['images'][0]['url']
        track_dict['name'] = track['name']
        artistas = track['artists'][0]['name']
        if len(track['artists']) > 1:
            for artist in track['artists'][1:]:
                artistas = artistas + "&" + artist['name']
        track_dict['artist'] = artistas
        track_dict['id'] = track['id']
        search_result.append(track_dict)


    return search_result

# %%
from datetime import datetime
float(str(datetime.now().timestamp()))
# Out:
# 1736011410.363547

# %%
import os
lista = ["none"]
os.environ["test"] = str(lista)

# %%
os.environ["test"][2:-2].split("', '")
# Out:
# ['none']

# %%
import urllib.parse

CLIENT_ID = "fb725b50f755401cb21714d2f2c08d56"
CLIENT_SECRET = "71d1e11f53ab4c7799b871f0cfd8f24c"
#REDIRECT_URI = "http://localhost:5000/callback"
REDIRECT_URI = "https://jukebox-459577242298.southamerica-east1.run.app/callback"

AUTH_URL = "https://accounts.spotify.com/authorize"
TOKEN_URL = "https://accounts.spotify.com/api/token"
API_BASE_URL = "https://api.spotify.com/v1/"

scope = "user-read-private user-read-email user-read-playback-state user-read-currently-playing user-modify-playback-state"

params = {
        'client_id': CLIENT_ID,
        'response_type': 'code',
        'scope': scope,
        'redirect_uri': REDIRECT_URI,
        'show_dialog': False
    }

auth_url = f"{AUTH_URL}?{urllib.parse.urlencode(params)}"

# %%
auth_url
# Out:
# 'https://accounts.spotify.com/authorize?client_id=fb725b50f755401cb21714d2f2c08d56&response_type=code&scope=user-read-private+user-read-email+user-read-playback-state+user-read-currently-playing+user-modify-playback-state&redirect_uri=https%3A%2F%2Fjukebox-459577242298.southamerica-east1.run.app%2Fcallback&show_dialog=False'

# %%
import json
import os

# %%
data = {}
data_str = json.dumps(data)

# %%
os.environ['LIKES'] = '{}'

likes = json.loads(os.environ['LIKES'])

# %%
likes
# Out:
# {}

# %%
from PIL import Image, ImageDraw, ImageFont
import requests

MAIN = "static/images/main-jukebox.jpg"
BAR= "static/images/IA.png"

# Example usage
main_image_path = MAIN
image1_path = BAR
font_path = "static/images/calibriz.ttf"
output_path = "static/images/juke-box-nowplaying.jpg"
image2 = Image.open(requests.get("https://i.scdn.co/image/ab67616d00001e02ff9ca10b55ce82ae553c8228", stream=True).raw)
text = """
Aqui curting um som do \n
Pinkfróid na juke-box do \n
@InspiriaBAR"
"""

# %%
def paste_images_resized(main_image_path, image1_path, image2, output_path, text):

  try:
    main_image = Image.open(main_image_path)
    image1 = Image.open(image1_path)

    # Resize images to 600x600
    image1 = image1.resize((600, 600))
    image2 = image2.resize((600, 600))

    # Paste
    main_image.paste(image1, (100, 150))
    main_image.paste(image2, (200, 450))

    draw = ImageDraw.Draw(main_image)
    font = ImageFont.truetype(font_path, 64)
    draw.multiline_text([800, 1200], text, font=font, fill="white", align = "right", anchor="ra")

    main_image.save(output_path)

    print(f"Images pasted successfully and saved to {output_path}")

  except Exception as e:
    print(f"Error pasting images: {e}")

# Example usage

paste_images_resized(main_image_path, image1_path, image2, output_path, text)
# Out:
# Images pasted successfully and saved to static/images/juke-box-nowplaying.jpg

# %%
def open_and_read_txt_file(filename):
    """
    Opens a text file and reads its contents.

    Args:
        filename: The name of the file to open.

    Returns:
        The contents of the file as a string.
    """

    try:
        with open(filename, 'r') as file:
            return file.read()
    except FileNotFoundError:
        print(f"Error: File '{filename}' not found.")
        return None

# Example usage:
file_contents = open_and_read_txt_file("C:/Users/nikin/OneDrive/Documentos/Projetos/Spotify/archive/Lista generos.txt")

# %%
generos = file_contents.split("\n")

# %%
def save_list_to_file(my_list, filename):
    """
    Saves a Python list to a file.

    Args:
        my_list: The list to be saved.
        filename: The name of the file to save the list to.
    """

    with open(filename, 'w') as file:
        for item in my_list:
            file.write(str(item) + '\n')

# Example usage:

save_list_to_file(generos, "generos.txt")

# %%
def find_matching_texts(list1, list2):
    """
    Finds and returns a list of texts that are present in both input lists.

    Args:
        list1: The first list of texts.
        list2: The second list of texts.

    Returns:
        A list of matching texts. If no matches are found, returns an empty list.
    """

    matching_texts = []
    for text1 in list1:
        if text1 in list2:
            matching_texts.append(text1)
    return matching_texts

# Example usage:
list1 = ['arrocha', 'sertanejo', 'sertanejo universitario']
with open("static/setup_files/ban_list.txt", 'r') as file:
    list2 = file.read().split("\n")
matching_texts = find_matching_texts(list1, list2)

if matching_texts:
    print("Matching texts:", matching_texts)
else:
    print("No matching texts found.")
# Out:
# Matching texts: ['sertanejo', 'sertanejo universitario']

# %%
list2
# Out:
# ['Atmospheric Black Metal',
#  'Axe',
#  'Baile Funk',
#  'Black Death',
#  'Black Metal',
#  'Black Sludge',
#  'Black Thrash',
#  'Boy Band',
#  'Brazilian Gospel',
#  'Brega',
#  'Calypso',
#  'Celtic Christmas',
#  'Chaotic Black Metal',
#  'Chaotic Hardcore',
#  'Chinese Opera',
#  'Christian Alternative Rock',
#  'Christian Christmas',
#  'Christian Dance',
#  'Christian Hardcore',
#  'Christian Hip Hop',
#  'Christian Metal',
#  'Christian Music',
#  'Christian Punk',
#  'Christian Rock',
#  'Christmas',
#  'Christmas Product',
#  'Cryptic Black Metal',
#  'Dark Black Metal',
#  'Death Metal',
#  'Gospel',
#  'Gospel Blues',
#  'Gospel Reggae',
#  'Gothic Alternative',
#  'Gothic Americana',
#  'Gothic Doom',
#  'Gothic Metal',
#  'Gothic Post-punk',
#  'Gothic Rock',
#  'Gothic Symphonic Metal',
#  'Noise Punk',
#  'Pagode',
#  'Sertanejo',
#  'Sertanejo Universitario',
#  'Thrash Metal',
#  'Worship']

# %%
import json

def open_text_file_as_dict(filename):
    """
    Opens a text file containing a JSON-formatted dictionary 
    and returns the dictionary.

    Args:
        filename: The name of the text file.

    Returns:
        The dictionary loaded from the file, or None if the file 
        cannot be opened or parsed.
    """
    try:
        with open(filename, 'r') as file:
            data = json.load(file)
            return data
    except FileNotFoundError:
        print(f"Error: File '{filename}' not found.")
        return None
    except json.JSONDecodeError:
        print(f"Error: Invalid JSON format in '{filename}'.")
        return None

# Example usage:
filename = 'C:/Users/nikin/OneDrive/Documentos/Projetos/Spotify/archive/feature_filter.txt'  # Replace with the actual filename
data = open_text_file_as_dict(filename)

if data:
    print(data)
# Out:
# {'valence': 0.3, 'valence_high': True, 'max_duration': 600000, 'energy': 0.3, 'energy_high': True, 'ban_list': True, 'grant_list': False}

# %%
with open("static/setup_files/refuse_msg_grant.txt", 'r', encoding='utf-8') as file:
    grant = file.read()

# %%
grant
# Out:
# 'Sinto muito, mas a sa escolha foi reprovada. Nenhum dos artistas relacionados à sua seleção de música se encontra na lista de generos musicais aprovados pelo recinto. Gêneros relacionado à sua seleção:'

# %%
def is_local():
    """
    Checks if the application is running locally.

    Returns:
        bool: True if running locally, False otherwise.
    """
    import socket
    try:
        socket.gethostbyname('google.com')  # Attempt to resolve a Google DNS 
        return False  # If successful, assume running on the cloud
    except:
        return True  # If unsuccessful, assume running locally

# %%
import socket

# %%
socket.gethostname()
# Out:
# 'lepdozicz'

# %%
import ast

text = "['7oEkUINVIj1Nr3Wnj8tzqr', '74PRTFBL3UJS9uiZXGzWrc', '6q7nMIVgGohQ14mSsq3F8t']"

text = ast.literal_eval(text)
type(text)
# Out:
# list

# %%
import os
files = os.listdir('static/reports')

# %%
from datetime import datetime
datetime.now().strftime("%Y%m%d-%H%M%S.%f")[:-3]
# Out:
# '20250120-071922.350'

# %%
from glob import glob

# %%
path = "static/reports/"
all_files = glob(path + "block*.txt", )
all_files = [os.path.basename(file)[:-4] for file in all_files] 
all_files
# Out:
# ['block_log_20250120']

# %%
# Out:
# ['static/reports\\block_log_20250120.txt',
#  'static/reports\\pass_log_20250120.txt']

# %%
all_files = [os.path.basename(file)[:-4] for file in all_files] 
all_files
# Out:
# ['block_log_20250119', 'block_log_20250120']

# %%
path = "static/reports/"

file = "block_log_20250120.txt"
with open(path + file, 'r', encoding='utf-8') as f:
    report = f.readlines()

# %%
import json
j=json.loads(report[0])

# %%
j['artists_ids'][0]
# Out:
# '5j3htXVskZF0u8qWY5zcF8'

# %%
import ast
artists_ids = "['6NqIUh0cpaygBWUUAjBaog']"
artists_ids = ast.literal_eval(artists_ids)

artists_ids
# Out:
# ['6NqIUh0cpaygBWUUAjBaog']

# %%
import requests

auth1 = requests.get("http://127.0.0.1:5000/autorization")
API_BASE_URL = "https://api.spotify.com/v1/"
headers = {
        'Authorization': "Bearer " + auth1.json()
    }

# %%
auth1.json()
# Out:
# 'BQD0KKzyaIblC4dM64XSC84tNP0L7yGksN2U0IFhM_J9OmehRwezVCsNSkG5VVD-huoj5KDIRruR5l1vfdvBchHIV8x85qpsYewh9FW2CGyiqeB-ROoA0Q4VQsNE92qXbY9jbMWCTr55h8Ok2cPy3g25fx-FR2ITvhjIcyvuk4kW2nGGnhfdlVI3yRBM8iLeQbprVUTPdstNaA'

# %%
generos = []
for id in artists_ids:
    response1 = requests.get( API_BASE_URL + "artists/" + id, headers = headers).json()
    for genero in response1['genres']:
        generos.append(genero)

# %%
generos
# Out:
# ['axé', 'pagode', 'samba', 'pagode baiano']

# %%
response1
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/6NqIUh0cpaygBWUUAjBaog'},
#  'followers': {'href': None, 'total': 298757},
#  'genres': ['axé', 'pagode', 'samba', 'pagode baiano'],
#  'href': 'https://api.spotify.com/v1/artists/6NqIUh0cpaygBWUUAjBaog',
#  'id': '6NqIUh0cpaygBWUUAjBaog',
#  'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5ebab451edaadf04c6fb5ddf065',
#    'height': 640,
#    'width': 640},
#   {'url': 'https://i.scdn.co/image/ab67616100005174ab451edaadf04c6fb5ddf065',
#    'height': 320,
#    'width': 320},
#   {'url': 'https://i.scdn.co/image/ab6761610000f178ab451edaadf04c6fb5ddf065',
#    'height': 160,
#    'width': 160}],
#  'name': 'Ara Ketu',
#  'popularity': 51,
#  'type': 'artist',
#  'uri': 'spotify:artist:6NqIUh0cpaygBWUUAjBaog'}

# %%
with open("static/setup_files/ban_list.txt", 'r',  encoding='utf-8') as file:
        ban_list = file.read().split("\n")
ban_list
# Out:
# ['axe',
#  'axé',
#  'baile funk',
#  'black death',
#  'black metal',
#  'black sludge',
#  'black thrash',
#  'boy band',
#  'brazilian gospel',
#  'calypso',
#  'celtic christmas',
#  'chaotic black metal',
#  'chaotic hardcore',
#  'chinese opera',
#  'christian alternative rock',
#  'christian christmas',
#  'christian dance',
#  'christian hardcore',
#  'christian hip hop',
#  'christian metal',
#  'christian music',
#  'christian punk',
#  'christian rock',
#  'christmas',
#  'christmas product',
#  'cryptic black metal',
#  'dark black metal',
#  'death metal',
#  'gospel',
#  'gospel blues',
#  'gospel reggae',
#  'noise punk',
#  'pagode universitario',
#  'sertanejo',
#  'sertanejo universitario',
#  'thrash metal',
#  'worship']

# %%
matching_texts = []
for text1 in generos:
    if text1 in ban_list:
        matching_texts.append(text1)

# %%
banned_list = matching_texts

# %%
banned_list != []
# Out:
# True

# %%
return_msg =  ""
for genero in banned_list:
    return_msg = return_msg + genero + ", "

# %%
return_msg
# Out:
# 'axé, '

# %%
import json
data = {'admin': 'inspiria-admin'}
with open('static/setup_files/credentials.json', 'w') as f:
    json.dump(data, f, indent=4)

# %%
from PIL import Image, ImageDraw

def black_rectangle_gradient(image_path, width_ratio=0.1):
  """
  Creates a black rectangle with a gradient opacity effect on the left side of an image.

  Args:
    image_path: Path to the image file.
    width_ratio: Ratio of the image width for the black rectangle. 
                 (Default: 0.2, meaning 20% of the image width)

  Returns:
    A PIL Image object with the applied gradient effect.
  """

  img = Image.open(image_path)
  width, height = img.size

  gradient_width = int(width * width_ratio)

  # Create a new image with the same dimensions as the original image
  mask = Image.new('L', (width, height), 255)  # 'L' for grayscale
  draw = ImageDraw.Draw(mask)

  # Create a gradient mask
  for x in range(gradient_width):
    opacity = int((x / gradient_width) * 255)  # Calculate opacity (0-255)
    draw.line([(x, 0), (x, height)], fill=opacity)

  # Apply the mask to the original image
  result = Image.new('RGBA', (width, height))  # Create a new RGBA image
  result.paste(img, (0, 0), mask)

  return result

# %%
image_path = "static/images/fundo - Copia.jpg"
output_path = "static/images/fundo - Copia - grad.jpg"


# Example usage:
image_path = "static/images/fundo - Copia.jpg" 
modified_image = black_rectangle_gradient(image_path)
modified_image.save("static/images/fundo - Copia - grad.png")

# %%
img = Image.open(image_path).convert("RGBA")

# %%
img.size[0]
# Out:
# 850

# %%
import json
def analyze_track_info():
  """
  Analyzes a JSON file containing track information and returns a dictionary
  with track counts, names, artists, and associated users.

  Args:
    file_path: Path to the JSON file.

  Returns:
    A dictionary with the following keys:
      - track_counts: A dictionary mapping track IDs to their counts.
      - tracks: A dictionary mapping track IDs to their names and artists.
      - users_per_track: A dictionary mapping track IDs to lists of users
                         who listened to the track.
  """
  track_counts = {}
  tracks = {}
  users_per_track = {}
  url = {}

  with open("static/reports/like_log.txt", 'r', encoding='utf-8') as f:
    for line in f:
      # Assuming the file contains one JSON object per line
      data = json.loads(line)
      track_id = data['track_id']
      song_name = data['song_name']
      song_artist = data['song_artist']
      url = data['album_url']
      user = data['user']

      # Update track counts
      track_counts[track_id] = track_counts.get(track_id, 0) + 1

      # Update track info
      tracks[track_id] = {
          'song_name': song_name,
          'song_artist': song_artist,
          'album_url' : url,
      }

      # Update users per track
      users_per_track.setdefault(track_id, []).append(user)

  sorted_tracks = sorted(track_counts.items(), key=lambda item: item[1], reverse=True)
  return_var = {}
  for track in sorted_tracks:
    track_id = track[0]
    return_var[track_id] = {
      'score' : track[1],
      'name' : tracks[track_id]['song_name'],
      'artist' : tracks[track_id]['song_artist'],
      'url' : tracks[track_id]['album_url'],
      'users' : users_per_track[track_id]
    }

  return return_var

# %%
result = analyze_track_info()

# %%
sorted(result['track_counts'].items(), key=lambda item: item[1], reverse=True)
# Out:
# [('0YZ3J8xzGwLOg4yEgST1YK', 2),
#  ('6FT83pFXKhDlXDsNJFAHWz', 1),
#  ('5tmrnhMxx39jnu3kjopMdP', 1),
#  ('6mGy6bzPJ6hrgPnVJZCEd4', 1),
#  ('2BydLQAh7CUIFvSEqAMc4x', 1)]

# %%
result
# Out:
# {'0YZ3J8xzGwLOg4yEgST1YK': {'score': 2,
#   'name': 'With A Little Help From My Friends',
#   'artist': 'Joe Cocker',
#   'url': 'https://i.scdn.co/image/ab67616d0000b2735bb09aa81ffb17ccf902629f',
#   'users': ['Nicholas, the creator', 'Anônimo']},
#  '6FT83pFXKhDlXDsNJFAHWz': {'score': 1,
#   'name': 'You Never Can Tell',
#   'artist': 'Chuck Berry',
#   'url': 'https://i.scdn.co/image/ab67616d0000b273e226488b7af9f296c95be551',
#   'users': ['Nicholas, the creator']},
#  '5tmrnhMxx39jnu3kjopMdP': {'score': 1,
#   'name': 'Evil Ways',
#   'artist': 'Santana',
#   'url': 'https://i.scdn.co/image/ab67616d0000b273c894463d06b775f87d57361b',
#   'users': ['Nicholas, the creator']},
#  '6mGy6bzPJ6hrgPnVJZCEd4': {'score': 1,
#   'name': 'Crossroads - 2008 Remaster',
#   'artist': 'Ry Cooder',
#   'url': 'https://i.scdn.co/image/ab67616d0000b2732045c02a2aba796742cc7973',
#   'users': ['Nicholas, the creator']},
#  '2BydLQAh7CUIFvSEqAMc4x': {'score': 1,
#   'name': 'If You Want Me to Stay',
# ...

# %%
from datetime import datetime, timedelta
period = 2
today = datetime.now()
cutoff_date = today - timedelta(days=period)

# %%
cutoff_date.strftime("%d-%m-%Y")
# Out:
# '24-01-2025'

# %%
from glob import glob
path = "static/reports/"
all_files = glob(path + "pass_log*.txt")
all_files
# Out:
# ['static/reports\\pass_log_20250120.txt',
#  'static/reports\\pass_log_20250121.txt',
#  'static/reports\\pass_log_20250122.txt',
#  'static/reports\\pass_log_20250123.txt',
#  'static/reports\\pass_log_20250124.txt',
#  'static/reports\\pass_log_20250126.txt']

# %%
from google.cloud.sql.connector import Connector, IPTypes
import pg8000
import sqlalchemy
from sqlalchemy import text

instance_connection_name = "jukebox-446711:southamerica-east1:jukebox" 
db_user = "postgres"
db_pass = "k]a-hXIRZ0taLT}K"
db_name = "postgres"

def getconn() -> pg8000.dbapi.Connection:
    """Initializes a connection to the Cloud SQL PostgreSQL instance."""
    connector = Connector()
    conn = connector.connect(
        instance_connection_name,
        "pg8000",
        user=db_user,
        password=db_pass,
        db=db_name,
        ip_type=IPTypes.PUBLIC  # or IPTypes.PRIVATE if applicable
    )
    return conn

# %%
# Create a connection pool using SQLAlchemy
pool = sqlalchemy.create_engine(
    "postgresql+pg8000://", creator=getconn
)

# %%
from sqlalchemy import text

query = text("""
        CREATE TABLE IF NOT EXISTS tracks(
            track_id VARCHAR(255) PRIMARY KEY,
            song_name VARCHAR(255),
            song_artist VARCHAR(255),
            album_url VARCHAR(255)
        )
    """)

# Use the connection pool to interact with the database
with pool.connect() as conn:
    # Execute SQL queries
    conn.execute(query)
    conn.commit()

# %%
query = text("INSERT INTO tracks (track_id, song_name, song_artist, album_url) VALUES ('6HwRRtvRPcrCtTKWYOgGtC', 'Noite Severina', 'Lula Queiroga', 'https://i.scdn.co/image/ab67616d0000b2738d5b8e619d6a3c0a530aac3f'), ('099z0pBmbnIKUHIH2G2HAq', 'Little Wing', 'Derek & The Dominos', 'https://i.scdn.co/image/ab67616d0000b27389040450a02bc9e9cb5b3dce');")

with pool.connect() as conn:
    conn.execute(query)
    conn.commit()

# %%
query = text("""
    CREATE TABLE IF NOT EXISTS likes(
    timestamp VARCHAR(255) PRIMARY KEY,
    track_id VARCHAR(255),
    user_name VARCHAR(255) 
    )
""")

# Use the connection pool to interact with the database
with pool.connect() as conn:
    # Execute SQL queries
    conn.execute(query)
    conn.commit()

# %%
query = text("""
             INSERT INTO likes (timestamp, track_id, user_name) VALUES
             ('2025-01-26 17:55:42.233', '099z0pBmbnIKUHIH2G2HAq', 'Nicholas, the creator');
            """)

with pool.connect() as conn:
    # Execute SQL queries
    conn.execute(query)
    conn.commit()

# %%
# Inserir linha verificando se já não existe

query = text("""
    INSERT INTO tracks (track_id, song_name, song_artist, album_url)
    SELECT '6HwRRtvRPcrCtTKWYOgGtT', 'Noite Severina', 'Lula Queiroga', 'https://i.scdn.co/image/ab67616d0000b2738d5b8e619d6a3c0a530aac3f'
    WHERE NOT EXISTS (
        SELECT 1 
        FROM tracks
        WHERE track_id = '6HwRRtvRPcrCtTKWYOgGtT' );
    """)

with pool.connect() as conn:
    conn.execute(query)
    conn.commit()

# %%
#DELETE LINE

query = text("""
            DELETE FROM tracks
            WHERE track_id = '6HwRRtvRPcrCtTKWYOgGtT';
""")

with pool.connect() as conn:
    conn.execute(query)
    conn.commit()

# %%
# GET VALUES
query = text("""
        SELECT * FROM tracks
        WHERE track_id = '6HwRRtvRPcrCtTKWYOgGtC';
""")

with pool.connect() as conn:
    result = conn.execute(query)
    print(result.fetchone())
# Out:
# ('6HwRRtvRPcrCtTKWYOgGtC', 'Noite Severina', 'Lula Queiroga', 'https://i.scdn.co/image/ab67616d0000b2738d5b8e619d6a3c0a530aac3f')

# %%
# GET VALUES
query = text("""
        CREATE TABLE IF NOT EXISTS generos (
        id SERIAL PRIMARY KEY,
        genero VARCHAR(40)
)
""")

with pool.connect() as conn:
    conn.execute(query)
    conn.commit()

# %%
def read_file_lines(filename):
  """
  Opens a text file with utf-8 encoding and returns a list of lines.

  Args:
    filename: The name of the file to open.

  Returns:
    A list of lines from the file.
  """
  try:
    with open(filename, 'r', encoding='utf-8') as file:
      lines = file.readlines()
      return lines
  except FileNotFoundError:
    print(f"Error: File '{filename}' not found.")
    return []

# Example usage:
file_lines = read_file_lines("archive/Lista generos Spotify.txt")

# %%
test = 'G' + 1388 * '0'

# %%
len(test)
# Out:
# 1389

# %%
query = f"""INSERT INTO configurations (config_name, ban_listm default_search, grant_list, refuse_msg_ban, refuse_msg_grant, share_msg, jukebox_title, genre_validation) VALUES
('Jukebox Inspiria', True, 'mpb', True, 'Gênero fora de contexto', 'Gênero não listado', 'Aqui, curtindo TRACK de ARTIST no jukebox do @barjacobina', 'Jukebox InpirIA', '{test}');
"""

# %%
# GET Gen val
query = text("""
        SELECT genre_validation FROM configurations
        WHERE config_name = 'jukebox';
""")

with pool.connect() as conn:
    result = conn.execute(query)
    gen_val = result.fetchone()[0]
print(gen_val)

# GET generos
query = text("""
        SELECT * FROM generos;
""")

with pool.connect() as conn:
    result = conn.execute(query)
    generos = result.fetchall()
print(len(generos))
# Out:
# ...
# 1388

# %%
def upgate_gen(string, genre, rep):
    """
    Replaces a character at a specific index in a string.

    Args:
        string: The input string.
        index: The index of the character to replace.
        replacement: The character to replace with.

    Returns:
        A new string with the character replaced.
    """
    #pool = create_engine( "postgresql+pg8000://", creator=getconn)

    query = text(f"SELECT id FROM generos WHERE genero = '{genre}';")

    with pool.connect() as conn:
        result = conn.execute(query)
        index = result.fetchone()

    if index:
        return string[:index[0]] + rep + string[index[0] + 1:]
    
    return string

# %%
returned = upgate_gen(gen_val, 'a cappella', 'B')

# %%
all_gen = [gen[0] for gen in generos]

# %%
query = "SELECT (id, genre_validation) FROM configurations;"
with pool.connect() as conn:
        result = conn.execute(text(query))
        configs = result.fetchall()

# %%
for config in configs:
    id = int(config[0][0])
    val = config[0][1][:77] + config[0][1][78:]
    query = f"UPDATE configurations SET genre_validation = '{val}' WHERE id = {id};"
    with pool.connect() as conn:
        conn.execute(text(query))
        conn.commit()

# %%
len(val)
# Out:
# 1390

# %%
# Out:
# '...'

# %%
genres, ban, grant = []
for i , val in enumerate(returned[1:4]):
    if val == 'A':
        grant.append(all_gen[i])
    elif val == 'B':
        ban.append(all_gen[i])
    else:
        genres.append(all_gen[i])
# Out:
#   Cell In[162], line 2
#     if val == 'A';
#                  ^
# SyntaxError: invalid syntax

# %%
[gen[0] for gen in generos]
# Out:
# ['a cappella',
#  'abstract',
#  'abstract beats',
#  'abstract hip hop',
#  'abstract idm',
#  'abstractro',
#  'accordion',
#  'acid house',
#  'acid jazz',
#  'acid techno',
#  'acousmatic',
#  'acoustic blues',
#  'acoustic pop',
#  'adult standards',
#  'african percussion',
#  'african rock',
#  'afrikaans',
#  'afrobeat',
#  'afrobeats',
#  'aggrotech',
#  'albanian pop',
#  'album rock',
#  'albuquerque indie',
#  'alternative americana',
#  'alternative country',
#  'alternative dance',
#  'alternative emo',
#  'alternative hardcore',
#  'alternative hip hop',
#  'alternative metal',
#  'alternative metalcore',
#  'alternative new age',
#  'alternative pop',
#  'alternative pop rock',
#  'alternative r&b',
#  'alternative rock',
#  'alternative roots rock',
#  'ambeat',
#  'ambient',
#  'ambient dub techno',
#  'ambient fusion',
#  'ambient idm',
#  'ambient psychill',
#  'ambient trance',
#  'anarcho-punk',
#  'andean',
#  'anime',
#  'anime score',
#  'anti-folk',
# ...

# %%
from sqlalchemy import create_engine

pool = create_engine( "postgresql+pg8000://", creator=getconn)
instance = 'jukebox'

# GET Gen val
query = text(f"""
        SELECT genre_validation FROM configurations
        WHERE config_name = '{instance}';
""")

with pool.connect() as conn:
    result = conn.execute(query)
    gen_val = result.fetchone()[0]


# GET generos
query = text("""
        SELECT * FROM generos;
""")

with pool.connect() as conn:
    result = conn.execute(query)
    generos = result.fetchall()

all_gen = [gen[1] for gen in generos]

genres, bans, grants = [], [], []

for i , val in enumerate(gen_val[1:]):
    if val == 'A':
        grants.append(all_gen[i])
    elif val == 'B':
        bans.append(all_gen[i])
    else:
        genres.append(all_gen[i])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 from sqlalchemy import create_engine
# ----> 3 pool = create_engine( "postgresql+pg8000://", creator=getconn)
#       4 instance = 'jukebox'
#       6 # GET Gen val
#
# NameError: name 'getconn' is not defined

# %%
grants
# Out:
# []

# %%
query = f"SELECT id FROM generos WHERE genero = 'axe';"
with pool.connect() as conn:
    result = conn.execute(text(query))
    id = result.fetchone()[0]

# %%
val = "..."

# %%
len(val)
# Out:
# 1389

# %%
val = val[:1387] + val[1388:]

# %%
query = f"UPDATE configurations SET genre_validation = '{val}' WHERE id = 1;"
with pool.connect() as conn:
    conn.execute(text(query))
    conn.commit()

# %%
genre = ['dafadsfad', 'sadfargtwhd', 'adsgdsfg']

# %%
print(genres)
print(genres.sort())
# Out:
# ['a cappella', 'abstract', 'abstract beats', 'abstract hip hop', 'abstract idm', 'abstractro', 'accordion', 'acid house', 'acid jazz', 'acid techno', 'acousmatic', 'acoustic blues', 'acoustic pop', 'adult standards', 'african percussion', 'african rock', 'afrikaans', 'afrobeat', 'afrobeats', 'aggrotech', 'albanian pop', 'album rock', 'albuquerque indie', 'alternative americana', 'alternative country', 'alternative dance', 'alternative emo', 'alternative hardcore', 'alternative hip hop', 'alternative metal', 'alternative metalcore', 'alternative new age', 'alternative pop', 'alternative pop rock', 'alternative r&b', 'alternative rock', 'alternative roots rock', 'ambeat', 'ambient', 'ambient dub techno', 'ambient fusion', 'ambient idm', 'ambient psychill', 'ambient trance', 'anarcho-punk', 'andean', 'anime', 'anime score', 'anti-folk', 'antiviral pop', 'appalachian folk', 'arab folk', 'arab pop', 'arabesk', 'argentine indie', 'argentine reggae', 'argentine rock', 'armenian folk', 'art 
# ...

# %%
query = f"SELECT genero FROM generos ORDER BY id ASC"
with pool.connect() as conn:
        result = conn.execute(text(query))
        list = result.fetchall()

# %%
list = [l[0] for l in list]

# %%
list.index("axe")
# Out:
# 1387

# %%
pool = create_engine( "postgresql+pg8000://", creator=getconn)
query = text(f"SELECT genero FROM generos ORDER BY id ASC;")

with pool.connect() as conn:
    result = conn.execute(query)
    list = result.fetchall()
list = [l[0] for l in list]
index = list.index('balearic')

# %%
index
# Out:
# 80

# %%
from google.cloud.sql.connector import Connector, IPTypes
import pg8000
from sqlalchemy import text, create_engine
from sqlalchemy.exc import SQLAlchemyError

instance_connection_name = "jukebox-446711:southamerica-east1:jukebox" 
db_user = "postgres"
db_pass = "k]a-hXIRZ0taLT}K"
db_name = "postgres"

def getconn() -> pg8000.dbapi.Connection:
    """Initializes a connection to the Cloud SQL PostgreSQL instance."""
    connector = Connector()
    conn = connector.connect(
        instance_connection_name,
        "pg8000",
        user=db_user,
        password=db_pass,
        db=db_name,
        ip_type=IPTypes.PUBLIC  # or IPTypes.PRIVATE if applicable
    )
    return conn

# %%
instance = "jukebox-jacobina"
query = f"""
INSERT INTO configurations (config_name, ban_list, grant_list, list_2_grant, list_2_ban, refuse_msg_grant, refuse_msg_ban, share_msg, default_search, jukebox_title)
VALUES ('{instance}', False, False, '[]', '[]', 'Não foi possível encontrar genero musical válido', 'Gênero musical do artista incompatível', 'Curtindo TRACK do ARTIST aqui na {instance}', 'mpb', '{instance}');
"""

pool = create_engine("postgresql+pg8000://", creator=getconn)
with pool.connect() as conn:
    conn.execute(text(query))
    conn.commit()
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# File c:\Users\nikin\OneDrive\Documentos\Projetos\Spotify\jukebox_env\Lib\site-packages\sqlalchemy\engine\base.py:1964, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1963     if not evt_handled:
# -> 1964         self.dialect.do_execute(
#    1965             cursor, str_statement, effective_parameters, context
#    1966         )
#    1968 if self._has_events or self.engine._has_events:
#
# File c:\Users\nikin\OneDrive\Documentos\Projetos\Spotify\jukebox_env\Lib\site-packages\sqlalchemy\engine\default.py:942, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     941 def do_execute(self, cursor, statement, parameters, context=None):
# --> 942     cursor.execute(statement, parameters)
#
# ...

# %%
"http://localhost:5000/callback"[:-9]
# Out:
# 'http://localhost:5000'

# %%
conn.execute()
conn.close()
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# File c:\Users\nikin\OneDrive\Documentos\Projetos\Spotify\jukebox_env\Lib\site-packages\sqlalchemy\engine\base.py:1964, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1963     if not evt_handled:
# -> 1964         self.dialect.do_execute(
#    1965             cursor, str_statement, effective_parameters, context
#    1966         )
#    1968 if self._has_events or self.engine._has_events:
#
# File c:\Users\nikin\OneDrive\Documentos\Projetos\Spotify\jukebox_env\Lib\site-packages\sqlalchemy\engine\default.py:942, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     941 def do_execute(self, cursor, statement, parameters, context=None):
# --> 942     cursor.execute(statement, parameters)
#
# ...

# %%
with pool.connect() as conn:
    result = conn.execute(text('SELECT * FROM configurations'))
    info = result.fetchall()

# %%
info
# Out:
# [(1, 'jukebox', True, 'rock', True, 'Gênero fora de contexto', 'Gênero não listado', 'Aqui, curtindo TRACK de ARTIST no jukebox do @barjacobina', 'Jukebox InpirIA', ['axé', 'forró universitario', 'pagode universitario', 'sertanejo', 'sertanejo universitario'], ['mpb', 'rock'])]

# %%
from datetime import datetime, date, timedelta
tmstp = datetime.now().timestamp()
ontem = datetime.today() - timedelta(days=1)

# %%
ontem
# Out:
# datetime.datetime(2025, 1, 29, 16, 58, 51, 960165)

# %%
tmstp = datetime.now().timestamp()

# %%
tmstp
# Out:
# 1738272887.082867

# %%
start_date = datetime(date.today().year, date.today().month, date.today().day)

# %%
start_date.strftime("%d/%m/%Y")
# Out:
# '30/01/2025'

# %%
then = datetime(2025, 1, 30, 8, 0, 0, 0).timestamp()

# %%
then
# Out:
# 1738234800.0

# %%
instance = 'jukebox'
start_date = datetime(2025, 1, 30, 8, 0, 0, 0).timestamp()
end_date = datetime.now().timestamp()


query = f""" 
SELECT
t.song_name,
t.album_url,
t.song_artist,
COUNT(l.track_id) AS like_count
FROM
likes l
JOIN
tracks t ON l.track_id = t.track_id
WHERE l.time_stamp BETWEEN {start_date} AND {end_date}  AND l.instance = '{instance}'
GROUP BY
t.song_name, t.album_url, t.song_artist
ORDER BY
like_count DESC;
"""

# %%
pool = create_engine( "postgresql+pg8000://", creator=getconn)
with pool.connect() as conn:
    result = conn.execute(text(query))
    info = result.fetchall()

# %%
info[0]._mapping
# Out:
# {'song_name': 'Fool in the Rain - Remaster', 'album_url': 'https://i.scdn.co/image/ab67616d0000b27315aa25b0b3b972a7be623605', 'song_artist': 'Led Zeppelin', 'like_count': 3}

# %%
line = dict(info[0]._mapping)

# %%
line
# Out:
# {'song_name': 'Fool in the Rain - Remaster',
#  'album_url': 'https://i.scdn.co/image/ab67616d0000b27315aa25b0b3b972a7be623605',
#  'like_count': 3}

# %%
import os
os.environ['JUKE_LIST'] = 'none'
juke_list = os.environ['JUKE_LIST'].split("', '")

# %%
juke_list
# Out:
# ['none']

# %%
import psycopg2

# %%
dburl = "postgresql://postgres:k]a-hXIRZ0taLT}K@/postgres?host=/cloudsql/jukebox-446711:southamerica-east1:jukebox"

# %%
conn = psycopg2.connect(dburl)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 conn = psycopg2.connect(dburl)
#
# File c:\Users\nikin\OneDrive\Documentos\Projetos\Spotify\jukebox_env\Lib\site-packages\psycopg2\__init__.py:122, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     119     kwasync['async_'] = kwargs.pop('async_')
#     121 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123 if cursor_factory is not None:
#     124     conn.cursor_factory = cursor_factory
#
# OperationalError: connection to server on socket "/cloudsql/jukebox-446711:southamerica-east1:jukebox/.s.PGSQL.5432" failed: Invalid argument (0x00002726/10022)
# 	Is the server running locally and accepting connections on that socket?

# %%
import uuid

def generate_unique_id():
  """Generates a unique identification ID using UUID v4.

  Returns:
      str: A unique ID string.
  """
  return str(uuid.uuid4())

# %%
print(generate_unique_id())
# Out:
# af166bf4-db6d-4ad6-a2af-2c690576a7a9

# %%
import datetime

datetime.datetime.now().timestamp()
# Out:
# 1742828287.670911

# %%
from sqlalchemy import create_engine
start_of_day_timestamp = datetime.datetime.now().replace(hour=0, minute=0, second=0, microsecond=0).timestamp()
now_timestamp = datetime.datetime.now().timestamp()
instance = 'jukebox'

pool = create_engine("postgresql+pg8000://", creator=getconn)

query = f"""
SELECT
l.time_stamp,
l.user_name,
t.song_name,
t.song_artist
FROM
likes l
JOIN
tracks t ON l.track_id = t.track_id
WHERE l.time_stamp BETWEEN {start_of_day_timestamp} AND {now_timestamp}  AND l.instance = '{instance}';
"""

with pool.connect() as conn:
    result = conn.execute(text(query))
    activity = result.fetchall()

if len(activity)>0:
    act = []
    for line in activity:
        line_dict = dict(line._mapping)
        line_dict['activity_type'] = "likes"
        act.append(line_dict)

print(act[0])
# Out:
# {'time_stamp': 1738677951.624238, 'user_name': 'Anônimo', 'song_name': 'Crossroads - 2008 Remaster', 'song_artist': 'Ry Cooder', 'activity_type': 'likes'}

# %%
query = """
SELECT
p.time_stamp,
p.user_name,
p.val_result,
t.song_name,
t.song_artist
FROM
pedidos p
JOIN
tracks t ON p.track_id = t.track_id
WHERE p.time_stamp BETWEEN 0 AND 1738686513.156527  AND p.instance = 'jukebox';
"""

sorted_data = sorted(data, key=lambda item: item['timestamp'])

# %%
from google.cloud.sql.connector import Connector, IPTypes
import pg8000
from sqlalchemy import text, create_engine
from sqlalchemy.exc import SQLAlchemyError
from passlib.hash import bcrypt
from datetime import datetime, timedelta
import asyncio
import os

class jukeSQL:
    def __init__(self, instance, ICN, DB_USER, DB_PASS, DB_NAME):
        self.instance = instance
        self.ICN = ICN
        self.DB_USER = DB_USER
        self.DB_PASS = DB_PASS
        self.DB_NAME = DB_NAME
        self.pool = create_engine( "postgresql+pg8000://", creator=self.__getconn__)

    def __getconn__(self) -> pg8000.dbapi.Connection:
        """Initializes a connection to the Cloud SQL PostgreSQL instance."""
        connector = Connector()
        conne = connector.connect(
            self.ICN,
            "pg8000",
            user=self.DB_USER,
            password=self.DB_PASS,
            db=DB_NAME,
            ip_type=IPTypes.PUBLIC  # or IPTypes.PRIVATE if applicable
        )
        return conne

    def save_token(self, token, expires_at, refresh_token):
        last_modified = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
        query = f"""
INSERT INTO instances (token, expires_at, ref_token, last_update)
VALUES ('{self.instance}', '{token}', '{expires_at}', '{last_modified}' )
ON CONFLICT (instance)
DO UPDATE SET token = '{token}', expires_at = '{expires_at}';
"""
        try:
            with self.pool.connect() as conn:
                conn.execute(text(query))
                conn.commit()
            return True
        except Exception as e:
            print("my log - 014 - Erro ao salvar token:", e)
            return False

    def get_token(self):
        query = f"SELECT token, ref_token, expires_at FROM instances WHERE instance='{self.instance}'"
        try:
            with self.pool.connect() as conn:
                result = conn.execute(text(query))
                row = result.fetchone()
            config_dict = dict(row._mapping)

            # Verificar validade

            # se válido retornar

            # se expirado erro de serviço

            return config_dict

        except Exception as e:
            return e

# %%
ICN = "jukebox-446711:southamerica-east1:jukebox" 
DB_USER = "postgres"
DB_PASS = "k]a-hXIRZ0taLT}K"
DB_NAME = "postgres"
INSTANCE = "jukebox"
juke = jukeSQL(INSTANCE, ICN, DB_USER, DB_PASS, DB_NAME)

# %%
tokens = juke.get_token()

# %%
tokens is not None
# Out:
# True
